# %% [markdown]
# # Week 06 / 2026

# %% [raw]
# 2025年版 Chrome 拡張機能ベスト20

# %% [raw]
# VS Code
# Indent-rainbow
# text syntax
# ToDo Tree

# %% [raw]
# 5 Python Libraries You Should Know in 2025!

# %% [raw]
# 【ありがたい】ChatGPTの環境を別物にする！Chrome拡張11選を紹介するぜ！！！
# 1. ChatGPT Ctrl+Enter Sender
# 2. AI質問ナビゲーター（Claude・ChatGPT・Gemini対応）
# 3. PinFlux - Pin ChatGPT Chats
# 4. ChatGPT to PDF by PDFCrowd
# 5. DeclutterGPT - Bulk Delete & Archive Chats
# 6. Searchable ChatGPT: search GPT conversation history
# 7. ChatGPT - ウェブサイトとYouTube動画の要約
# 8. GPThemes - ChatGPT Customization
# 9. Custom Themes for ChatGPT - Skins, Dark Mode & UI Styles
# 10. ChatGPT Folders Organizer - FolderMate: for GPT, Gemini, Grok
# 11. ChatGPT Timestamp

# %% [markdown]
# # *Get Week Number

# %%
from datetime import datetime

# Get today's date
today = datetime.now()

# Get the week number starting from Sunday
# %U: Week number of the year (Sunday as the first day of the week)
week_number = today.strftime("%U")

print(f"Today's date: {today.strftime('%Y-%m-%d')}")
print(f"Week Number (Sunday start): {week_number}")
# Out:
# Today's date: 2026-02-12
# Week Number (Sunday start): 06

# %%
! python yfinance/monitor.py
# Out:
# Fetching S&P 500 (^GSPC)...
# [*********************100%***********************]  1 of 1 completed
# Error fetching S&P 500: unsupported format string passed to Series.__format__
# Fetching Nikkei 225 (^N225)...
# [*********************100%***********************]  1 of 1 completed
# Error fetching Nikkei 225: unsupported format string passed to Series.__format__
# Fetching Gold (GC=F)...
# [*********************100%***********************]  1 of 1 completed
# Error fetching Gold: unsupported format string passed to Series.__format__
# Fetching VIX (^VIX)...
# [*********************100%***********************]  1 of 1 completed
# Error fetching VIX: unsupported format string passed to Series.__format__
# Fetching USD/JPY (JPY=X)...
# [*********************100%***********************]  1 of 1 completed
# Error fetching USD/JPY: unsupported format string passed to Series.__format__
# Fetching Crude Oil (CL=F)...
# [*********************100%***********************]  1 of 1 completed
# ...
