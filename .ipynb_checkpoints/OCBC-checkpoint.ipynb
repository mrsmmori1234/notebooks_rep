# %% [markdown]
# # OCBC 365

# %%
import pandas as pd
import glob
import os

# 1. すべての対象ファイルを取得

search_path = f"../Win_Downloads/TransactionHistory*.csv"
all_files = glob.glob(search_path)

li = []

for filename in all_files:
    temp_df = pd.read_csv(filename, encoding='cp932', skiprows=5, quotechar='"')
    temp_df['Transaction date'] = pd.to_datetime(temp_df['Transaction date'], dayfirst=True)
    temp_df['Description'] = temp_df['Description'].str.replace(r'\s+', ' ', regex=True).str.strip()
    li.append(temp_df)

df = pd.concat(li, axis=0, ignore_index=True)
df = df.drop_duplicates()
df = df.sort_values('Transaction date').reset_index(drop=True)
df = df.sort_values('Transaction date', ascending=False).reset_index(drop=True)

# %% [raw]
# Memo
# 2026-02-28	28/02/2026	FUND TRANSFER OTHR - OTHR via PayNow-Mobile fr...	NaN	450.00 -> Minko 入金 total 1300

# %%
df
# Out:
#    Transaction date  Value date  \
# 0        2026-03-01  28/02/2026
# 1        2026-02-28  28/02/2026
# 2        2026-02-19  19/02/2026
# 3        2026-02-18  19/02/2026
# 4        2026-02-16  16/02/2026
# 5        2026-02-16  16/02/2026
# 6        2026-02-14  14/02/2026
# 7        2026-02-13  13/02/2026
# 8        2026-02-13  13/02/2026
# 9        2026-02-12  12/02/2026
# 10       2026-02-10  10/02/2026
# 11       2026-02-10  10/02/2026
# 12       2026-02-10  10/02/2026
# 13       2026-02-02  02/02/2026
# 14       2026-02-02  02/02/2026
# 15       2026-02-01  31/01/2026
# 16       2026-01-23  23/01/2026
# 17       2026-01-23  23/01/2026
# 18       2026-01-22  22/01/2026
# 19       2026-01-22  22/01/2026
# 20       2026-01-21  21/01/2026
# 21       2026-01-21  21/01/2026
# 22       2026-01-19  19/01/2026
# 23       2026-01-19  19/01/2026
# 24       2026-01-12  12/01/2026
# 25       2026-01-12  12/01/2026
# 26       2026-01-12  12/01/2026
# 27       2026-01-02  02/01/2026
# 28       2026-01-02  02/01/2026
# 29       2026-01-02  02/01/2026
# 30       2026-01-02  02/01/2026
# 31       2026-01-01  31/12/2025
# 32       2025-12-23  23/12/2025
# 33       2025-12-20  20/12/2025
# 34       2025-12-17  17/12/2025
# 35       2025-12-12  12/12/2025
# 36       2025-12-09  09/12/2025
# 37       2025-12-09  09/12/2025
# 38       2025-12-09  09/12/2025
# 39       2025-12-07  08/12/2025
# 40       2025-12-03  03/12/2025
# 41       2025-12-02  02/12/2025
# 42       2025-12-01  01/12/2025
# 43       2025-11-30  29/11/2025
# 44       2025-11-25  25/11/2025
# 45       2025-11-24  24/11/2025
# 46       2025-11-19  19/11/2025
# 47       2025-11-12  12/11/2025
# 48       2025-11-11  11/11/2025
#
#                                           Description Withdrawals(SGD)  \
# 0                                     INTEREST CREDIT              NaN
# 1   FUND TRANSFER OTHR - OTHR via PayNow-Mobile fr...              NaN
# 2   IBG GIRO GIRO Collection 8934190185 SP SERVICE...            95.19
# 3   FAST PAYMENT OTHR-9263838450972645 to YOU TECH...           200.00
# 4         IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 5   FAST PAYMENT OTHR-2830218424305228 to YOU TECH...           200.00
# 6   FAST PAYMENT OTHR-2051788124184146 to YOU TECH...           200.00
# 7   FAST PAYMENT OTHR-1868939075356574 to YOU TECH...           480.00
# 8    FAST PAYMENT OTHR-naoki to SC CUT via PayNow-UEN            14.00
# 9   GIRO - SALARY 26021000169GS00004 T-SYSTEMS SIN...              NaN
# 10                    BONUS INTEREST 360 SALARY BONUS              NaN
# 11                  BONUS INTEREST 360 CC SPEND BONUS              NaN
# 12                      BONUS INTEREST 360 SAVE BONUS              NaN
# 13  IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 14  BILL PAYMENT INB INTERNET BANKING SINGAPORE541...         1,020.86
# 15                                    INTEREST CREDIT              NaN
# 16    CASH WITHDRAWAL ATM xx-2589 OCBC-QUEENSWAY SC S             80.0
# 17    CASH WITHDRAWAL ATM xx-2589 OCBC-QUEENSWAY SC S            80.00
# 18  GIRO - SALARY 26012000017GS00054 T-SYSTEMS SIN...              NaN
# 19  GIRO - SALARY 26012000017GS00054 SALA T-SYSTEM...              NaN
# 20       IBG GIRO 9031001075 OTHR T-SYSTEMS SINGAPORE              NaN
# 21        IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 22  IBG GIRO GIRO Collection 8934190185 SP SERVICE...            98.32
# 23  IBG GIRO GIRO Collection 8934190185 COLL 89341...            98.32
# 24                      BONUS INTEREST 360 SAVE BONUS              NaN
# 25                    BONUS INTEREST 360 SALARY BONUS              NaN
# 26                  BONUS INTEREST 360 CC SPEND BONUS              NaN
# 27  BILL PAYMENT INB INTERNET BANKING SINGAPORE541...           937.17
# 28  IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 29  BILL PAYMENT INB INTERNET BANKING SINGAPORE541...           937.17
# 30  IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 31                                    INTEREST CREDIT              NaN
# 32        IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 33  CASH WITHDRAWAL ATM xx-2589 OCBC-FP DAWSON PLA...             80.0
# 34  IBG GIRO GIRO Collection 8934190185 SP SERVICE...            85.96
# 35  IBG GIRO 25120900302GS00046 SALA T-SYSTEMS SIN...              NaN
# 36                  BONUS INTEREST 360 CC SPEND BONUS              NaN
# 37                      BONUS INTEREST 360 SAVE BONUS              NaN
# 38                    BONUS INTEREST 360 SALARY BONUS              NaN
# 39    CASH WITHDRAWAL ATM xx-2589 OCBC-QUEENSWAY SC S            80.00
# 40  IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 41  BILL PAYMENT INB INTERNET BANKING SINGAPORE541...         2,464.65
# 42  PAYMENT/TRANSFER DIVD 10989J9004M8GD from HSBC...              NaN
# 43                                    INTEREST CREDIT              NaN
# 44        IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 45  GIRO - SALARY 25111900178GS00011 T-SYSTEMS SIN...              NaN
# 46  IBG GIRO GIRO Collection 8934190185 SP SERVICE...            89.14
# 47  FAST PAYMENT OTHR-OTHR to Lye Bo via PayNow-Mo...             5.00
# 48                    BONUS INTEREST 360 SALARY BONUS              NaN
#
#    Deposits(SGD)
# 0           1.84
# 1         450.00
# 2            NaN
# 3            NaN
# 4           1.85
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9       7,030.83
# 10         41.35
# 11         13.78
# 12         13.78
# 13           NaN
# 14           NaN
# 15          1.72
# 16           NaN
# 17           NaN
# 18      7,030.83
# 19      7,030.83
# 20        139.90
# 21        139.90
# 22           NaN
# 23           NaN
# 24         12.42
# 25         37.26
# 26         12.42
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31          1.55
# 32        419.78
# 33           NaN
# 34           NaN
# 35      7,150.83
# 36          9.17
# 37          9.17
# 38         27.52
# 39           NaN
# 40           NaN
# 41           NaN
# 42      1,000.87
# 43          1.14
# 44         27.42
# 45      7,150.83
# 46           NaN
# 47           NaN
# 48         24.17

# %%
df.to_csv('./outputs/ocbc.csv', index=False, encoding='utf-8-sig')
