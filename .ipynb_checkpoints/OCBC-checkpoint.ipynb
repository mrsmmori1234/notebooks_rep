# %% [markdown]
# # OCBC 365

# %%
import pandas as pd
import glob
import os

# 1. すべての対象ファイルを取得

search_path = f"../Win_Downloads/TransactionHistory*.csv"
all_files = glob.glob(search_path)

li = []

for filename in all_files:
    temp_df = pd.read_csv(filename, encoding='cp932', skiprows=5, quotechar='"')
    temp_df['Transaction date'] = pd.to_datetime(temp_df['Transaction date'], dayfirst=True)
    temp_df['Description'] = temp_df['Description'].str.replace(r'\s+', ' ', regex=True).str.strip()
    li.append(temp_df)

df = pd.concat(li, axis=0, ignore_index=True)
df = df.drop_duplicates()
df = df.sort_values('Transaction date').reset_index(drop=True)
df = df.sort_values('Transaction date', ascending=False).reset_index(drop=True)

# %%
df
# Out:
#    Transaction date  Value date  \
# 0        2026-01-23  23/01/2026
# 1        2026-01-22  22/01/2026
# 2        2026-01-21  21/01/2026
# 3        2026-01-19  19/01/2026
# 4        2026-01-12  12/01/2026
# 5        2026-01-12  12/01/2026
# 6        2026-01-12  12/01/2026
# 7        2026-01-02  02/01/2026
# 8        2026-01-02  02/01/2026
# 9        2026-01-01  31/12/2025
# 10       2025-12-23  23/12/2025
# 11       2025-12-20  20/12/2025
# 12       2025-12-17  17/12/2025
# 13       2025-12-12  12/12/2025
# 14       2025-12-09  09/12/2025
# 15       2025-12-09  09/12/2025
# 16       2025-12-09  09/12/2025
# 17       2025-12-07  08/12/2025
# 18       2025-12-03  03/12/2025
# 19       2025-12-02  02/12/2025
# 20       2025-12-01  01/12/2025
# 21       2025-11-30  29/11/2025
# 22       2025-11-25  25/11/2025
# 23       2025-11-24  24/11/2025
# 24       2025-11-19  19/11/2025
# 25       2025-11-12  12/11/2025
# 26       2025-11-11  11/11/2025
#
#                                           Description Withdrawals(SGD)  \
# 0     CASH WITHDRAWAL ATM xx-2589 OCBC-QUEENSWAY SC S             80.0
# 1   GIRO - SALARY 26012000017GS00054 SALA T-SYSTEM...              NaN
# 2        IBG GIRO 9031001075 OTHR T-SYSTEMS SINGAPORE              NaN
# 3   IBG GIRO GIRO Collection 8934190185 COLL 89341...            98.32
# 4                       BONUS INTEREST 360 SAVE BONUS              NaN
# 5                   BONUS INTEREST 360 CC SPEND BONUS              NaN
# 6                     BONUS INTEREST 360 SALARY BONUS              NaN
# 7   IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 8   BILL PAYMENT INB INTERNET BANKING SINGAPORE541...           937.17
# 9                                     INTEREST CREDIT              NaN
# 10        IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 11  CASH WITHDRAWAL ATM xx-2589 OCBC-FP DAWSON PLA...             80.0
# 12  IBG GIRO GIRO Collection 8934190185 SP SERVICE...            85.96
# 13  IBG GIRO 25120900302GS00046 SALA T-SYSTEMS SIN...              NaN
# 14                    BONUS INTEREST 360 SALARY BONUS              NaN
# 15                  BONUS INTEREST 360 CC SPEND BONUS              NaN
# 16                      BONUS INTEREST 360 SAVE BONUS              NaN
# 17    CASH WITHDRAWAL ATM xx-2589 OCBC-QUEENSWAY SC S            80.00
# 18  IBG GIRO M1 Limited-Ref: 601932618 M1 LIMITED ...            30.45
# 19  BILL PAYMENT INB INTERNET BANKING SINGAPORE541...         2,464.65
# 20  PAYMENT/TRANSFER DIVD 10989J9004M8GD from HSBC...              NaN
# 21                                    INTEREST CREDIT              NaN
# 22        IBG GIRO 9031001075 T-SYSTEMS SINGAPOREOTHR              NaN
# 23  GIRO - SALARY 25111900178GS00011 T-SYSTEMS SIN...              NaN
# 24  IBG GIRO GIRO Collection 8934190185 SP SERVICE...            89.14
# 25  FAST PAYMENT OTHR-OTHR to Lye Bo via PayNow-Mo...             5.00
# 26                    BONUS INTEREST 360 SALARY BONUS              NaN
#
#    Deposits(SGD)
# 0            NaN
# 1       7,030.83
# 2         139.90
# 3            NaN
# 4          12.42
# 5          12.42
# 6          37.26
# 7            NaN
# 8            NaN
# 9           1.55
# 10        419.78
# 11           NaN
# 12           NaN
# 13      7,150.83
# 14         27.52
# 15          9.17
# 16          9.17
# 17           NaN
# 18           NaN
# 19           NaN
# 20      1,000.87
# 21          1.14
# 22         27.42
# 23      7,150.83
# 24           NaN
# 25           NaN
# 26         24.17

# %%
df.to_csv('./outputs/ocbc.csv', index=False, encoding='utf-8-sig')
