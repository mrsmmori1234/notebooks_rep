# %% [markdown]
# https://www.sgx.com/securities/etf-screener

# %% [markdown]
# # Setup

# %%
# Setup
# %load_ext autoreload
# %autoreload 2
#%load_ext jupyter_ai_magics
import sys; sys.path.append('..')
from src.env_setup import init_analysis_env; init_analysis_env()


df = load_local_data("myData*.csv*", na_values=['-'], dtype={'Code': str})
df.head()

# Cleaning
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 🚀 Analysis environment initialized: pd, np, yf, plt, sns, load_local_data, datetime, timedelta, xw are ready.
# Loading: /home/mrsmmori/notebooks/Win_Downloads/myData.csv
#               Trading Name Trading Code  CCY                               Underlying Benchmark  Close   Last  Chng %  \
# 0                  STI ETF          ES3  SGD                                Straits Times Index   4.41   4.41    0.14
# 1          IS ASIA HYG US$          O9P  USD  Bloomberg Asia USD High Yield Diversified Cred...   6.70   6.70    0.30
# 2                  GLD US$          O87  USD                                 LBMA Gold Price PM 340.00 340.00    1.52
# 3  Lion-OCBC Sec HSTECH S$          HST  SGD                               Hang Seng TECH Index   0.96   0.96    1.26
# 4      LION-PHILLIP S-REIT          CLR  SGD   Morningstar  Singapore REIT Yield Focus Index SM   0.86   0.86    0.93
#
#    Val ($M)  Yield (%)  TER (%)  ... Ann. TR 1Y (%) Ann. TR 3Y (%)   Asset Class  Geographical Focus  \
# 0      5.87       4.17     0.28  ...          30.48          14.80      Equities           Singapore
# 1      4.54       7.23     0.50  ...           7.16           8.99  Fixed Income                Asia
# 2      4.10        NaN     0.40  ...          35.65          24.62   Commodities                Gold
# 3      4.09        NaN     0.58  ...          61.74           7.35      Equities               China
# 4      2.97       5.67     0.60  ...          -0.23          -1.81         REITs           Singapore
#
#    Income Treatment  Sustainability linked  Management Style CPF Eligibility SIP/EIP Tick Size
# 0      Distributing                     No           PASSIVE             Yes     EIP      0.00
# 1      Distributing                     No           PASSIVE              No     EIP      0.01
# 2               NaN                     No           PASSIVE             Yes     EIP      0.01
# 3      Accumulating                     No           PASSIVE              No     EIP      0.00
# 4      Distributing                     No           PASSIVE              No     EIP      0.00
#
# [5 rows x 25 columns]

# %%
target_columns = [
    "Yield (%)",
    "TR 1M (%)",
    "TR 3M (%)",
    "TR 1Y (%)",
    "Ann. TR 1Y (%)",
    "Ann. TR 3Y (%)",
]

df[target_columns] = df[target_columns].round(2)

# %%
df["Geographical Focus"].value_counts()
# Out:
# Geographical Focus
# China               29
# Singapore           17
# Asia                15
# Asia Pacific         8
# India                3
# Vietnam              3
# Gold                 2
# USA                  2
# Japan                2
# Saudi Arabia         1
# Indonesia            1
# Emerging Markets     1
# Name: count, dtype: int64

# %% [markdown]
# # df -> df_usd, df_sgd

# %%
df_usd = df[(df["CCY"] == "USD") | (df["CCY"] == "USD")].copy()
df_sgd = df[(df["CCY"] == "SGD") | (df["CCY"] == "SGD")].copy()

# %% [markdown]
# # df_sgd -> df

# %%
df = df_sgd.copy()
df = df[df["Sustainability linked"] == "No"]

# %%
df["Geographical Focus"].value_counts()
# Out:
# Geographical Focus
# China           13
# Singapore        9
# Asia             6
# Asia Pacific     2
# Gold             1
# Japan            1
# Vietnam          1
# Name: count, dtype: int64

# %%
df["Asset Class"].value_counts()
# Out:
# Asset Class
# Equities        20
# Fixed Income     8
# REITs            4
# Commodities      1
# Name: count, dtype: int64

# %%
df["Income Treatment"].value_counts()
# Out:
# Income Treatment
# Distributing    20
# Accumulating    12
# Name: count, dtype: int64

# %% [raw]
# Distributing（分配型）
# → ファンドが得た配当や利息を投資家に分配します。
# → 例：ETFが四半期ごとに配当金を支払う。
#
# Accumulating（再投資型）
# → ファンドが得た配当や利息を投資家に分配せず、ファンド内部で自動的に再投資します。
# → その結果、投資家の受け取るキャッシュはないけど、基準価額（NAV）が上昇していきます。

# %%
base_url = "https://investors.sgx.com/market/securities?code="
last_url = "&type=etfs&lang=en"
df['URL'] = base_url + df['Trading Code'] + last_url

# %%
df = df[
    [
        "Trading Name",
        "Trading Code",
        #'CCY',
        "Underlying Benchmark",
        "URL",
        #'Close',
        #'Last',
        #'Chng %',
        #'Val ($M)',
        "Yield (%)",
        #'TER (%)',
        #'Documents',
        #'Fund Manager',
        "TR 1M (%)",
        "TR 3M (%)",
        "TR 1Y (%)",
        "Ann. TR 1Y (%)",
        "Ann. TR 3Y (%)",
        "Asset Class",
        "Geographical Focus",
        "Income Treatment",
        #'Sustainability linked',
        "Management Style",
        #'CPF Eligibility',
        #'SIP/EIP',
        #'Tick Size',
    ]
]

# %%
pd.crosstab(df["Asset Class"], df["Income Treatment"])
# Out:
# Income Treatment  Accumulating  Distributing
# Asset Class
# Equities                    11             9
# Fixed Income                 1             7
# REITs                        0             4

# %%
df_bonds = df.query("`Asset Class` == 'BONDS'")
df_bonds.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_747d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_747d1_level0_col0" class="col_heading level0 col0" >Trading Name</th>
#       <th id="T_747d1_level0_col1" class="col_heading level0 col1" >Trading Code</th>
#       <th id="T_747d1_level0_col2" class="col_heading level0 col2" >Underlying Benchmark</th>
#       <th id="T_747d1_level0_col3" class="col_heading level0 col3" >URL</th>
#       <th id="T_747d1_level0_col4" class="col_heading level0 col4" >Yield (%)</th>
#       <th id="T_747d1_level0_col5" class="col_heading level0 col5" >TR 1M (%)</th>
#       <th id="T_747d1_level0_col6" class="col_heading level0 col6" >TR 3M (%)</th>
#       <th id="T_747d1_level0_col7" class="col_heading level0 col7" >TR 1Y (%)</th>
#       <th id="T_747d1_level0_col8" class="col_heading level0 col8" >Ann. TR 1Y (%)</th>
#       <th id="T_747d1_level0_col9" class="col_heading level0 col9" >Ann. TR 3Y (%)</th>
#       <th id="T_747d1_level0_col10" class="col_heading level0 col10" >Asset Class</th>
#       <th id="T_747d1_level0_col11" class="col_heading level0 col11" >Geographical Focus</th>
#       <th id="T_747d1_level0_col12" class="col_heading level0 col12" >Income Treatment</th>
#       <th id="T_747d1_level0_col13" class="col_heading level0 col13" >Management Style</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
df_equities = df.query("`Asset Class`.str.lower() == 'equities'")
df_equities.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0495">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0495_level0_col0" class="col_heading level0 col0" >Trading Name</th>
#       <th id="T_a0495_level0_col1" class="col_heading level0 col1" >Trading Code</th>
#       <th id="T_a0495_level0_col2" class="col_heading level0 col2" >Underlying Benchmark</th>
#       <th id="T_a0495_level0_col3" class="col_heading level0 col3" >URL</th>
#       <th id="T_a0495_level0_col4" class="col_heading level0 col4" >Yield (%)</th>
#       <th id="T_a0495_level0_col5" class="col_heading level0 col5" >TR 1M (%)</th>
#       <th id="T_a0495_level0_col6" class="col_heading level0 col6" >TR 3M (%)</th>
#       <th id="T_a0495_level0_col7" class="col_heading level0 col7" >TR 1Y (%)</th>
#       <th id="T_a0495_level0_col8" class="col_heading level0 col8" >Ann. TR 1Y (%)</th>
#       <th id="T_a0495_level0_col9" class="col_heading level0 col9" >Ann. TR 3Y (%)</th>
#       <th id="T_a0495_level0_col10" class="col_heading level0 col10" >Asset Class</th>
#       <th id="T_a0495_level0_col11" class="col_heading level0 col11" >Geographical Focus</th>
#       <th id="T_a0495_level0_col12" class="col_heading level0 col12" >Income Treatment</th>
#       <th id="T_a0495_level0_col13" class="col_heading level0 col13" >Management Style</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0495_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0495_row0_col0" class="data row0 col0" >STI ETF</td>
#       <td id="T_a0495_row0_col1" class="data row0 col1" >ES3</td>
#       <td id="T_a0495_row0_col2" class="data row0 col2" >Straits Times Index</td>
#       <td id="T_a0495_row0_col3" class="data row0 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=ES3&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row0_col4" class="data row0 col4" >4.170000</td>
#       <td id="T_a0495_row0_col5" class="data row0 col5" >2.490000</td>
#       <td id="T_a0495_row0_col6" class="data row0 col6" >10.480000</td>
#       <td id="T_a0495_row0_col7" class="data row0 col7" >30.480000</td>
#       <td id="T_a0495_row0_col8" class="data row0 col8" >30.480000</td>
#       <td id="T_a0495_row0_col9" class="data row0 col9" >14.800000</td>
#       <td id="T_a0495_row0_col10" class="data row0 col10" >Equities</td>
#       <td id="T_a0495_row0_col11" class="data row0 col11" >Singapore</td>
#       <td id="T_a0495_row0_col12" class="data row0 col12" >Distributing</td>
#       <td id="T_a0495_row0_col13" class="data row0 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_a0495_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_a0495_row1_col0" class="data row1 col0" >Lion-OCBC Sec HSTECH S$</td>
#       <td id="T_a0495_row1_col1" class="data row1 col1" >HST</td>
#       <td id="T_a0495_row1_col2" class="data row1 col2" >Hang Seng TECH Index</td>
#       <td id="T_a0495_row1_col3" class="data row1 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=HST&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a0495_row1_col5" class="data row1 col5" >0.550000</td>
#       <td id="T_a0495_row1_col6" class="data row1 col6" >6.940000</td>
#       <td id="T_a0495_row1_col7" class="data row1 col7" >61.740000</td>
#       <td id="T_a0495_row1_col8" class="data row1 col8" >61.740000</td>
#       <td id="T_a0495_row1_col9" class="data row1 col9" >7.350000</td>
#       <td id="T_a0495_row1_col10" class="data row1 col10" >Equities</td>
#       <td id="T_a0495_row1_col11" class="data row1 col11" >China</td>
#       <td id="T_a0495_row1_col12" class="data row1 col12" >Accumulating</td>
#       <td id="T_a0495_row1_col13" class="data row1 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_a0495_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_a0495_row2_col0" class="data row2 col0" >Amova STI ETF</td>
#       <td id="T_a0495_row2_col1" class="data row2 col1" >G3B</td>
#       <td id="T_a0495_row2_col2" class="data row2 col2" >Straits Times Index</td>
#       <td id="T_a0495_row2_col3" class="data row2 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=G3B&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row2_col4" class="data row2 col4" >4.090000</td>
#       <td id="T_a0495_row2_col5" class="data row2 col5" >2.500000</td>
#       <td id="T_a0495_row2_col6" class="data row2 col6" >10.670000</td>
#       <td id="T_a0495_row2_col7" class="data row2 col7" >31.110000</td>
#       <td id="T_a0495_row2_col8" class="data row2 col8" >31.110000</td>
#       <td id="T_a0495_row2_col9" class="data row2 col9" >14.810000</td>
#       <td id="T_a0495_row2_col10" class="data row2 col10" >Equities</td>
#       <td id="T_a0495_row2_col11" class="data row2 col11" >Singapore</td>
#       <td id="T_a0495_row2_col12" class="data row2 col12" >Distributing</td>
#       <td id="T_a0495_row2_col13" class="data row2 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_a0495_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_a0495_row3_col0" class="data row3 col0" >Lion-OSPL China L S$</td>
#       <td id="T_a0495_row3_col1" class="data row3 col1" >YYY</td>
#       <td id="T_a0495_row3_col2" class="data row3 col2" >Hang Seng Stock Connect China 80 Index</td>
#       <td id="T_a0495_row3_col3" class="data row3 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=YYY&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row3_col4" class="data row3 col4" >3.050000</td>
#       <td id="T_a0495_row3_col5" class="data row3 col5" >1.520000</td>
#       <td id="T_a0495_row3_col6" class="data row3 col6" >7.980000</td>
#       <td id="T_a0495_row3_col7" class="data row3 col7" >32.610000</td>
#       <td id="T_a0495_row3_col8" class="data row3 col8" >32.610000</td>
#       <td id="T_a0495_row3_col9" class="data row3 col9" >5.940000</td>
#       <td id="T_a0495_row3_col10" class="data row3 col10" >Equities</td>
#       <td id="T_a0495_row3_col11" class="data row3 col11" >China</td>
#       <td id="T_a0495_row3_col12" class="data row3 col12" >Distributing</td>
#       <td id="T_a0495_row3_col13" class="data row3 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_a0495_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_a0495_row4_col0" class="data row4 col0" >CSOP Star&Chinext50 S$</td>
#       <td id="T_a0495_row4_col1" class="data row4 col1" >SCY</td>
#       <td id="T_a0495_row4_col2" class="data row4 col2" >CSI STAR and ChiNext 50 Index</td>
#       <td id="T_a0495_row4_col3" class="data row4 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=SCY&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a0495_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_a0495_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_a0495_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_a0495_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_a0495_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_a0495_row4_col10" class="data row4 col10" >Equities</td>
#       <td id="T_a0495_row4_col11" class="data row4 col11" >China</td>
#       <td id="T_a0495_row4_col12" class="data row4 col12" >Accumulating</td>
#       <td id="T_a0495_row4_col13" class="data row4 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_a0495_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_a0495_row5_col0" class="data row5 col0" >XT MSCHINA S$</td>
#       <td id="T_a0495_row5_col1" class="data row5 col1" >TID</td>
#       <td id="T_a0495_row5_col2" class="data row5 col2" >MSCI China TR Net Daily USD Index</td>
#       <td id="T_a0495_row5_col3" class="data row5 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=TID&type=etfs&lang=en">link</a></td>
#       <td id="T_a0495_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_a0495_

# %%
df_reits = df.query("`Asset Class` == 'REITs'")
df_reits.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8e7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8e7e_level0_col0" class="col_heading level0 col0" >Trading Name</th>
#       <th id="T_d8e7e_level0_col1" class="col_heading level0 col1" >Trading Code</th>
#       <th id="T_d8e7e_level0_col2" class="col_heading level0 col2" >Underlying Benchmark</th>
#       <th id="T_d8e7e_level0_col3" class="col_heading level0 col3" >URL</th>
#       <th id="T_d8e7e_level0_col4" class="col_heading level0 col4" >Yield (%)</th>
#       <th id="T_d8e7e_level0_col5" class="col_heading level0 col5" >TR 1M (%)</th>
#       <th id="T_d8e7e_level0_col6" class="col_heading level0 col6" >TR 3M (%)</th>
#       <th id="T_d8e7e_level0_col7" class="col_heading level0 col7" >TR 1Y (%)</th>
#       <th id="T_d8e7e_level0_col8" class="col_heading level0 col8" >Ann. TR 1Y (%)</th>
#       <th id="T_d8e7e_level0_col9" class="col_heading level0 col9" >Ann. TR 3Y (%)</th>
#       <th id="T_d8e7e_level0_col10" class="col_heading level0 col10" >Asset Class</th>
#       <th id="T_d8e7e_level0_col11" class="col_heading level0 col11" >Geographical Focus</th>
#       <th id="T_d8e7e_level0_col12" class="col_heading level0 col12" >Income Treatment</th>
#       <th id="T_d8e7e_level0_col13" class="col_heading level0 col13" >Management Style</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e7e_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_d8e7e_row0_col0" class="data row0 col0" >LION-PHILLIP S-REIT</td>
#       <td id="T_d8e7e_row0_col1" class="data row0 col1" >CLR</td>
#       <td id="T_d8e7e_row0_col2" class="data row0 col2" >Morningstar  Singapore REIT Yield Focus Index SM</td>
#       <td id="T_d8e7e_row0_col3" class="data row0 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=CLR&type=etfs&lang=en">link</a></td>
#       <td id="T_d8e7e_row0_col4" class="data row0 col4" >5.670000</td>
#       <td id="T_d8e7e_row0_col5" class="data row0 col5" >0.360000</td>
#       <td id="T_d8e7e_row0_col6" class="data row0 col6" >8.630000</td>
#       <td id="T_d8e7e_row0_col7" class="data row0 col7" >-0.230000</td>
#       <td id="T_d8e7e_row0_col8" class="data row0 col8" >-0.230000</td>
#       <td id="T_d8e7e_row0_col9" class="data row0 col9" >-1.810000</td>
#       <td id="T_d8e7e_row0_col10" class="data row0 col10" >REITs</td>
#       <td id="T_d8e7e_row0_col11" class="data row0 col11" >Singapore</td>
#       <td id="T_d8e7e_row0_col12" class="data row0 col12" >Distributing</td>
#       <td id="T_d8e7e_row0_col13" class="data row0 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_d8e7e_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d8e7e_row1_col0" class="data row1 col0" >Amova-STC Asia REIT</td>
#       <td id="T_d8e7e_row1_col1" class="data row1 col1" >CFA</td>
#       <td id="T_d8e7e_row1_col2" class="data row1 col2" >FTSE EPRA/NAREIT Asia ex Japan Net Total Return REIT Index</td>
#       <td id="T_d8e7e_row1_col3" class="data row1 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=CFA&type=etfs&lang=en">link</a></td>
#       <td id="T_d8e7e_row1_col4" class="data row1 col4" >5.450000</td>
#       <td id="T_d8e7e_row1_col5" class="data row1 col5" >1.550000</td>
#       <td id="T_d8e7e_row1_col6" class="data row1 col6" >9.090000</td>
#       <td id="T_d8e7e_row1_col7" class="data row1 col7" >6.530000</td>
#       <td id="T_d8e7e_row1_col8" class="data row1 col8" >6.530000</td>
#       <td id="T_d8e7e_row1_col9" class="data row1 col9" >-1.400000</td>
#       <td id="T_d8e7e_row1_col10" class="data row1 col10" >REITs</td>
#       <td id="T_d8e7e_row1_col11" class="data row1 col11" >Asia</td>
#       <td id="T_d8e7e_row1_col12" class="data row1 col12" >Distributing</td>
#       <td id="T_d8e7e_row1_col13" class="data row1 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_d8e7e_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_d8e7e_row2_col0" class="data row2 col0" >CSOP iEdge SREIT ETF S$</td>
#       <td id="T_d8e7e_row2_col1" class="data row2 col1" >SRT</td>
#       <td id="T_d8e7e_row2_col2" class="data row2 col2" >iEdge SREIT Leaders Index</td>
#       <td id="T_d8e7e_row2_col3" class="data row2 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=SRT&type=etfs&lang=en">link</a></td>
#       <td id="T_d8e7e_row2_col4" class="data row2 col4" >5.730000</td>
#       <td id="T_d8e7e_row2_col5" class="data row2 col5" >3.850000</td>
#       <td id="T_d8e7e_row2_col6" class="data row2 col6" >11.220000</td>
#       <td id="T_d8e7e_row2_col7" class="data row2 col7" >2.550000</td>
#       <td id="T_d8e7e_row2_col8" class="data row2 col8" >2.550000</td>
#       <td id="T_d8e7e_row2_col9" class="data row2 col9" >-1.130000</td>
#       <td id="T_d8e7e_row2_col10" class="data row2 col10" >REITs</td>
#       <td id="T_d8e7e_row2_col11" class="data row2 col11" >Singapore</td>
#       <td id="T_d8e7e_row2_col12" class="data row2 col12" >Distributing</td>
#       <td id="T_d8e7e_row2_col13" class="data row2 col13" >PASSIVE</td>
#     </tr>
#     <tr>
#       <th id="T_d8e7e_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_d8e7e_row3_col0" class="data row3 col0" >PHIL AP DIV REIT S$D</td>
#       <td id="T_d8e7e_row3_col1" class="data row3 col1" >BYJ</td>
#       <td id="T_d8e7e_row3_col2" class="data row3 col2" >iEdge APAC ex Japan Dividend Leaders REIT Index</td>
#       <td id="T_d8e7e_row3_col3" class="data row3 col3" ><a target="_blank" href="https://investors.sgx.com/market/securities?code=BYJ&type=etfs&lang=en">link</a></td>
#       <td id="T_d8e7e_row3_col4" class="data row3 col4" >4.280000</td>
#       <td id="T_d8e7e_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_d8e7e_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_d8e7e_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_d8e7e_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_d8e7e_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_d8e7e_row3_col10" class="data row3 col10" >REITs</td>
#       <td id="T_d8e7e_row3_col11" class="data row3 col11" >Asia Pacific</td>
#       <td id="T_d8e7e_row3_col12" class="data row3 col12" >Distributing</td>
#       <td id="T_d8e7e_row3_col13" class="data row3 col13" >PASSIVE</td>
#     </tr>
#   </tbody>
# </table>

# %%
#df.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})

# %%
code = "VND"
url = f"https://www.example.com/stocks/{code}"
print(url)
# Out:
# https://www.example.com/stocks/VND

# %% [markdown]
# # df_usd -> df

# %%
df = df_usd.copy()
df = df[df["Sustainability linked"] == "No"]

# %%
grouped = df.groupby(["Asset Class", "Income Treatment"])

for (asset_class, income), group_df in grouped:
    print(f"=== Asset Class: {asset_class}, Income Treatment: {income} ===")
    group_df

# %%
base_url = "https://investors.sgx.com/market/securities?code="
last_url = "&type=etfs&lang=en"
df['URL'] = base_url + df['Trading Code'] + last_url
df.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})
