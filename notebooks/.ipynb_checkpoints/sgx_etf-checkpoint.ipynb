# %% [markdown]
# https://www.sgx.com/securities/etf-screener

# %% [markdown]
# # Setup

# %%
import pandas as pd

pd.set_option("display.float_format", "{:.2f}".format)
pd.set_option("display.width", 120)
pd.set_option("display.max_rows", 50)
pd.set_option("display.max_columns", 20)

from IPython.display import display, HTML
from IPython import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
from datetime import datetime
import xlwings as xw
import time
import glob
import re

# import warnings
# warnings.filterwarnings("ignore")
import hashlib
from IPython.display import HTML

# %%
import os
import pandas as pd
import numpy as np

# Define the folder path
folder_path = os.path.expanduser("~/notebooks/Win_Downloads")
# Get all files that start with 'export' and end with '.xlsx'
export_files = [
    f for f in os.listdir(folder_path) if f.startswith("myData") and f.endswith(".csv")
]
# Check if any matching files exist
if not export_files:
    raise FileNotFoundError("No 'export*.xlsx' files found in the specified folder.")
# Find the latest file based on modification time
latest_file = max(
    export_files, key=lambda f: os.path.getmtime(os.path.join(folder_path, f))
)
# Build the full path to the latest file
latest_file_path = os.path.join(folder_path, latest_file)
# Read the Excel file using pandas
df = pd.read_csv(latest_file_path)

# Display the result
print(f"Loaded file: {latest_file_path}")
# Out:
# Loaded file: /home/mrsmmori/notebooks/Win_Downloads/myData.csv

# %%
df = df.replace("-", np.nan)

for col in df.columns:
    try:
        df[col] = df[col].str.replace(",", "")
        df[col] = pd.to_numeric(df[col])
    except Exception:
        pass  #

# %%
df["Geographical Focus"].value_counts()
# Out:
# Geographical Focus
# China               29
# Singapore           17
# Asia                15
# Asia Pacific         8
# India                3
# Vietnam              3
# Gold                 2
# USA                  2
# Japan                2
# Saudi Arabia         1
# Indonesia            1
# Emerging Markets     1
# Name: count, dtype: int64

# %% [markdown]
# # df -> df_usd, df_sgd

# %%
df_usd = df[(df["CCY"] == "USD") | (df["CCY"] == "USD")].copy()
df_sgd = df[(df["CCY"] == "SGD") | (df["CCY"] == "SGD")].copy()

# %% [markdown]
# # df_sgd -> df

# %%
df = df_sgd.copy()
df = df[df["Sustainability linked"] == "No"]

# %%
df["Geographical Focus"].value_counts()
# Out:
# Geographical Focus
# China           13
# Singapore        9
# Asia             6
# Asia Pacific     2
# Gold             1
# Japan            1
# Vietnam          1
# Name: count, dtype: int64

# %%
df["Asset Class"].value_counts()
# Out:
# Asset Class
# Equities        20
# Fixed Income     8
# REITs            4
# Commodities      1
# Name: count, dtype: int64

# %%
df["Income Treatment"].value_counts()
# Out:
# Income Treatment
# Distributing    20
# Accumulating    12
# Name: count, dtype: int64

# %% [raw]
# Distributing（分配型）
# → ファンドが得た配当や利息を投資家に分配します。
# → 例：ETFが四半期ごとに配当金を支払う。
#
# Accumulating（再投資型）
# → ファンドが得た配当や利息を投資家に分配せず、ファンド内部で自動的に再投資します。
# → その結果、投資家の受け取るキャッシュはないけど、基準価額（NAV）が上昇していきます。

# %%
df.columns
# Out:
# Index(['Trading Name', 'Trading Code', 'CCY', 'Underlying Benchmark', 'Close', 'Last', 'Chng %', 'Val ($M)',
#        'Yield (%)', 'TER (%)', 'Documents', 'Fund Manager', 'TR 1M (%)', 'TR 3M (%)', 'TR 1Y (%)', 'Ann. TR 1Y (%)',
#        'Ann. TR 3Y (%)', 'Asset Class', 'Geographical Focus', 'Income Treatment', 'Sustainability linked',
#        'Management Style', 'CPF Eligibility', 'SIP/EIP', 'Tick Size'],
#       dtype='str')

# %%
df = df[
    [
        "Trading Name",
        "Trading Code",
        #'CCY',
        "Underlying Benchmark",
        #'Close',
        #'Last',
        #'Chng %',
        #'Val ($M)',
        "Yield (%)",
        #'TER (%)',
        #'Documents',
        #'Fund Manager',
        "TR 1M (%)",
        "TR 3M (%)",
        "TR 1Y (%)",
        "Ann. TR 1Y (%)",
        "Ann. TR 3Y (%)",
        "Asset Class",
        "Geographical Focus",
        "Income Treatment",
        #'Sustainability linked',
        "Management Style",
        #'CPF Eligibility',
        #'SIP/EIP',
        #'Tick Size',
    ]
]

# %%
grouped = df.groupby(["Asset Class", "Income Treatment"])

for (asset_class, income), group_df in grouped:
    print(f"=== Asset Class: {asset_class}, Income Treatment: {income} ===")
    group_df
# Out:
# === Asset Class: Equities, Income Treatment: Accumulating ===
#                Trading Name Trading Code                         Underlying Benchmark  Yield (%)  TR 1M (%)  \
# 3   Lion-OCBC Sec HSTECH S$          HST                         Hang Seng TECH Index        NaN       0.55
# 13   CSOP Star&Chinext50 S$          SCY                CSI STAR and ChiNext 50 Index        NaN        NaN
# 14            XT MSCHINA S$          TID            MSCI China TR Net Daily USD Index        NaN       1.08
# 15       Amova Asia exJC S$          A93         MSCI AC Asia ex Japan ex China Index        NaN        NaN
# 30    AmovaEFund ChiNext S$          CXT                                ChiNext Index        NaN        NaN
# 32   A Lion-Nomura Japan S$          JJJ                                  Topix Index        NaN       6.70
# 33      CF VN 30 SC ETF SG$          VNM  iEdge Vietnam 30 Sector Cap USD Index (NTR)        NaN      14.86
# 35  UOBAM PINGAN CHINEXT S$          CXS                                ChiNext Index        NaN      19.97
# 44     CSOP SEA TECH ETF S$          SQQ             iEdge Southeast Asia+ TECH Index        NaN       7.16
# 69       Lion-CM EM Asia S$          EAA          iEdge Emerging Asia Select 50 Index        NaN        NaN
# 76  PHIL-CU MS CHINA A50 S$          MCN                MSCI China A 50 Connect Index        NaN      12.23
#
#     TR 3M (%)  TR 1Y (%)  Ann. TR 1Y (%)  Ann. TR 3Y (%) Asset Class Geographical Focus Income Treatment  \
# 3        6.94      61.74           61.74            7.35    Equities              China     Accumulating
# 13        NaN        NaN             NaN             NaN    Equities              China     Accumulating
# 14      10.76      45.53           45.53            5.82    Equities              China     Accumulating
# 15        NaN        NaN             NaN             NaN    Equities               Asia     Accumulating
# 30        NaN        NaN             NaN             NaN    Equities              China     Accumulating
# 32      10.70      21.00           21.00             NaN    Equities              Japan     Accumulating
# 33      31.68      39.34           39.34             NaN    Equities            Vietnam     Accumulating
# 35      39.96      74.23           74.23             NaN    Equities              China     Accumulating
# 44      12.44      12.56           12.56             NaN    Equities               Asia     Accumulating
# 69        NaN        NaN             NaN             NaN    Equities               Asia     Accumulating
# 76      18.92      34.46           34.46             NaN    Equities              China     Accumulating
#
#    Management Style
# 3           PASSIVE
# 13          PASSIVE
# 14          PASSIVE
# 15          PASSIVE
# 30          PASSIVE
# 32           ACTIVE
# 33          PASSIVE
# 35          PASSIVE
# 44          PASSIVE
# 69          PASSIVE
# 76          PASSIVE
# === Asset Class: Equities, Income Treatment: Distributing ===
#              Trading Name Trading Code                       Underlying Benchmark  Yield (%)  TR 1M (%)  TR 3M (%)  \
# 0                 STI ETF          ES3                        Straits Times Index       4.17       2.49      10.48
# 9           Amova STI ETF          G3B                        Straits Times Index       4.09       2.50      10.67
# 10   Lion-OSPL China L S$          YYY     Hang Seng Stock Connect China 80 Index       3.05       1.52       7.98
# 17  Lion-OSPL APAC Fin S$          YLD  iEdge APAC Financials Dividend Plus Index       6.44       4.43       5.85
# 22   UOBAM FTSE CN A50 S$          JK8                       FTSE China A50 Index        NaN        NaN        NaN
# 34     Lion-CM CSI Div S$          INC                         CSI Dividend Index        NaN     -99.89     -99.89
# 39          PHIL SING INC          OVQ   Morningstar  Singapore Yield Focus Index       3.39       2.11       7.78
# 59      CGS FG CSI1000 S$          GRO                             CSI 1000 Index        NaN      15.17      25.95
# 61        CSOP DIV ETF S$          SHD                         SSE Dividend Index        NaN       0.38       2.63
#
#     TR 1Y (%)  Ann. TR 1Y (%)  Ann. TR 3Y (%) Asset Class Geographical Focus Income Treatment Management Style
# 0       30.48           30.48           14.80    Equities          Singapore     Distributing          PASSIVE
# 9       31.11           31.11           14.81    Equities          Singapore     Distributing          PASSIVE
# 10      32.61           32.61            5.94    Equities              China     Distributing          PASSIVE
# 17      17.94           17.94             NaN    Equities       Asia Pacific     Distributing          PASSIVE
# 22        NaN             NaN             NaN    Equities              China     Distributing          PASSIVE
# 34        NaN             NaN             NaN    Equities              China     Distributing          PASSIVE
# 39      26.43           26.43           13.30    Equities          Singapore     Distributing          PASSIVE
# 59      54.98           54.98             NaN    Equities              China     Distributing          PASSIVE
# 61       7.55            7.55             NaN    Equities              China     Distributing          PASSIVE
# === Asset Class: Fixed Income, Income Treatment: Accumulating ===
#           Trading Name Trading Code                  Underlying Benchmark  Yield (%)  TR 1M (%)  TR 3M (%)  TR 1Y (%)  \
# 37  XT SingGovBond SG$          KV4  FTSE Singapore Government Bond Index        NaN       2.64       5.78      10.25
#
#     Ann. TR 1Y (%)  Ann. TR 3Y (%)   Asset Class Geographical Focus Income Treatment Management Style
# 37           10.25            5.86  Fixed Income          Singapore     Accumulating          PASSIVE
# === Asset Class: Fixed Income, Income Treatment: Distributing ===
#             Trading Name Trading Code                               Underlying Benchmark  Yield (%)  TR 1M (%)  \
# 7        ABF SG BOND ETF          A35                     iBoxx ABF Singapore Bond Index       2.24       2.37
# 8   Amova SGD IGBond ETF          MBH  iBoxx SGD Non-Sovereigns Large Cap Investment ...       3.22       1.14
# 12       IS ASIA HYG S$D          QL3  Bloomberg Asia USD High Yield Diversified Cred...       7.23        NaN
# 21         PHILLIP MM S$          MMS                         FTSE SGD 3-month SOR Index       2.88       0.15
# 29       IS ASIA BND S$D          QL2               J.P. Morgan Asia Credit Index - Core       4.24        NaN
# 42  ICBC CSOP CGB ETF S$          CYC                 FTSE Chinese Government Bond Index       2.95       0.37
# 45   Amova-ICBCSG CNB S$          ZHS  ChinaBond ICBC 1-10 Year Treasury and Policy B...       2.37       0.31
#
#     TR 3M (%)  TR 1Y (%)  Ann. TR 1Y (%)  Ann. TR 3Y (%)   Asset Class Geographical Focus Income Treatment  \
# 7        5.49       9.92            9.92            6.15  Fixed Income          Singapore     Distributing
# 8        3.98       8.50            8.50            6.20  Fixed Income          Singapore     Distributing
# 12        NaN        NaN             NaN             NaN  Fixed Income               Asia     Distributing
# 21       0.56       1.78            1.78            2.65  Fixed Income          Singapore     Distributing
# 29        NaN        NaN             NaN             NaN  Fixed Income               Asia     Distributing
# 42       0.50       1.54            1.54            0.01  Fixed Income              China     Distributing
# 45       0.05       0.57            0.57           -0.69  Fixed Income              China     Distributing
#
#    Management Style
# 7           PASSIVE
# 8           PASSIVE
# 12          PASSIVE
# 21          PASSIVE
# 29          PASSIVE
# 42          PASSIVE
# 45          PASSIVE
# === Asset Class: REITs, Income Treatment: Distributing ===
#                Trading Name Trading Code                               Underlying Benchmark  Yield (%)  TR 1M (%)  \
# 4       LION-PHILLIP S-REIT          CLR   Morningstar  Singapore REIT Yield Focus Index SM       5.67       0.36
# 5       Amova-STC Asia REIT          CFA  FTSE EPRA/NAREIT Asia ex Japan Net Total Retur...       5.45       1.55
# 11  CSOP iEdge SREIT ETF S$          SRT                          iEdge SREIT Leaders Index       5.73       3.85
# 23     PHIL AP DIV REIT S$D          BYJ    iEdge APAC ex Japan Dividend Leaders REIT Index       4.28        NaN
#
#     TR 3M (%)  TR 1Y (%)  Ann. TR 1Y (%)  Ann. TR 3Y (%) Asset Class Geographical Focus Income Treatment  \
# 4        8.63      -0.23           -0.23           -1.81       REITs          Singapore     Distributing
# 5        9.09       6.53            6.53           -1.40       REITs               Asia     Distributing
# 11      11.22       2.55            2.55           -1.13       REITs          Singapore     Distributing
# 23        NaN        NaN             NaN             NaN       REITs       Asia Pacific     Distributing
#
#    Management Style
# 4           PASSIVE
# 5           PASSIVE
# 11          PASSIVE
# 23          PASSIVE

# %%
code = "VND"
url = f"https://www.example.com/stocks/{code}"
print(url)
# Out:
# https://www.example.com/stocks/VND

# %% [markdown]
# # df_usd -> df

# %%
df = df_usd.copy()
df = df[df["Sustainability linked"] == "No"]

# %%
grouped = df.groupby(["Asset Class", "Income Treatment"])

for (asset_class, income), group_df in grouped:
    print(f"=== Asset Class: {asset_class}, Income Treatment: {income} ===")
    group_df

# %%
base_url = "https://investors.sgx.com/market/securities?code="
last_url = "&type=etfs&lang=en"
df['URL'] = base_url + df['Trading Code'] + last_url
df.style.format({'URL': lambda x: f'<a target="_blank" href="{x}">link</a>'})
