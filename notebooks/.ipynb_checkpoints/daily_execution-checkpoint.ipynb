# %% [markdown]
# # setup

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %% [markdown]
# # youtube-env

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UbTkEyU5mJc
# [youtube] UbTkEyU5mJc: Downloading webpage
# [youtube] UbTkEyU5mJc: Downloading android vr player API JSON
# [info] UbTkEyU5mJc: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.f398.mp4
# [download] Got error: The read operation timed out. Retrying (1/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.mp4"
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.f251.webm (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-24 - スウェーデン戦の舞台アメリカのテキサス州ダラスに帰還！【北中米W杯#7】2026年6月21日 - UbTkEyU5mJc.f398.mp4 (pass -k to keep)
# [download] GL-iChSS-bE: World Cup Tunisia Match 🇲🇽 Completely felt like a home game for Japan with massive support from M... has already been recorded in the archive
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] kcxRQo6MgN0: Inside Of The Most Unequal Country In The World has already been recorded in the archive
# [download] atQFyMEStqQ: Surviving with The Last Hunters in Greenland’s Ice World has already been recorded in the archive
# [download] Finished downloading playlist: Bappa Shota - Videos
# Completed: https://www.youtube.com/@BappaShota/videos
# ✅ All processes completed

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# Everything up-to-date
# [main 3385385] Jun 25
#  2 files changed, 7 insertions(+)

# %% [markdown]
# # scripts-env

# %%
env_name = "scripts"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Everything up-to-date
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # notebooks-env

# %%
env_name = "notebooks"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/notebooks_rep.git
#    81aac77..bad7ab7  main -> main
# [main 695d41b] Jun 25
#  1 file changed, 473 insertions(+), 843 deletions(-)
#  rewrite notebooks/daily_execution.ipynb (63%)

# %% [markdown]
# # web_scraping-env

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Everything up-to-date
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # daily check

# %%
from datetime import datetime

# Get today's date
today = datetime.now()

# Get the week number starting from Sunday
# %U: Week number of the year (Sunday as the first day of the week)
week_number = today.strftime("%U")

print(f"Today's date: {today.strftime('%Y-%m-%d')}")
print(f"Week Number (Sunday start): {week_number}")
# Out:
# Today's date: 2026-06-25
# Week Number (Sunday start): 25

# %%
import datetime
import pandas as pd
import yfinance as yf
from IPython.display import display, HTML

# Define the lookback periods (in business days) for performance calculation.
LOOKBACK_DAYS = {
    "1 Day (%)": -2,
    "3 Days (%)": -4,
    "1 Week (%)": -6,
    "1 Month (%)": -21,
    "6 Months (%)": -126,
    "1 Year (%)": -252,
}

# =====================================================================
# DATA PROCESSING FUNCTION (Supports Market Segmentation)
# =====================================================================
def show_market_performances(market_dict):
    today = datetime.date.today()
    start_date = today - datetime.timedelta(days=60)
    
    # Format numerical values to 2 decimal places
    format_config = {"Latest Price": "{:,.2f}"}
    for column_name in LOOKBACK_DAYS.keys():
        format_config[column_name] = "{:+.2f}%"
        
    # -----------------------------------------------------------------
    # ハイライト用の条件関数を定義
    # -----------------------------------------------------------------
    def highlight_extreme_values(val):
        if pd.isna(val):
            return ''
        
        # 10%以上の場合（薄い赤背景に赤文字、太字）
        if val >= 10:
            return 'background-color: #ffcccc; color: #cc0000; font-weight: bold;'
        
        # -10%以下の場合（薄い青背景に青文字、太字）
        elif val <= -10:
            return 'background-color: #cce5ff; color: #004085; font-weight: bold;'
        
        return ''
    # -----------------------------------------------------------------
        
    # Process each market section
    for market_name, ticker_dict in market_dict.items():
        records = []
        
        # Display market header
        display(HTML(f"<h3 style='margin-top: 20px; color: #333;'>■ {market_name} Market</h3>"))
        
        for name, ticker in ticker_dict.items():
            try:
                # Download stock data
                df = yf.download(ticker, start=start_date, end=today, progress=False)
                
                if df.empty:
                    print(f"[Warning] No data found for: {name} ({ticker})")
                    continue
                    
                prices = df["Close"].squeeze()
                latest_price = prices.iloc[-1]
                
                row = {
                    "Name": name,
                    "Ticker": ticker,
                    "Latest Price": latest_price
                }
                
                for label, index in LOOKBACK_DAYS.items():
                    if len(prices) >= abs(index):
                        past_price = prices.iloc[index]
                    else:
                        past_price = prices.iloc[0]
                    
                    row[label] = ((latest_price - past_price) / past_price) * 100
                    
                records.append(row)
                
            except Exception as e:
                print(f"[Error] Failed to process {name}: {e}")
        
        if records:
            df_performance = pd.DataFrame(records)
            
            # .applymap を使って騰落率の列（subset）だけにハイライトを適用
            styled_df = (df_performance.style
                         .format(format_config)
                         .map(highlight_extreme_values, subset=list(LOOKBACK_DAYS.keys()))
                         .hide(axis="index"))
            
            # Display formatted table for the current market
            display(styled_df)
        else:
            print("No data available for this market.")

# %%
# =====================================================================
# CONFIGURATION & EXECUTION (Segmented by Market)
# =====================================================================
MARKET_TICKERS = {
    "United States": {
        "S&P 500": "^GSPC",
        "NASDAQ Composite": "^IXIC",
        "Apple": "AAPL",
        "NVIDIA": "NVDA",
        "Microsoft": "MSFT",
    },
    "Japan": {
        "Nikkei 225": "^N225",
        "Toyota Motor": "7203.T",
        "Sony Group": "6758.T",
        "Mitsubishi UFJ Financial": "8306.T",
    },
    "Singapore": {
        "STI Index": "^STI",
        "DBS Group": "D05.SI",
        "UOB": "U11.SI",
        "Singtel": "Z74.SI",
        "CapitaLand Ascendas REIT": "A17U.SI",
    },
    "Japan Stock": {
        "小松製作所 (6301)": "6301.T",
        "ニデック (6594)": "6594.T",
        "未来工業 (7931)": "7931.T",
        "東部ネットワーク (9036)": "9036.T",
        "ニトリHD (9843)": "9843.T",
        "MRK HD (9980)": "9980.T",
    },
    "US Stock (ETF)": {
        "iシェアーズ コア米国総合債券ETF (AGG)": "AGG"
    }
}

# Run and display the segmented tables
show_market_performances(MARKET_TICKERS)
# Out:
# <h3 style='margin-top: 20px; color: #333;'>■ United States Market</h3>
# <style type="text/css">
# #T_1dc24_row4_col6, #T_1dc24_row4_col7, #T_1dc24_row4_col8 {
#   background-color: #cce5ff;
#   color: #004085;
#   font-weight: bold;
# }
# </style>
# <table id="T_1dc24">
#   <thead>
#     <tr>
#       <th id="T_1dc24_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_1dc24_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_1dc24_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_1dc24_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_1dc24_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_1dc24_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_1dc24_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_1dc24_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_1dc24_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1dc24_row0_col0" class="data row0 col0" >S&P 500</td>
#       <td id="T_1dc24_row0_col1" class="data row0 col1" >^GSPC</td>
#       <td id="T_1dc24_row0_col2" class="data row0 col2" >7,358.22</td>
#       <td id="T_1dc24_row0_col3" class="data row0 col3" >-0.10%</td>
#       <td id="T_1dc24_row0_col4" class="data row0 col4" >-1.90%</td>
#       <td id="T_1dc24_row0_col5" class="data row0 col5" >-2.04%</td>
#       <td id="T_1dc24_row0_col6" class="data row0 col6" >-2.14%</td>
#       <td id="T_1dc24_row0_col7" class="data row0 col7" >+2.57%</td>
#       <td id="T_1dc24_row0_col8" class="data row0 col8" >+2.57%</td>
#     </tr>
#     <tr>
#       <td id="T_1dc24_row1_col0" class="data row1 col0" >NASDAQ Composite</td>
#       <td id="T_1dc24_row1_col1" class="data row1 col1" >^IXIC</td>
#       <td id="T_1dc24_row1_col2" class="data row1 col2" >25,476.64</td>
#       <td id="T_1dc24_row1_col3" class="data row1 col3" >-0.43%</td>
#       <td id="T_1dc24_row1_col4" class="data row1 col4" >-3.93%</td>
#       <td id="T_1dc24_row1_col5" class="data row1 col5" >-3.41%</td>
#       <td id="T_1dc24_row1_col6" class="data row1 col6" >-4.43%</td>
#       <td id="T_1dc24_row1_col7" class="data row1 col7" >+2.37%</td>
#       <td id="T_1dc24_row1_col8" class="data row1 col8" >+2.37%</td>
#     </tr>
#     <tr>
#       <td id="T_1dc24_row2_col0" class="data row2 col0" >Apple</td>
#       <td id="T_1dc24_row2_col1" class="data row2 col1" >AAPL</td>
#       <td id="T_1dc24_row2_col2" class="data row2 col2" >293.08</td>
#       <td id="T_1dc24_row2_col3" class="data row2 col3" >-0.41%</td>
#       <td id="T_1dc24_row2_col4" class="data row2 col4" >-1.65%</td>
#       <td id="T_1dc24_row2_col5" class="data row2 col5" >-2.06%</td>
#       <td id="T_1dc24_row2_col6" class="data row2 col6" >-4.95%</td>
#       <td id="T_1dc24_row2_col7" class="data row2 col7" >+9.62%</td>
#       <td id="T_1dc24_row2_col8" class="data row2 col8" >+9.62%</td>
#     </tr>
#     <tr>
#       <td id="T_1dc24_row3_col0" class="data row3 col0" >NVIDIA</td>
#       <td id="T_1dc24_row3_col1" class="data row3 col1" >NVDA</td>
#       <td id="T_1dc24_row3_col2" class="data row3 col2" >199.00</td>
#       <td id="T_1dc24_row3_col3" class="data row3 col3" >-0.52%</td>
#       <td id="T_1dc24_row3_col4" class="data row3 col4" >-5.55%</td>
#       <td id="T_1dc24_row3_col5" class="data row3 col5" >-4.05%</td>
#       <td id="T_1dc24_row3_col6" class="data row3 col6" >-7.27%</td>
#       <td id="T_1dc24_row3_col7" class="data row3 col7" >-8.02%</td>
#       <td id="T_1dc24_row3_col8" class="data row3 col8" >-8.02%</td>
#     </tr>
#     <tr>
#       <td id="T_1dc24_row4_col0" class="data row4 col0" >Microsoft</td>
#       <td id="T_1dc24_row4_col1" class="data row4 col1" >MSFT</td>
#       <td id="T_1dc24_row4_col2" class="data row4 col2" >365.46</td>
#       <td id="T_1dc24_row4_col3" class="data row4 col3" >-2.27%</td>
#       <td id="T_1dc24_row4_col4" class="data row4 col4" >-3.67%</td>
#       <td id="T_1dc24_row4_col5" class="data row4 col5" >-7.20%</td>
#       <td id="T_1dc24_row4_col6" class="data row4 col6" >-12.16%</td>
#       <td id="T_1dc24_row4_col7" class="data row4 col7" >-13.79%</td>
#       <td id="T_1dc24_row4_col8" class="data row4 col8" >-13.79%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ Japan Market</h3>
# <style type="text/css">
# #T_24c50_row0_col7, #T_24c50_row0_col8, #T_24c50_row3_col7, #T_24c50_row3_col8 {
#   background-color: #ffcccc;
#   color: #cc0000;
#   font-weight: bold;
# }
# #T_24c50_row1_col6, #T_24c50_row1_col7, #T_24c50_row1_col8 {
#   background-color: #cce5ff;
#   color: #004085;
#   font-weight: bold;
# }
# </style>
# <table id="T_24c50">
#   <thead>
#     <tr>
#       <th id="T_24c50_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_24c50_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_24c50_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_24c50_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_24c50_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_24c50_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_24c50_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_24c50_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_24c50_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_24c50_row0_col0" class="data row0 col0" >Nikkei 225</td>
#       <td id="T_24c50_row0_col1" class="data row0 col1" >^N225</td>
#       <td id="T_24c50_row0_col2" class="data row0 col2" >69,174.97</td>
#       <td id="T_24c50_row0_col3" class="data row0 col3" >-0.88%</td>
#       <td id="T_24c50_row0_col4" class="data row0 col4" >-2.91%</td>
#       <td id="T_24c50_row0_col5" class="data row0 col5" >-1.04%</td>
#       <td id="T_24c50_row0_col6" class="data row0 col6" >+6.42%</td>
#       <td id="T_24c50_row0_col7" class="data row0 col7" >+14.27%</td>
#       <td id="T_24c50_row0_col8" class="data row0 col8" >+14.27%</td>
#     </tr>
#     <tr>
#       <td id="T_24c50_row1_col0" class="data row1 col0" >Toyota Motor</td>
#       <td id="T_24c50_row1_col1" class="data row1 col1" >7203.T</td>
#       <td id="T_24c50_row1_col2" class="data row1 col2" >2,686.00</td>
#       <td id="T_24c50_row1_col3" class="data row1 col3" >-0.74%</td>
#       <td id="T_24c50_row1_col4" class="data row1 col4" >-3.26%</td>
#       <td id="T_24c50_row1_col5" class="data row1 col5" >-4.41%</td>
#       <td id="T_24c50_row1_col6" class="data row1 col6" >-10.70%</td>
#       <td id="T_24c50_row1_col7" class="data row1 col7" >-12.42%</td>
#       <td id="T_24c50_row1_col8" class="data row1 col8" >-12.42%</td>
#     </tr>
#     <tr>
#       <td id="T_24c50_row2_col0" class="data row2 col0" >Sony Group</td>
#       <td id="T_24c50_row2_col1" class="data row2 col1" >6758.T</td>
#       <td id="T_24c50_row2_col2" class="data row2 col2" >3,250.00</td>
#       <td id="T_24c50_row2_col3" class="data row2 col3" >+2.88%</td>
#       <td id="T_24c50_row2_col4" class="data row2 col4" >+3.50%</td>
#       <td id="T_24c50_row2_col5" class="data row2 col5" >-1.10%</td>
#       <td id="T_24c50_row2_col6" class="data row2 col6" >-7.80%</td>
#       <td id="T_24c50_row2_col7" class="data row2 col7" >+1.94%</td>
#       <td id="T_24c50_row2_col8" class="data row2 col8" >+1.94%</td>
#     </tr>
#     <tr>
#       <td id="T_24c50_row3_col0" class="data row3 col0" >Mitsubishi UFJ Financial</td>
#       <td id="T_24c50_row3_col1" class="data row3 col1" >8306.T</td>
#       <td id="T_24c50_row3_col2" class="data row3 col2" >3,205.00</td>
#       <td id="T_24c50_row3_col3" class="data row3 col3" >-1.90%</td>
#       <td id="T_24c50_row3_col4" class="data row3 col4" >-2.23%</td>
#       <td id="T_24c50_row3_col5" class="data row3 col5" >-2.05%</td>
#       <td id="T_24c50_row3_col6" class="data row3 col6" >+5.74%</td>
#       <td id="T_24c50_row3_col7" class="data row3 col7" >+14.96%</td>
#       <td id="T_24c50_row3_col8" class="data row3 col8" >+14.96%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ Singapore Market</h3>
# <style type="text/css">
# #T_9ac59_row1_col7, #T_9ac59_row1_col8, #T_9ac59_row2_col7, #T_9ac59_row2_col8 {
#   background-color: #ffcccc;
#   color: #cc0000;
#   font-weight: bold;
# }
# </style>
# <table id="T_9ac59">
#   <thead>
#     <tr>
#       <th id="T_9ac59_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_9ac59_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_9ac59_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_9ac59_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_9ac59_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_9ac59_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_9ac59_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_9ac59_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_9ac59_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ac59_row0_col0" class="data row0 col0" >STI Index</td>
#       <td id="T_9ac59_row0_col1" class="data row0 col1" >^STI</td>
#       <td id="T_9ac59_row0_col2" class="data row0 col2" >5,215.99</td>
#       <td id="T_9ac59_row0_col3" class="data row0 col3" >+0.20%</td>
#       <td id="T_9ac59_row0_col4" class="data row0 col4" >+0.45%</td>
#       <td id="T_9ac59_row0_col5" class="data row0 col5" >+0.76%</td>
#       <td id="T_9ac59_row0_col6" class="data row0 col6" >+2.87%</td>
#       <td id="T_9ac59_row0_col7" class="data row0 col7" >+6.61%</td>
#       <td id="T_9ac59_row0_col8" class="data row0 col8" >+6.61%</td>
#     </tr>
#     <tr>
#       <td id="T_9ac59_row1_col0" class="data row1 col0" >DBS Group</td>
#       <td id="T_9ac59_row1_col1" class="data row1 col1" >D05.SI</td>
#       <td id="T_9ac59_row1_col2" class="data row1 col2" >66.22</td>
#       <td id="T_9ac59_row1_col3" class="data row1 col3" >-0.11%</td>
#       <td id="T_9ac59_row1_col4" class="data row1 col4" >+0.39%</td>
#       <td id="T_9ac59_row1_col5" class="data row1 col5" >+1.86%</td>
#       <td id="T_9ac59_row1_col6" class="data row1 col6" >+6.81%</td>
#       <td id="T_9ac59_row1_col7" class="data row1 col7" >+18.24%</td>
#       <td id="T_9ac59_row1_col8" class="data row1 col8" >+18.24%</td>
#     </tr>
#     <tr>
#       <td id="T_9ac59_row2_col0" class="data row2 col0" >UOB</td>
#       <td id="T_9ac59_row2_col1" class="data row2 col1" >U11.SI</td>
#       <td id="T_9ac59_row2_col2" class="data row2 col2" >39.90</td>
#       <td id="T_9ac59_row2_col3" class="data row2 col3" >+0.15%</td>
#       <td id="T_9ac59_row2_col4" class="data row2 col4" >+1.66%</td>
#       <td id="T_9ac59_row2_col5" class="data row2 col5" >+1.40%</td>
#       <td id="T_9ac59_row2_col6" class="data row2 col6" >+5.78%</td>
#       <td id="T_9ac59_row2_col7" class="data row2 col7" >+11.14%</td>
#       <td id="T_9ac59_row2_col8" class="data row2 col8" >+11.14%</td>
#     </tr>
#     <tr>
#       <td id="T_9ac59_row3_col0" class="data row3 col0" >Singtel</td>
#       <td id="T_9ac59_row3_col1" class="data row3 col1" >Z74.SI</td>
#       <td id="T_9ac59_row3_col2" class="data row3 col2" >4.41</td>
#       <td id="T_9ac59_row3_col3" class="data row3 col3" >+1.38%</td>
#       <td id="T_9ac59_row3_col4" class="data row3 col4" >+1.38%</td>
#       <td id="T_9ac59_row3_col5" class="data row3 col5" >+1.38%</td>
#       <td id="T_9ac59_row3_col6" class="data row3 col6" >-1.56%</td>
#       <td id="T_9ac59_row3_col7" class="data row3 col7" >-4.34%</td>
#       <td id="T_9ac59_row3_col8" class="data row3 col8" >-4.34%</td>
#     </tr>
#     <tr>
#       <td id="T_9ac59_row4_col0" class="data row4 col0" >CapitaLand Ascendas REIT</td>
#       <td id="T_9ac59_row4_col1" class="data row4 col1" >A17U.SI</td>
#       <td id="T_9ac59_row4_col2" class="data row4 col2" >2.53</td>
#       <td id="T_9ac59_row4_col3" class="data row4 col3" >+0.40%</td>
#       <td id="T_9ac59_row4_col4" class="data row4 col4" >+0.80%</td>
#       <td id="T_9ac59_row4_col5" class="data row4 col5" >-1.56%</td>
#       <td id="T_9ac59_row4_col6" class="data row4 col6" >+0.40%</td>
#       <td id="T_9ac59_row4_col7" class="data row4 col7" >-0.39%</td>
#       <td id="T_9ac59_row4_col8" class="data row4 col8" >-0.39%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ Japan Stock Market</h3>
# <style type="text/css">
# #T_64f06_row1_col7, #T_64f06_row1_col8 {
#   background-color: #ffcccc;
#   color: #cc0000;
#   font-weight: bold;
# }
# </style>
# <table id="T_64f06">
#   <thead>
#     <tr>
#       <th id="T_64f06_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_64f06_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_64f06_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_64f06_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_64f06_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_64f06_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_64f06_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_64f06_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_64f06_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_64f06_row0_col0" class="data row0 col0" >小松製作所 (6301)</td>
#       <td id="T_64f06_row0_col1" class="data row0 col1" >6301.T</td>
#       <td id="T_64f06_row0_col2" class="data row0 col2" >6,481.00</td>
#       <td id="T_64f06_row0_col3" class="data row0 col3" >-0.89%</td>
#       <td id="T_64f06_row0_col4" class="data row0 col4" >-0.17%</td>
#       <td id="T_64f06_row0_col5" class="data row0 col5" >-2.54%</td>
#       <td id="T_64f06_row0_col6" class="data row0 col6" >+0.08%</td>
#       <td id="T_64f06_row0_col7" class="data row0 col7" >-8.11%</td>
#       <td id="T_64f06_row0_col8" class="data row0 col8" >-8.11%</td>
#     </tr>
#     <tr>
#       <td id="T_64f06_row1_col0" class="data row1 col0" >ニデック (6594)</td>
#       <td id="T_64f06_row1_col1" class="data row1 col1" >6594.T</td>
#       <td id="T_64f06_row1_col2" class="data row1 col2" >2,750.00</td>
#       <td id="T_64f06_row1_col3" class="data row1 col3" >-1.40%</td>
#       <td id="T_64f06_row1_col4" class="data row1 col4" >+2.04%</td>
#       <td id="T_64f06_row1_col5" class="data row1 col5" >-1.65%</td>
#       <td id="T_64f06_row1_col6" class="data row1 col6" >+0.00%</td>
#       <td id="T_64f06_row1_col7" class="data row1 col7" >+12.34%</td>
#       <td id="T_64f06_row1_col8" class="data row1 col8" >+12.34%</td>
#     </tr>
#     <tr>
#       <td id="T_64f06_row2_col0" class="data row2 col0" >未来工業 (7931)</td>
#       <td id="T_64f06_row2_col1" class="data row2 col1" >7931.T</td>
#       <td id="T_64f06_row2_col2" class="data row2 col2" >3,010.00</td>
#       <td id="T_64f06_row2_col3" class="data row2 col3" >+0.33%</td>
#       <td id="T_64f06_row2_col4" class="data row2 col4" >+0.00%</td>
#       <td id="T_64f06_row2_col5" class="data row2 col5" >-1.79%</td>
#       <td id="T_64f06_row2_col6" class="data row2 col6" >-3.99%</td>
#       <td id="T_64f06_row2_col7" class="data row2 col7" >+1.90%</td>
#       <td id="T_64f06_row2_col8" class="data row2 col8" >+1.90%</td>
#     </tr>
#     <tr>
#       <td id="T_64f06_row3_col0" class="data row3 col0" >東部ネットワーク (9036)</td>
#       <td id="T_64f06_row3_col1" class="data row3 col1" >9036.T</td>
#       <td id="T_64f06_row3_col2" class="data row3 col2" >1,229.00</td>
#       <td id="T_64f06_row3_col3" class="data row3 col3" >-3.00%</td>
#       <td id="T_64f06_row3_col4" class="data row3 col4" >-0.57%</td>
#       <td id="T_64f06_row3_col5" class="data row3 col5" >+2.59%</td>
#       <td id="T_64f06_row3_col6" class="data row3 col6" >-8.96%</td>
#       <td id="T_64f06_row3_col7" class="data row3 col7" >+0.99%</td>
#       <td id="T_64f06_row3_col8" class="data row3 col8" >+0.99%</td>
#     </tr>
#     <tr>
#       <td id="T_64f06_row4_col0" class="data row4 col0" >ニトリHD (9843)</td>
#       <td id="T_64f06_row4_col1" class="data row4 col1" >9843.T</td>
#       <td id="T_64f06_row4_col2" class="data row4 col2" >2,369.50</td>
#       <td id="T_64f06_row4_col3" class="data row4 col3" >-0.46%</td>
#       <td id="T_64f06_row4_col4" class="data row4 col4" >+0.49%</td>
#       <td id="T_64f06_row4_col5" class="data row4 col5" >-8.39%</td>
#       <td id="T_64f06_row4_col6" class="data row4 col6" >-5.92%</td>
#       <td id="T_64f06_row4_col7" class="data row4 col7" >+4.54%</td>
#       <td id="T_64f06_row4_col8" class="data row4 col8" >+4.54%</td>
#     </tr>
#     <tr>
#       <td id="T_64f06_row5_col0" class="data row5 col0" >MRK HD (9980)</td>
#       <td id="T_64f06_row5_col1" class="data row5 col1" >9980.T</td>
#       <td id="T_64f06_row5_col2" class="data row5 col2" >91.00</td>
#       <td id="T_64f06_row5_col3" class="data row5 col3" >-2.15%</td>
#       <td id="T_64f06_row5_col4" class="data row5 col4" >-3.19%</td>
#       <td id="T_64f06_row5_col5" class="data row5 col5" >-5.21%</td>
#       <td id="T_64f06_row5_col6" class="data row5 col6" >-9.90%</td>
#       <td id="T_64f06_row5_col7" class="data row5 col7" >-9.00%</td>
#       <td id="T_64f06_row5_col8" class="data row5 col8" >-9.00%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ US Stock (ETF) Market</h3>
# <style type="text/css">
# </style>
# <table id="T_52f55">
#   <thead>
#     <tr>
#       <th id="T_52f55_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_52f55_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_52f55_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_52f55_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_52f55_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_52f55_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_52f55_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_52f55_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_52f55_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52f55_row0_col0" class="data row0 col0" >iシェアーズ コア米国総合債券ETF (AGG)</td>
#       <td id="T_52f55_row0_col1" class="data row0 col1" >AGG</td>
#       <td id="T_52f55_row0_col2" class="data row0 col2" >99.19</td>
#       <td id="T_52f55_row0_col3" class="data row0 col3" >+0.49%</td>
#       <td id="T_52f55_row0_col4" class="data row0 col4" >+0.29%</td>
#       <td id="T_52f55_row0_col5" class="data row0 col5" >+0.22%</td>
#       <td id="T_52f55_row0_col6" class="data row0 col6" >+0.81%</td>
#       <td id="T_52f55_row0_col7" class="data row0 col7" >+0.42%</td>
#       <td id="T_52f55_row0_col8" class="data row0 col8" >+0.42%</td>
#     </tr>
#   </tbody>
# </table>
