# %% [markdown]
# # setup

# %%
import site
import sys
from pathlib import Path
from IPython.display import Audio, display


# Specify the path to the site-packages of your preferred pyenv environment
pyenv_lib = Path(
    "~/.pyenv/versions/scripts-env/lib/python3.12/site-packages"
).expanduser()

if pyenv_lib.exists():
    sys.path.insert(0, str(pyenv_lib))
    print(f"Environment fixed to: {pyenv_lib}")
else:
    print("Error: Path not found. Please verify the environment name and Python version.")
# Out:
# Environment fixed to: /home/mrsmmori/.pyenv/versions/scripts-env/lib/python3.12/site-packages

# %%
from pathlib import Path
import sys
import os
scripts_dir = Path("~/scripts").expanduser()
sys.path.insert(0, str(scripts_dir))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # youtube download

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/interactive_dl.sh").expanduser()

    print(f"🎬 Starting download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)
# Out:
# 📥 Enter YouTube URL:  https://www.youtube.com/watch?v=RcGyVTAoXEU
# 🎬 Starting download...
# URL: https://www.youtube.com/watch?v=RcGyVTAoXEU
#
# --- Execution Log ---
# Preparing download with subtitles (English)...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RcGyVTAoXEU
# [youtube] RcGyVTAoXEU: Downloading webpage
# [youtube] RcGyVTAoXEU: Downloading android vr player API JSON
# [info] RcGyVTAoXEU: Downloading subtitles: en
# [info] RcGyVTAoXEU: Downloading 1 format(s): 399-sr+140
# [info] Writing video subtitles to: /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.en.vtt
# [download] Sleeping 2.00 seconds ...
# [download] Destination: /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.en.vtt
#
# [download]    1.00KiB at    2.36KiB/s (00:00:00)
# [download]    3.00KiB at    7.06KiB/s (00:00:00)
# [download]    7.00KiB at   16.41KiB/s (00:00:00)
# [download]   15.00KiB at   35.00KiB/s (00:00:00)
# [download]   19.82KiB at   45.96KiB/s (00:00:00)
# [download] 100% of   19.82KiB in 00:00:00 at 39.47KiB/s
# [SubtitlesConvertor] Converting subtitles
# Deleting original file /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.en.vtt (pass -k to keep)
# [download] Destination: /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.f399-sr.mp4
#
# [download]   0.0% of   88.42MiB at  293.45KiB/s ETA 05:09
# [download]   0.0% of   88.42MiB at  738.65KiB/s ETA 02:03
# [download]   0.0% of   88.42MiB at    1.24MiB/s ETA 01:11
# [download]   0.0% of   88.42MiB at    1.99MiB/s ETA 00:44
# [download]   0.0% of   88.42MiB at    3.46MiB/s ETA 00:25
# [download]   0.1% of   88.42MiB at    4.55MiB/s ETA 00:19
# [download]   0.1% of   88.42MiB at    6.64MiB/s ETA 00:13
# [download]   0.3% of   88.42MiB at    8.74MiB/s ETA 00:10
# [download]  71.0% of   13.41MiB at  Unknown B/s ETA Unknown
# [download]  71.0% of   13.41MiB at  Unknown B/s ETA Unknown
# [download]  71.0% of   13.41MiB at    3.34MiB/s ETA 00:01
# [download]  71.1% of   13.41MiB at    3.69MiB/s ETA 00:01
# [download]  71.2% of   13.41MiB at    5.71MiB/s ETA 00:00
# [download]  71.4% of   13.41MiB at    8.92MiB/s ETA 00:00
# [download]  71.9% of   13.41MiB at   12.37MiB/s ETA 00:00
# [download]  72.8% of   13.41MiB at   19.99MiB/s ETA 00:00
# [download]  74.7% of   13.41MiB at    1.14MiB/s ETA 00:02
# [download]  78.4% of   13.41MiB at    2.13MiB/s ETA 00:01
# [download]  85.9% of   13.41MiB at    3.03MiB/s ETA 00:00
# [download] 100.0% of   13.41MiB at    5.48MiB/s ETA 00:00
# [download] 100% of   13.41MiB in 00:00:01 at 8.12MiB/s
# [Merger] Merging formats into "/mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.mp4"
# Deleting original file /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.f140.m4a (pass -k to keep)
# Deleting original file /mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.f399-sr.mp4 (pass -k to keep)
# [EmbedSubtitle] Embedding subtitles in "/mnt/d/Youtube/How to Make Stress Your Friend ｜ Kelly McGonigal ｜-RcGyVTAoXEU.mp4"
# ✅ Download completed successfully.
#
# --- Standard Error / Warnings ---
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one

# %% [markdown]
# # scripts environment | main

# %% [markdown]
# ## translate_deepl_srt

# %%
import translate_deepl_srt
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
translate_deepl_srt.translate_srt(full_path)

# %% [markdown]
# ## srt_to_pro_epub

# %%
import srt_to_pro_epub 
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName: ")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
srt_to_pro_epub.convert(full_path, vertical=False)
# Out:
# Enter SRT FileName:  A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.en_Bilingual.srt
# プロ仕様のEPUBを出力しました: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.en_Bilingual.epub
# True

# %% [markdown]
# ## split_media

# %%
import split_media

base = '/mnt/d/Youtube/'

filename = ""
while not filename:
    filename = input("Enter SRT FileName: ").strip().strip('"').strip("'")

num_splits = input("Enter Number of Splits (Default is 3): ")

# 2. パスの結合と分割数の変換
full_path = os.path.join(base, filename)
num_splits = int(num_splits) if num_splits.strip() else 3

# 3. 実行
split_media.split_media_files([full_path], num_splits)
# Out:
# Enter SRT FileName:  A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.mp4
# Enter Number of Splits (Default is 3):  3
# >>> Starting process for: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.mp4
# Detected SRT: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.en_Bilingual.srt
# /home/mrsmmori/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/video/io/ffmpeg_reader.py:522: UserWarning: Subtitle stream parsing is not supported by moviepy and will be ignored
# ffmpeg output:
#
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:09:24.66, start: 0.000000, bitrate: 990 kb/s
#   Stream #0:0[0x1](und): Video: av1 (libdav1d) (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 1920x1080, 855 kb/s, SAR 1:1 DAR 16:9, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Subtitle: mov_text (tx3g / 0x67337874), 0 kb/s (default)
#       Metadata:
#         handler_name    : SubtitleHandler
# At least one output file must be specified
#
#   warnings.warn(
# --- Processing Part 1/3 (0.00s - 188.22s) ---
# Exporting video: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part1.mp4
# Saving subtitles: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part1.srt
#
# --- Processing Part 2/3 (188.22s - 376.44s) ---
# Exporting video: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part2.mp4
# Saving subtitles: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part2.srt
#
# --- Processing Part 3/3 (376.44s - 564.66s) ---
# Exporting video: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part3.mp4
# Saving subtitles: /mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part3.srt
#
# ==========================================
# Success! All files have been split and saved.
# ==========================================
# ['/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part1.mp4',
#  '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part1.srt',
#  '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part2.mp4',
#  '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part2.srt',
#  '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part3.mp4',
#  '/mnt/d/Youtube/A Simple Way to Break a Bad Habit ｜ Judson Brewer --moW9jvvMr4_part3.srt']

# %% [markdown]
# ## make_mp3

# %%
import make_mp3
make_mp3.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
# Out:
# Found 24 files. Processing...
# MoviePy - Writing audio in /mnt/d/Youtube/Movie_Pool_20260628_0000.mp3
# chunk:  75%|███████▌  | 171508/228640 [03:12<01:05, 875.16it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import make_mp3
# ----> 2 make_mp3.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
#
# File ~/scripts/make_mp3.py:40, in combine_audio_files(target_dir, output_dir)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:53, in requires_duration(func, clip, *args, **kwargs)
#      51     raise ValueError("Attribute 'duration' not set")
#      52 else:
# ---> 53     return func(clip, *args, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:102, in preprocess_args.<locals>.decor.<locals>.wrapper(func, *args, **kwargs)
#      90 new_args = [
#      91     (
#      92         preprocess_func(arg)
#    (...)     96     for (arg, name) in zip(args, argnames)
#      97 ]
#      98 new_kwargs = {
#      99     kwarg: preprocess_func(value) if kwarg in varnames else value
#     100     for (kwarg, value) in kwargs.items()
#     101 }
# --> 102 return func(*new_args, **new_kwargs)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/audio/AudioClip.py:258, in AudioClip.write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, logger)
#     251     except KeyError:
#     252         raise ValueError(
#     253             "MoviePy couldn't find the codec associated "
#     254             "with the filename. Provide the 'codec' "
#     255             "parameter in write_audiofile."
#     256         )
# --> 258 return ffmpeg_audiowrite(
#     259     self,
#     260     filename,
#     261     fps,
#     262     nbytes,
#     263     buffersize,
#     264     codec=codec,
#     265     bitrate=bitrate,
#     266     write_logfile=write_logfile,
#     267     ffmpeg_params=ffmpeg_params,
#     268     logger=logger,
#     269 )
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:53, in requires_duration(func, clip, *args, **kwargs)
#      51     raise ValueError("Attribute 'duration' not set")
#      52 else:
# ---> 53     return func(clip, *args, **kwargs)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/audio/io/ffmpeg_audiowriter.py:220, in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, ffmpeg_params, logger)
#     208 logger(message="MoviePy - Writing audio in %s" % filename)
#     209 writer = FFMPEG_AudioWriter(
#     210     filename,
#     211     fps,
#    (...)    217     ffmpeg_params=ffmpeg_params,
#     218 )
# --> 220 for chunk in clip.iter_chunks(
#     221     chunksize=buffersize, quantize=True, nbytes=nbytes, fps=fps, logger=logger
#     222 ):
#     223     writer.write_frames(chunk)
#     225 writer.close()
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/audio/AudioClip.py:112, in AudioClip.iter_chunks(self, chunksize, chunk_duration, fps, quantize, nbytes, logger)
#     110 assert size <= chunksize
#     111 timings = (1.0 / fps) * np.arange(positions[i], positions[i + 1])
# --> 112 yield self.to_soundarray(
#     113     timings, nbytes=nbytes, quantize=quantize, fps=fps, buffersize=chunksize
#     114 )
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:53, in requires_duration(func, clip, *args, **kwargs)
#      51     raise ValueError("Attribute 'duration' not set")
#      52 else:
# ---> 53     return func(clip, *args, **kwargs)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/audio/AudioClip.py:160, in AudioClip.to_soundarray(self, tt, fps, quantize, nbytes, buffersize)
#     151         tt = np.arange(0, self.duration, 1.0 / fps)
#     152 """
#     153 elif len(tt)> 1.5*buffersize:
#     154     nchunks = int(len(tt)/buffersize+1)
#    (...)    158                       for ttc in tt_chunks])
#     159 """
# --> 160 snd_array = self.get_frame(tt)
#     162 if quantize:
#     163     snd_array = np.maximum(-0.99, np.minimum(0.99, snd_array))
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:102, in preprocess_args.<locals>.decor.<locals>.wrapper(func, *args, **kwargs)
#      90 new_args = [
#      91     (
#      92         preprocess_func(arg)
#    (...)     96     for (arg, name) in zip(args, argnames)
#      97 ]
#      98 new_kwargs = {
#      99     kwarg: preprocess_func(value) if kwarg in varnames else value
#     100     for (kwarg, value) in kwargs.items()
#     101 }
# --> 102 return func(*new_args, **new_kwargs)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/Clip.py:87, in Clip.get_frame(self, t)
#      85         return frame
#      86 else:
# ---> 87     return self.frame_function(t)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/audio/AudioClip.py:407, in CompositeAudioClip.frame_function(self, t)
#     405 def frame_function(self, t):
#     406     """Renders a frame for the composition for the time ``t``."""
# --> 407     played_parts = [clip.is_playing(t) for clip in self.clips]
#     409     sounds = [
#     410         clip.get_frame(t - clip.start) * np.array([part]).T
#     411         for clip, part in zip(self.clips, played_parts)
#     412         if (part is not False)
#     413     ]
#     415     if isinstance(t, np.ndarray):
#
# File ~/.pyenv/versions/3.12.2/envs/notebooks-env/lib/python3.12/site-packages/decorator/__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/decorators.py:102, in preprocess_args.<locals>.decor.<locals>.wrapper(func, *args, **kwargs)
#      90 new_args = [
#      91     (
#      92         preprocess_func(arg)
#    (...)     96     for (arg, name) in zip(args, argnames)
#      97 ]
#      98 new_kwargs = {
#      99     kwarg: preprocess_func(value) if kwarg in varnames else value
#     100     for (kwarg, value) in kwargs.items()
#     101 }
# --> 102 return func(*new_args, **new_kwargs)
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/moviepy/Clip.py:579, in Clip.is_playing(self, t)
#     571 """If ``t`` is a time, returns true if t is between the start and the end
#     572 of the clip. ``t`` can be expressed in seconds (15.35), in (min, sec), in
#     573 (hour, min, sec), or as a string: '01:03:05.35'. If ``t`` is a numpy
#     574 array, returns False if none of the ``t`` is in the clip, else returns a
#     575 vector [b_1, b_2, b_3...] where b_i is true if tti is in the clip.
#     576 """
#     577 if isinstance(t, np.ndarray):
#     578     # is the whole list of t outside the clip ?
# --> 579     tmin, tmax = t.min(), t.max()
#     581     if (self.end is not None) and (tmin >= self.end):
#     582         return False
#
# File ~/.pyenv/versions/scripts-env/lib/python3.12/site-packages/numpy/_core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:
# chunk:  75%|███████▌  | 171522/228640 [03:27<01:05, 875.16it/s, now=None]

# %% [markdown]
# ## make_playlist

# %%
import make_playlist
make_playlist.generate_xspf("/mnt/d/Youtube/Movie_Pool")
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Movie_Pool.xspf
# '/mnt/d/Youtube/Movie_Pool.xspf'
