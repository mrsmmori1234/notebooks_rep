# %% [markdown]
# # youtube-env

# %%
! source ~/.pyenv/versions/3.12.2/envs/youtube-env/bin/activate && cd ~/youtube && ./update.sh
! source ~/.pyenv/versions/3.12.2/envs/youtube-env/bin/activate && cd ~/youtube && ./channel_mp4.sh
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ➡️ Latest 2 videos already downloaded. Skipping.
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# ...

# %%
! source ~/.pyenv/versions/3.12.2/envs/youtube-env/bin/activate && cd ~/youtube && ./backup.sh
# Out:
# Enumerating objects: 24, done.
# Counting objects: 100% (24/24), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (14/14), 5.06 KiB | 2.53 MiB/s, done.
# Total 14 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/mrsmmori1234/youtube_rep.git
#    faea8c8..41e389b  main -> main
# [main 37541d1] Jun 14
#  4 files changed, 103 insertions(+)
#  create mode 100755 clean_pip.sh
#  create mode 100755 freeze_pip.sh
