# %% [markdown]
# # Import

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.env_setup import init_analysis_env; init_analysis_env()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
#       3 import sys; sys.path.append('..')
# ----> 4 from src.env_setup import init_analysis_env; init_analysis_env()
#
# File ~/notebooks/notebooks/../src/env_setup.py:26, in init_analysis_env()
#      24 def init_analysis_env():
#      25     """Imports major libraries into the Notebook's global namespace"""
# ---> 26     import pandas as pd
#      27     import numpy as np
#      28     import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = load_local_data("Stock Screener Data*.csv*", na_values=['-'], dtype={'Code': str})
df.head()

# %%
! pip install pandas
# Out:
# Failed to reload module 'packaging.version' from file '/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/packaging/version.py'
# Traceback (most recent call last):
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 625, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 451, in update_generic
#     update(a, b)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 403, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 451, in update_generic
#     update(a, b)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 363, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __lt__() requires a code object with 1 free vars, not 0
# [autoreload of packaging.version failed: Traceback (most recent call last):
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 625, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 451, in update_generic
#     update(a, b)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 403, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 451, in update_generic
#     update(a, b)
#   File "/home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages/IPython/extensions/autoreload.py", line 363, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __lt__() requires a code object with 1 free vars, not 0
# ]
# Collecting pandas
#   Using cached pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mrsmmori/.pyenv/versions/notebooks-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
