# %% [markdown]
# # setup

# %%
import site
import sys
from pathlib import Path
from IPython.display import Audio, display
import importlib

# Specify the path to the site-packages of your preferred pyenv environment
pyenv_lib = Path(
    "~/.pyenv/versions/scripts-env/lib/python3.12/site-packages"
).expanduser()

if pyenv_lib.exists():
    sys.path.insert(0, str(pyenv_lib))
    print(f"Environment fixed to: {pyenv_lib}")
else:
    print("Error: Path not found. Please verify the environment name and Python version.")
# Out:
# Environment fixed to: /home/mrsmmori/.pyenv/versions/scripts-env/lib/python3.12/site-packages

# %%
from pathlib import Path
import sys
import os
scripts_dir = Path("~/scripts").expanduser()
sys.path.insert(0, str(scripts_dir))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # youtube environment

# %% [markdown]
# ## Standard Youtube Movie

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/interactive_dl.sh").expanduser()

    print(f"🎬 Starting download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)
# Out:
# 📥 Enter YouTube URL:  https://www.youtube.com/shorts/5mMWSxWHLyI
# 🎬 Starting download...
# URL: https://www.youtube.com/shorts/5mMWSxWHLyI
#
# --- Execution Log ---
# Preparing download with subtitles (English)...
# [youtube] Extracting URL: https://www.youtube.com/shorts/5mMWSxWHLyI
# [youtube] 5mMWSxWHLyI: Downloading webpage
# [youtube] 5mMWSxWHLyI: Downloading android vr player API JSON
# [info] 5mMWSxWHLyI: Downloading 1 format(s): 137+140
# [info] There are no subtitles for the requested languages
# [SubtitlesConvertor] There aren't any subtitles to convert
# [download] Destination: /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f137.mp4
#
# [download]   0.0% of    8.31MiB at   95.43KiB/s ETA 01:29
# [download]   0.0% of    8.31MiB at  253.44KiB/s ETA 00:33
# [download]   0.1% of    8.31MiB at  488.93KiB/s ETA 00:17
# [download]   0.2% of    8.31MiB at  847.87KiB/s ETA 00:10
# [download]   0.4% of    8.31MiB at    1.54MiB/s ETA 00:05
# [download]   0.7% of    8.31MiB at    2.77MiB/s ETA 00:02
# [download]   1.5% of    8.31MiB at    3.72MiB/s ETA 00:02
# [download]   3.0% of    8.31MiB at    5.75MiB/s ETA 00:01
# [download]   6.0% of    8.31MiB at    9.07MiB/s ETA 00:00
# [download]  12.0% of    8.31MiB at   12.22MiB/s ETA 00:00
# [download]  24.0% of    8.31MiB at   10.60MiB/s ETA 00:00
# [download]  48.1% of    8.31MiB at    5.80MiB/s ETA 00:00
# [download]  96.1% of    8.31MiB at    8.35MiB/s ETA 00:00
# [download] 100.0% of    8.31MiB at    8.66MiB/s ETA 00:00
# [download] 100% of    8.31MiB in 00:00:01 at 4.51MiB/s
# [download] Destination: /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f140.m4a
#
# [download]   0.1% of  885.01KiB at  243.74KiB/s ETA 00:03
# [download]   0.3% of  885.01KiB at  612.04KiB/s ETA 00:01
# [download]   0.8% of  885.01KiB at    1.07MiB/s ETA 00:00
# [download]   1.7% of  885.01KiB at    1.65MiB/s ETA 00:00
# [download]   3.5% of  885.01KiB at    2.82MiB/s ETA 00:00
# [download]   7.1% of  885.01KiB at    4.78MiB/s ETA 00:00
# [download]  14.4% of  885.01KiB at    7.99MiB/s ETA 00:00
# [download]  28.8% of  885.01KiB at   13.38MiB/s ETA 00:00
# [download]  57.7% of  885.01KiB at   15.56MiB/s ETA 00:00
# [download] 100.0% of  885.01KiB at   13.34MiB/s ETA 00:00
# [download] 100% of  885.01KiB in 00:00:00 at 1.57MiB/s
# [Merger] Merging formats into "/mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.mp4"
# Deleting original file /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f137.mp4 (pass -k to keep)
# Deleting original file /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f140.m4a (pass -k to keep)
# [EmbedSubtitle] There aren't any subtitles to embed
# ✅ Download completed successfully.
#
# --- Standard Error / Warnings ---
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one

# %% [markdown]
# ## Short Movie

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube Shorts / Channel URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/shorts_dl.sh").expanduser()

    print(f"🎬 Starting Shorts download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)

# %% [markdown]
# # scripts environment | main

# %% [markdown]
# ## translate_deepl_srt

# %%
import translate_deepl_srt
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)

translate_deepl_srt.translate_srt(full_path, target_lang="JA")

# %% [markdown]
# ## split_media

# %%
import split_media

base = '/mnt/d/Youtube/'

filename = ""
while not filename:
    filename = input("Enter .mp4 FileName: ").strip().strip('"').strip("'")

num_splits = input("Enter Number of Splits (Default is 3): ")

# 2. パスの結合と分割数の変換
full_path = os.path.join(base, filename)
num_splits = int(num_splits) if num_splits.strip() else 3

# 3. 実行
split_media.split_media_files([full_path], num_splits)

# Switching_Movie/
# Out:
# Enter .mp4 FileName:  Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.mp4
# Enter Number of Splits (Default is 3):  3
# >>> Starting process for: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.mp4
# Detected SRT: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.en.srt
#
# --- Processing Part 1/3 (0.00s - 189.70s) ---
# Exporting video: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part1.mp4
# Saving subtitles: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part1.srt
#
# --- Processing Part 2/3 (189.70s - 379.40s) ---
# Exporting video: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part2.mp4
# Saving subtitles: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part2.srt
#
# --- Processing Part 3/3 (379.40s - 569.10s) ---
# Exporting video: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part3.mp4
# Saving subtitles: /mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part3.srt
#
# ==========================================
# Success! All files have been split and saved.
# ==========================================
# ['/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part1.mp4',
#  '/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part1.srt',
#  '/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part2.mp4',
#  '/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part2.srt',
#  '/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part3.mp4',
#  '/mnt/d/Youtube/Switching_Movie/How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI_part3.srt']

# %% [markdown]
# ## make_playlist

# %%
import make_playlist
#make_playlist.generate_xspf("/mnt/d/Youtube/Movie_Pool")
#make_playlist.generate_xspf("/mnt/d/Youtube/Switching_Movie")
#make_playlist.generate_xspf("/mnt/d/Youtube/MontaEnglish/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/ドイツ語オンラインレッスン「Vollmond (フォルモント)」/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/BBC Learning English/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/AdviceWithErin/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/JForrest English/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/Learn English With TV Series/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/Rachel's English/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/Everyday Chinese/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/FluenDay_Japan/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/Luke Davidson/Shorts")
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Luke Davidson.xspf
# '/mnt/d/Youtube/Luke Davidson.xspf'

# %% [markdown]
# ## switch_subtitles

# %% [raw]
# import switch_subtitle
# switch_subtitle.switch_subtitles("ja")
#
# #witch_subtitle.switch_subtitles("en")

# %% [raw]
# import time
# import switch_subtitle
#
# # 初期設定（Trueなら最初は日本語、Falseなら英語からスタート）
# is_japanese = True
#
# print("Jupyter上で字幕の切り替えループを開始します。")
# print("停止するには、上部の『■ (Interrupt the kernel)』ボタンを押してください。\n")
#
# try:
#     while True:
#         # 言語の決定
#         lang = "ja" if is_japanese else "en"
#
#         # 実行ログの出力
#         current_time = time.strftime('%H:%M:%S')
#         print(f"[{current_time}] 字幕を '{lang}' に切り替えました。")
#
#         # 切り替え関数の実行
#         switch_subtitle.switch_subtitles(lang)
#
#         # フラグを反転（次回の言語を切り替える）
#         is_japanese = not is_japanese
#
#         # 3分（180秒）待機
#         time.sleep(30)
#
# except KeyboardInterrupt:
#     print("\n[STOP] カーネルが中断されました。ループを停止します。")

# %% [markdown]
# ## make_mp3

# %%
import make_mp3
make_mp3.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
# Out:
# Found 29 files. Processing...
# MoviePy - Writing audio in /mnt/d/Youtube/Movie_Pool_20260719_1202.mp3
# MoviePy - Done.
#
# Successfully created: /mnt/d/Youtube/Movie_Pool_20260719_1202.mp3
# '/mnt/d/Youtube/Movie_Pool_20260719_1202.mp3'

# %% [markdown]
# ## make_mp4

# %% [markdown]
# **Non Standard**
#
# ---
# - `https://www.youtube.com/@Leechanch` | Downloaded |  Chinese
# - `https://www.youtube.com/@MontaEnglish33` | Downloaded
# - `https://www.youtube.com/@LearnEnglishwithBobtheCanadian` | subscription is required
# - `https://www.youtube.com/@LearnEnglishWithTVSeries` | Downloaded
# - `https://www.youtube.com/@bbclearningenglish/` | Downloaded
# - `https://www.youtube.com/@POCEnglish` | Downloaded
# - `https://www.youtube.com/@AdviceWithErin` | Downloaded
# - `https://www.youtube.com/@JForrestEnglish` | Downloaded
# - `https://www.youtube.com/@LittleFoxChinese` | Downloaded
# - `https://www.youtube.com/@rachelsenglish` | Downloaded
# - `https://www.youtube.com/@EverydayChinese` | Downloaded
# - `https://www.youtube.com/@fluenday_jp` | ERROR: unable to open for writing: [Errno 36] File name too long: '/mnt/d/Youtube/FluenDay_Japan/Shorts/20231108 - 英語の勉強は退屈かな？でも映画を楽しみながら勉強すれば全然止まらないよ！🌟 #英語勉強 #英語  #英語学習 #英語リスニング #英会話  #shorts  #fluenday  #英語力 #映画 - u-3qKUg1Mto.f140.m4a.part'
# - `https://www.youtube.com/@yuuukun_eigo`
# - `https://www.youtube.com/@lukedavidson81` | Downloaded
#
# ---
# **standard format**

# %%
import make_mp4
importlib.reload(make_mp4)
#make_mp4.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
#make_mp4.generate_xspf("/mnt/d/Youtube/Switching_Movie")
### make_mp4.generate_xspf("/mnt/d/Youtube/MontaEnglish/Shorts") 
#make_mp4.generate_xspf("/mnt/d/Youtube/ドイツ語オンラインレッスン「Vollmond (フォルモント)」/Shorts")
make_mp4.main(["/mnt/d/Youtube/BBC Learning English/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/AdviceWithErin/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/JForrest English/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/Learn English With TV Series/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/Rachel's English/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/Everyday Chinese/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/FluenDay_Japan/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/Luke Davidson/Shorts"])
#make_mp4.main(["/mnt/d/Youtube/毎日中国語のかね/Shorts"])
# Out:
# Checking video specs for 322 files...
# Target Resolution: 360x640 (Found 258 matching files)
#
# Concatenating and normalizing 321 videos (Fast Encoding)...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [libdav1d @ 0x62b9d9f42400] libdav1d 0.9.2
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251231 - 4 expressions for New Year’s Day - E5FWvJg7ZZ4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:28.47, start: 0.000000, bitrate: 380 kb/s
#   Stream #0:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 247 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250411 - 🧑‍💼 5 business expressions for when there’s a problem #shorts - vof91j4fm5E.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:49.02, start: 0.000000, bitrate: 366 kb/s
#   Stream #1:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 232 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #1:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9d9f73a80] libdav1d 0.9.2
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260320 - When is glass countable？ #shorts - Zm8GNCdro4o.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:47.74, start: 0.000000, bitrate: 386 kb/s
#   Stream #2:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 253 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #2:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9d9fc7ac0] libdav1d 0.9.2
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260427 - 5 ways to say you’re angry 😡 #shorts - D46qtFPTjvo.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:12.77, start: 0.000000, bitrate: 400 kb/s
#   Stream #3:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 266 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #3:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da13c180] libdav1d 0.9.2
# Input #4, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240920 - How do you 🗣️ say ‘often’？ #shorts - DDVe9Sk9C4A.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:26.43, start: 0.000000, bitrate: 359 kb/s
#   Stream #4:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 227 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #4:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #5, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250113 - ‘I hope I can keep in mind this lesson’ – Fix this sentence! #shorts #english - dFz4j_y7gFg.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.42, start: 0.000000, bitrate: 429 kb/s
#   Stream #5:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 296 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #5:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9d9fa5b40] libdav1d 0.9.2
# Input #6, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260703 - How to count countable nouns #shorts #english - 2dhelyUSuYE.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:47.74, start: 0.000000, bitrate: 381 kb/s
#   Stream #6:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 248 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #6:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da0694c0] libdav1d 0.9.2
# Input #7, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251126 - 📱 8 phrases you need for video calls - J8vsP942pxs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:36.62, start: 0.000000, bitrate: 371 kb/s
#   Stream #7:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 238 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #7:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da0aecc0] libdav1d 0.9.2
# Input #8, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250723 - How do you say ✉️ ‘envelope’？ #shorts - UZEomtlk41o.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:18.21, start: 0.000000, bitrate: 406 kb/s
#   Stream #8:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 274 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #8:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da05e5c0] libdav1d 0.9.2
# Input #9, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251205 - ‘it’s time to go’ and ‘it’s time we went’ – what’s the difference？ #shorts - veZpeSHej1I.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:02.11, start: 0.000000, bitrate: 387 kb/s
#   Stream #9:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 254 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #9:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da152780] libdav1d 0.9.2
# Input #10, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260622 - 🗣️ How to say the English short vowel ⧸ʌ⧸ #shorts #english - 14w_lT_iMCI.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:36.06, start: 0.000000, bitrate: 262 kb/s
#   Stream #10:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 130 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #10:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da023180] libdav1d 0.9.2
# Input #11, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241108 - Pop! How to use ‘pop’ in spoken English - uSvvXS8qbag.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:59.65, start: 0.000000, bitrate: 310 kb/s
#   Stream #11:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 177 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #11:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da1b2f40] libdav1d 0.9.2
# Input #12, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241122 - How to learn NEW phrasal verbs - KQS6lYv-XNA.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.98, start: 0.000000, bitrate: 313 kb/s
#   Stream #12:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 180 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #12:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da20bf00] libdav1d 0.9.2
# Input #13, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260302 - English at the airport #english #shorts - 5P773n6aDoQ.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:48.44, start: 0.000000, bitrate: 374 kb/s
#   Stream #13:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 242 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #13:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da1c1680] libdav1d 0.9.2
# Input #14, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250604 - Talking about day trips #shorts - uIFDu5uzjxo.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:23.45, start: 0.000000, bitrate: 307 kb/s
#   Stream #14:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 174 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #14:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da263b40] libdav1d 0.9.2
# Input #15, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241206 - 'prefer’ or ‘would prefer’ or ‘would rather’？ - Xvj64oqNYl8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.63, start: 0.000000, bitrate: 349 kb/s
#   Stream #15:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 216 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #15:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da350000] libdav1d 0.9.2
# Input #16, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250609 - every day or everyday – what’s the difference？ #shorts - 5-EZFt1rjYI.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:56.77, start: 0.000000, bitrate: 318 kb/s
#   Stream #16:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 185 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #16:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #17, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240830 - ‘White means milky coffee, isn’t it？’ – Fix this sentence! #shorts - zaN3KB-Rqgs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:59.12, start: 0.000000, bitrate: 471 kb/s
#   Stream #17:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 338 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #17:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da2e6a80] libdav1d 0.9.2
# Input #18, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260720 - English for a doctor’s appointment #english #shorts - nG4PFZ13-fc.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:51.99, start: 0.000000, bitrate: 305 kb/s
#   Stream #18:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 172 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #18:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #19, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20230327 - Say this when you feel unwell 🤒🤢 #shorts - UXsT7vxxQkU.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:21.34, start: 0.000000, bitrate: 378 kb/s
#   Stream #19:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 245 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #19:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da4d2c00] libdav1d 0.9.2
# Input #20, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250331 - 3 meanings of ‘get through’ #shorts #education #english - j9CDSHxBnxs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:01.58, start: 0.000000, bitrate: 268 kb/s
#   Stream #20:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 135 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #20:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da32b140] libdav1d 0.9.2
# Input #21, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251114 - 🇺🇸 🇬🇧 American English and British English： vocabulary - g6NSB38JCqg.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:53.78, start: 0.000000, bitrate: 391 kb/s
#   Stream #21:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 258 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #21:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da57c680] libdav1d 0.9.2
# Input #22, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250507 - ‘arrive in’ Vs ‘arrive at’ Vs ‘arrive’ – what’s the difference？ #shorts - GhdGbxRXiAQ.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:37.83, start: 0.000000, bitrate: 432 kb/s
#   Stream #22:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 299 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #22:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da415a40] libdav1d 0.9.2
# Input #23, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250514 - How to describe a busy 🚊 train journey #shorts - 24SN7hY_3UU.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:19.06, start: 0.000000, bitrate: 365 kb/s
#   Stream #23:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 232 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #23:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da566340] libdav1d 0.9.2
# Input #24, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260330 - How to respond to compliments 🥰 #shorts - g8uDG73wSFg.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:27.21, start: 0.000000, bitrate: 425 kb/s
#   Stream #24:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 292 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #24:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da5357c0] libdav1d 0.9.2
# Input #25, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260522 - 👋 3 ways to politely end a conversation #shorts - s-s0KCAD5zs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:34.95, start: 0.000000, bitrate: 334 kb/s
#   Stream #25:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 200 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #25:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da575d00] libdav1d 0.9.2
# Input #26, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241106 - ‘in', 'on' or 'at'？ Do you know how to use these English words？ #shorts #prepositions - oBatJc1VZCE.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:41.87, start: 0.000000, bitrate: 421 kb/s
#   Stream #26:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 288 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #26:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da4237c0] libdav1d 0.9.2
# Input #27, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241127 - Don’t make these 3 mistakes with prepositions! #shorts - o-OT8g5n6jk.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:57.98, start: 0.000000, bitrate: 347 kb/s
#   Stream #27:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 214 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #27:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da637380] libdav1d 0.9.2
# Input #28, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260706 - 🥛 Don’t cry over spilt milk! Learn this English phrase! - n_Q-qcoMDuw.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:56.82, start: 0.000000, bitrate: 383 kb/s
#   Stream #28:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 250 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #28:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da5ceac0] libdav1d 0.9.2
# Input #29, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260626 - 🇺🇸 🇬🇧 American English or British English： vocabulary - bRqWGpF8EmQ.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:34.20, start: 0.000000, bitrate: 428 kb/s
#   Stream #29:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 295 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #29:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da3eff00] libdav1d 0.9.2
# Input #30, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251013 - American English and British English： clothes #shorts #vocabulary - SxrpdKN8jh8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:53.24, start: 0.000000, bitrate: 407 kb/s
#   Stream #30:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 274 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #30:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da5bf200] libdav1d 0.9.2
# Input #31, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250901 - ‘I have done’ and ‘I have been doing’ – what’s the difference？ #shorts #learnenglish - uXinD12IXDs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.58, start: 0.000000, bitrate: 368 kb/s
#   Stream #31:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 235 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #31:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da709540] libdav1d 0.9.2
# Input #32, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250818 - ‘I am totally agree’ – Fix this sentence! #shorts #english - X4wlL7XVKCQ.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:44.35, start: 0.000000, bitrate: 356 kb/s
#   Stream #32:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 224 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #32:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da6ad440] libdav1d 0.9.2
# Input #33, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250702 - 🗣️ Watch to the end： Can you understand fast speech？ #shorts - gKc0D9bLpF0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:49.30, start: 0.000000, bitrate: 399 kb/s
#   Stream #33:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 266 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #33:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da7b6780] libdav1d 0.9.2
# Input #34, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240902 - How do you say 🗓️ ‘schedule’？ #shorts - rIweLp5SjKI.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:29.77, start: 0.000000, bitrate: 349 kb/s
#   Stream #34:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 216 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #34:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da6b2900] libdav1d 0.9.2
# Input #35, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240705 - Can you understand fast, British conversation？ #shorts - rPt8cYJ5tFc.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.70, start: 0.000000, bitrate: 324 kb/s
#   Stream #35:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 191 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #35:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da77f400] libdav1d 0.9.2
# Input #36, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241213 - Words that sound the same - but have different meanings - isj_d9xWFEw.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:59.82, start: 0.000000, bitrate: 308 kb/s
#   Stream #36:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 175 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #36:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da780500] libdav1d 0.9.2
# Input #37, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260225 - The short vowel sound ⧸ɪ⧸ and the long vowel sound ⧸i：⧸ #shorts #english - rS_IgcSUipI.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:03.18, start: 0.000000, bitrate: 281 kb/s
#   Stream #37:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 148 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #37:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da84a240] libdav1d 0.9.2
# Input #38, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240624 - 4 phrasal verbs for relaxation #shorts - 9GT95P0B-AM.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:59.75, start: 0.000000, bitrate: 283 kb/s
#   Stream #38:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 150 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #38:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da8af280] libdav1d 0.9.2
# Input #39, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240508 - 🪑 Asking for a seat #shorts - f30UyWQfdWc.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:27.98, start: 0.000000, bitrate: 408 kb/s
#   Stream #39:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 275 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #39:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da88d680] libdav1d 0.9.2
# Input #40, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20260313 - Use 'just', 'already' and 'yet' correctly! - OHgz_Y3R_5I.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:55.78, start: 0.000000, bitrate: 411 kb/s
#   Stream #40:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 278 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #40:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #41, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240304 - 5 adjectives that are difficult to say #shorts - WCnwqu5Ecus.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:27.98, start: 0.000000, bitrate: 551 kb/s
#   Stream #41:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 418 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #41:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da95bec0] libdav1d 0.9.2
# Input #42, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20241021 - Inviting people out and replying to invitations #shorts - sc4T5xQr5-E.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:33.58, start: 0.000000, bitrate: 340 kb/s
#   Stream #42:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 207 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #42:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da8d7500] libdav1d 0.9.2
# Input #43, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250627 - ‘both’, ‘either’ and ‘neither’– what’s the difference？ #shorts - moOCSv71PAk.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:21.50, start: 0.000000, bitrate: 347 kb/s
#   Stream #43:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 214 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #43:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #44, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240607 - 🗣️ Fast British speech! #shorts - Jcdvxgzr3sY.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:58.91, start: 0.000000, bitrate: 609 kb/s
#   Stream #44:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 476 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #44:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9da99b9c0] libdav1d 0.9.2
# Input #45, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250106 - English synonym quiz #shorts #english #education - a6xT6LcVvu4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:28.93, start: 0.000000, bitrate: 330 kb/s
#   Stream #45:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 197 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #45:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9dac35fc0] libdav1d 0.9.2
# Input #46, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251027 - What’s the difference – ‘despite’ and ‘although’ #shorts #english - HjbomKOfAII.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:22.50, start: 0.000000, bitrate: 386 kb/s
#   Stream #46:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 253 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #46:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #47, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240819 - 5 things you can do with an office chair #shorts - kRvs2HQeTKs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:21.39, start: 0.000000, bitrate: 510 kb/s
#   Stream #47:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 377 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #47:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #48, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20240422 - 'happy' idioms– Idioms with George #shorts - yfwanhhtGns.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:51.18, start: 0.000000, bitrate: 574 kb/s
#   Stream #48:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 438 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #48:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #49, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20230320 - ❓ Quick Quiz： 'Been' or 'gone'？ #shorts #quiz - yjhEulC59bk.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:53.13, start: 0.000000, bitrate: 630 kb/s
#   Stream #49:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 497 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #49:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9daaca280] libdav1d 0.9.2
# Input #50, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20250407 - What does ‘slay’ mean？ - Mx-hfmEbRD4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:01:05.67, start: 0.000000, bitrate: 442 kb/s
#   Stream #50:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 360x640 [SAR 1:1 DAR 9:16], 309 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #50:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# [libdav1d @ 0x62b9dabf6780] libdav1d 0.9.2
# Input #51, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/d/Youtube/BBC Learning English/Shorts/20251124 - English at the supermarket #english #shorts - 2b-x6VYLHBU.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
# ...
#   Stream #124:1 (aac) -> aresample
#   Stream #125:0 (libdav1d) -> fps
#   Stream #125:1 (aac) -> aresample
#   Stream #126:0 (libdav1d) -> fps
#   Stream #126:1 (aac) -> aresample
#   Stream #127:0 (libdav1d) -> fps
#   Stream #127:1 (aac) -> aresample
#   Stream #128:0 (libdav1d) -> fps
#   Stream #128:1 (aac) -> aresample
#   Stream #129:0 (libdav1d) -> fps
#   Stream #129:1 (aac) -> aresample
#   Stream #130:0 (libdav1d) -> fps
#   Stream #130:1 (aac) -> aresample
#   Stream #131:0 (libdav1d) -> fps
#   Stream #131:1 (aac) -> aresample
#   Stream #132:0 (libdav1d) -> fps
#   Stream #132:1 (aac) -> aresample
#   Stream #133:0 (libdav1d) -> fps
#   Stream #133:1 (aac) -> aresample
#   Stream #134:0 (libdav1d) -> fps
#   Stream #134:1 (aac) -> aresample
#   Stream #135:0 (libdav1d) -> fps
#   Stream #135:1 (aac) -> aresample
#   Stream #136:0 (libdav1d) -> fps
#   Stream #136:1 (aac) -> aresample
#   Stream #137:0 (h264) -> fps
#   Stream #137:1 (aac) -> aresample
#   Stream #138:0 (libdav1d) -> fps
#   Stream #138:1 (aac) -> aresample
#   Stream #139:0 (libdav1d) -> fps
#   Stream #139:1 (aac) -> aresample
#   Stream #140:0 (libdav1d) -> fps
#   Stream #140:1 (aac) -> aresample
#   Stream #141:0 (libdav1d) -> fps
#   Stream #141:1 (aac) -> aresample
#   Stream #142:0 (libdav1d) -> fps
#   Stream #142:1 (aac) -> aresample
#   Stream #143:0 (libdav1d) -> fps
#   Stream #143:1 (aac) -> aresample
#   Stream #144:0 (libdav1d) -> fps
#   Stream #144:1 (aac) -> aresample
#   Stream #145:0 (libdav1d) -> fps
#   Stream #145:1 (aac) -> aresample
#   Stream #146:0 (libdav1d) -> fps
#   Stream #146:1 (aac) -> aresample
#   Stream #147:0 (libdav1d) -> fps
#   Stream #147:1 (aac) -> aresample
#   Stream #148:0 (libdav1d) -> fps
#   Stream #148:1 (aac) -> aresample
#   Stream #149:0 (libdav1d) -> fps
#   Stream #149:1 (aac) -> aresample
#   Stream #150:0 (libdav1d) -> fps
#   Stream #150:1 (aac) -> aresample
#   Stream #151:0 (libdav1d) -> fps
#   Stream #151:1 (aac) -> aresample
#   Stream #152:0 (libdav1d) -> fps
#   Stream #152:1 (aac) -> aresample
#   Stream #153:0 (libdav1d) -> fps
#   Stream #153:1 (aac) -> aresample
#   Stream #154:0 (libdav1d) -> fps
#   Stream #154:1 (aac) -> aresample
#   Stream #155:0 (h264) -> fps
#   Stream #155:1 (aac) -> aresample
#   Stream #156:0 (h264) -> fps
#   Stream #156:1 (aac) -> aresample
#   Stream #157:0 (h264) -> fps
#   Stream #157:1 (aac) -> aresample
#   Stream #158:0 (libdav1d) -> fps
#   Stream #158:1 (aac) -> aresample
#   Stream #159:0 (h264) -> fps
#   Stream #159:1 (aac) -> aresample
#   Stream #160:0 (libdav1d) -> fps
#   Stream #160:1 (aac) -> aresample
#   Stream #161:0 (libdav1d) -> fps
#   Stream #161:1 (aac) -> aresample
#   Stream #162:0 (libdav1d) -> fps
#   Stream #162:1 (aac) -> aresample
#   Stream #163:0 (libdav1d) -> fps
#   Stream #163:1 (aac) -> aresample
#   Stream #164:0 (libdav1d) -> fps
#   Stream #164:1 (aac) -> aresample
#   Stream #165:0 (libdav1d) -> fps
#   Stream #165:1 (aac) -> aresample
#   Stream #166:0 (libdav1d) -> fps
#   Stream #166:1 (aac) -> aresample
#   Stream #167:0 (libdav1d) -> fps
#   Stream #167:1 (aac) -> aresample
#   Stream #168:0 (libdav1d) -> fps
#   Stream #168:1 (aac) -> aresample
#   Stream #169:0 (libdav1d) -> fps
#   Stream #169:1 (aac) -> aresample
#   Stream #170:0 (h264) -> fps
#   Stream #170:1 (aac) -> aresample
#   Stream #171:0 (libdav1d) -> fps
#   Stream #171:1 (aac) -> aresample
#   Stream #172:0 (h264) -> fps
#   Stream #172:1 (aac) -> aresample
#   Stream #173:0 (libdav1d) -> fps
#   Stream #173:1 (aac) -> aresample
#   Stream #174:0 (libdav1d) -> fps
#   Stream #174:1 (aac) -> aresample
#   Stream #175:0 (h264) -> fps
#   Stream #175:1 (aac) -> aresample
#   Stream #176:0 (libdav1d) -> fps
#   Stream #176:1 (aac) -> aresample
#   Stream #177:0 (h264) -> fps
#   Stream #177:1 (aac) -> aresample
#   Stream #178:0 (libdav1d) -> fps
#   Stream #178:1 (aac) -> aresample
#   Stream #179:0 (libdav1d) -> fps
#   Stream #179:1 (aac) -> aresample
#   Stream #180:0 (libdav1d) -> fps
#   Stream #180:1 (aac) -> aresample
#   Stream #181:0 (h264) -> fps
#   Stream #181:1 (aac) -> aresample
#   Stream #182:0 (libdav1d) -> fps
#   Stream #182:1 (aac) -> aresample
#   Stream #183:0 (libdav1d) -> fps
#   Stream #183:1 (aac) -> aresample
#   Stream #184:0 (h264) -> fps
#   Stream #184:1 (aac) -> aresample
#   Stream #185:0 (libdav1d) -> fps
#   Stream #185:1 (aac) -> aresample
#   Stream #186:0 (libdav1d) -> fps
#   Stream #186:1 (aac) -> aresample
#   Stream #187:0 (libdav1d) -> fps
#   Stream #187:1 (aac) -> aresample
#   Stream #188:0 (libdav1d) -> fps
#   Stream #188:1 (aac) -> aresample
#   Stream #189:0 (h264) -> fps
#   Stream #189:1 (aac) -> aresample
#   Stream #190:0 (h264) -> fps
#   Stream #190:1 (aac) -> aresample
#   Stream #191:0 (h264) -> fps
#   Stream #191:1 (aac) -> aresample
#   Stream #192:0 (libdav1d) -> fps
#   Stream #192:1 (aac) -> aresample
#   Stream #193:0 (h264) -> fps
#   Stream #193:1 (aac) -> aresample
#   Stream #194:0 (h264) -> fps
#   Stream #194:1 (aac) -> aresample
#   Stream #195:0 (h264) -> fps
#   Stream #195:1 (aac) -> aresample
#   Stream #196:0 (libdav1d) -> fps
#   Stream #196:1 (aac) -> aresample
#   Stream #197:0 (libdav1d) -> fps
#   Stream #197:1 (aac) -> aresample
#   Stream #198:0 (libdav1d) -> fps
#   Stream #198:1 (aac) -> aresample
#   Stream #199:0 (h264) -> fps
#   Stream #199:1 (aac) -> aresample
#   Stream #200:0 (libdav1d) -> fps
#   Stream #200:1 (aac) -> aresample
#   Stream #201:0 (libdav1d) -> fps
#   Stream #201:1 (aac) -> aresample
#   Stream #202:0 (libdav1d) -> fps
#   Stream #202:1 (aac) -> aresample
#   Stream #203:0 (libdav1d) -> fps
#   Stream #203:1 (aac) -> aresample
#   Stream #204:0 (libdav1d) -> fps
#   Stream #204:1 (aac) -> aresample
#   Stream #205:0 (h264) -> fps
#   Stream #205:1 (aac) -> aresample
#   Stream #206:0 (libdav1d) -> fps
#   Stream #206:1 (aac) -> aresample
#   Stream #207:0 (libdav1d) -> fps
#   Stream #207:1 (aac) -> aresample
#   Stream #208:0 (libdav1d) -> fps
#   Stream #208:1 (aac) -> aresample
#   Stream #209:0 (libdav1d) -> fps
#   Stream #209:1 (aac) -> aresample
#   Stream #210:0 (libdav1d) -> fps
#   Stream #210:1 (aac) -> aresample
#   Stream #211:0 (libdav1d) -> fps
#   Stream #211:1 (aac) -> aresample
#   Stream #212:0 (libdav1d) -> fps
#   Stream #212:1 (aac) -> aresample
#   Stream #213:0 (libdav1d) -> fps
#   Stream #213:1 (aac) -> aresample
#   Stream #214:0 (libdav1d) -> fps
#   Stream #214:1 (aac) -> aresample
#   Stream #215:0 (libdav1d) -> fps
#   Stream #215:1 (aac) -> aresample
#   Stream #216:0 (libdav1d) -> fps
#   Stream #216:1 (aac) -> aresample
#   Stream #217:0 (h264) -> fps
#   Stream #217:1 (aac) -> aresample
#   Stream #218:0 (libdav1d) -> fps
#   Stream #218:1 (aac) -> aresample
#   Stream #219:0 (h264) -> fps
#   Stream #219:1 (aac) -> aresample
#   Stream #220:0 (libdav1d) -> fps
#   Stream #220:1 (aac) -> aresample
#   Stream #221:0 (libdav1d) -> fps
#   Stream #221:1 (aac) -> aresample
#   Stream #222:0 (libdav1d) -> fps
#   Stream #222:1 (aac) -> aresample
#   Stream #223:0 (h264) -> fps
#   Stream #223:1 (aac) -> aresample
#   Stream #224:0 (libdav1d) -> fps
#   Stream #224:1 (aac) -> aresample
#   Stream #225:0 (libdav1d) -> fps
#   Stream #225:1 (aac) -> aresample
#   Stream #226:0 (libdav1d) -> fps
#   Stream #226:1 (aac) -> aresample
#   Stream #227:0 (libdav1d) -> fps
#   Stream #227:1 (aac) -> aresample
#   Stream #228:0 (libdav1d) -> fps
#   Stream #228:1 (aac) -> aresample
#   Stream #229:0 (libdav1d) -> fps
#   Stream #229:1 (aac) -> aresample
#   Stream #230:0 (h264) -> fps
#   Stream #230:1 (aac) -> aresample
#   Stream #231:0 (libdav1d) -> fps
#   Stream #231:1 (aac) -> aresample
#   Stream #232:0 (libdav1d) -> fps
#   Stream #232:1 (aac) -> aresample
#   Stream #233:0 (libdav1d) -> fps
#   Stream #233:1 (aac) -> aresample
#   Stream #234:0 (libdav1d) -> fps
#   Stream #234:1 (aac) -> aresample
#   Stream #235:0 (libdav1d) -> fps
#   Stream #235:1 (aac) -> aresample
#   Stream #236:0 (libdav1d) -> fps
#   Stream #236:1 (aac) -> aresample
#   Stream #237:0 (libdav1d) -> fps
#   Stream #237:1 (aac) -> aresample
#   Stream #238:0 (libdav1d) -> fps
#   Stream #238:1 (aac) -> aresample
#   Stream #239:0 (libdav1d) -> fps
#   Stream #239:1 (aac) -> aresample
#   Stream #240:0 (libdav1d) -> fps
#   Stream #240:1 (aac) -> aresample
#   Stream #241:0 (libdav1d) -> fps
#   Stream #241:1 (aac) -> aresample
#   Stream #242:0 (libdav1d) -> fps
#   Stream #242:1 (aac) -> aresample
#   Stream #243:0 (libdav1d) -> fps
#   Stream #243:1 (aac) -> aresample
#   Stream #244:0 (libdav1d) -> fps
#   Stream #244:1 (aac) -> aresample
#   Stream #245:0 (libdav1d) -> fps
#   Stream #245:1 (aac) -> aresample
#   Stream #246:0 (libdav1d) -> fps
#   Stream #246:1 (aac) -> aresample
#   Stream #247:0 (libdav1d) -> fps
#   Stream #247:1 (aac) -> aresample
#   Stream #248:0 (libdav1d) -> fps
#   Stream #248:1 (aac) -> aresample
#   Stream #249:0 (h264) -> fps
#   Stream #249:1 (aac) -> aresample
#   Stream #250:0 (libdav1d) -> fps
#   Stream #250:1 (aac) -> aresample
#   Stream #251:0 (libdav1d) -> fps
#   Stream #251:1 (aac) -> aresample
#   Stream #252:0 (h264) -> fps
#   Stream #252:1 (aac) -> aresample
#   Stream #253:0 (libdav1d) -> fps
#   Stream #253:1 (aac) -> aresample
#   Stream #254:0 (libdav1d) -> fps
#   Stream #254:1 (aac) -> aresample
#   Stream #255:0 (libdav1d) -> fps
#   Stream #255:1 (aac) -> aresample
#   Stream #256:0 (libdav1d) -> fps
#   Stream #256:1 (aac) -> aresample
#   Stream #257:0 (libdav1d) -> fps
#   Stream #257:1 (aac) -> aresample
#   Stream #258:0 (libdav1d) -> fps
#   Stream #258:1 (aac) -> aresample
#   Stream #259:0 (h264) -> fps
#   Stream #259:1 (aac) -> aresample
#   Stream #260:0 (libdav1d) -> fps
#   Stream #260:1 (aac) -> aresample
#   Stream #261:0 (libdav1d) -> fps
#   Stream #261:1 (aac) -> aresample
#   Stream #262:0 (libdav1d) -> fps
#   Stream #262:1 (aac) -> aresample
#   Stream #263:0 (libdav1d) -> fps
#   Stream #263:1 (aac) -> aresample
#   Stream #264:0 (libdav1d) -> fps
#   Stream #264:1 (aac) -> aresample
#   Stream #265:0 (h264) -> fps
#   Stream #265:1 (aac) -> aresample
#   Stream #266:0 (libdav1d) -> fps
#   Stream #266:1 (aac) -> aresample
#   Stream #267:0 (libdav1d) -> fps
#   Stream #267:1 (aac) -> aresample
#   Stream #268:0 (libdav1d) -> fps
#   Stream #268:1 (aac) -> aresample
#   Stream #269:0 (h264) -> fps
#   Stream #269:1 (aac) -> aresample
#   Stream #270:0 (libdav1d) -> fps
#   Stream #270:1 (aac) -> aresample
#   Stream #271:0 (libdav1d) -> fps
#   Stream #271:1 (aac) -> aresample
#   Stream #272:0 (libdav1d) -> fps
#   Stream #272:1 (aac) -> aresample
#   Stream #273:0 (libdav1d) -> fps
#   Stream #273:1 (aac) -> aresample
#   Stream #274:0 (libdav1d) -> fps
#   Stream #274:1 (aac) -> aresample
#   Stream #275:0 (libdav1d) -> fps
#   Stream #275:1 (aac) -> aresample
#   Stream #276:0 (h264) -> fps
#   Stream #276:1 (aac) -> aresample
#   Stream #277:0 (libdav1d) -> fps
#   Stream #277:1 (aac) -> aresample
#   Stream #278:0 (libdav1d) -> fps
#   Stream #278:1 (aac) -> aresample
#   Stream #279:0 (libdav1d) -> fps
#   Stream #279:1 (aac) -> aresample
#   Stream #280:0 (libdav1d) -> fps
#   Stream #280:1 (aac) -> aresample
#   Stream #281:0 (libdav1d) -> fps
#   Stream #281:1 (aac) -> aresample
#   Stream #282:0 (libdav1d) -> fps
#   Stream #282:1 (aac) -> aresample
#   Stream #283:0 (libdav1d) -> fps
#   Stream #283:1 (aac) -> aresample
#   Stream #284:0 (libdav1d) -> fps
#   Stream #284:1 (aac) -> aresample
#   Stream #285:0 (libdav1d) -> fps
#   Stream #285:1 (aac) -> aresample
#   Stream #286:0 (libdav1d) -> fps
#   Stream #286:1 (aac) -> aresample
#   Stream #287:0 (h264) -> fps
#   Stream #287:1 (aac) -> aresample
#   Stream #288:0 (libdav1d) -> fps
#   Stream #288:1 (aac) -> aresample
#   Stream #289:0 (libdav1d) -> fps
#   Stream #289:1 (aac) -> aresample
#   Stream #290:0 (libdav1d) -> fps
#   Stream #290:1 (aac) -> aresample
#   Stream #291:0 (libdav1d) -> fps
#   Stream #291:1 (aac) -> aresample
#   Stream #292:0 (libdav1d) -> fps
#   Stream #292:1 (aac) -> aresample
#   Stream #293:0 (libdav1d) -> fps
#   Stream #293:1 (aac) -> aresample
#   Stream #294:0 (libdav1d) -> fps
#   Stream #294:1 (aac) -> aresample
#   Stream #295:0 (libdav1d) -> fps
#   Stream #295:1 (aac) -> aresample
#   Stream #296:0 (libdav1d) -> fps
#   Stream #296:1 (aac) -> aresample
#   Stream #297:0 (libdav1d) -> fps
#   Stream #297:1 (aac) -> aresample
#   Stream #298:0 (libdav1d) -> fps
#   Stream #298:1 (aac) -> aresample
#   Stream #299:0 (libdav1d) -> fps
#   Stream #299:1 (aac) -> aresample
#   Stream #300:0 (h264) -> fps
#   Stream #300:1 (aac) -> aresample
#   Stream #301:0 (libdav1d) -> fps
#   Stream #301:1 (aac) -> aresample
#   Stream #302:0 (libdav1d) -> fps
#   Stream #302:1 (aac) -> aresample
#   Stream #303:0 (h264) -> fps
#   Stream #303:1 (aac) -> aresample
#   Stream #304:0 (libdav1d) -> fps
#   Stream #304:1 (aac) -> aresample
#   Stream #305:0 (libdav1d) -> fps
#   Stream #305:1 (aac) -> aresample
#   Stream #306:0 (libdav1d) -> fps
#   Stream #306:1 (aac) -> aresample
#   Stream #307:0 (libdav1d) -> fps
#   Stream #307:1 (aac) -> aresample
#   Stream #308:0 (libdav1d) -> fps
#   Stream #308:1 (aac) -> aresample
#   Stream #309:0 (h264) -> fps
#   Stream #309:1 (aac) -> aresample
#   Stream #310:0 (libdav1d) -> fps
#   Stream #310:1 (aac) -> aresample
#   Stream #311:0 (h264) -> fps
#   Stream #311:1 (aac) -> aresample
#   Stream #312:0 (libdav1d) -> fps
#   Stream #312:1 (aac) -> aresample
#   Stream #313:0 (h264) -> fps
#   Stream #313:1 (aac) -> aresample
#   Stream #314:0 (libdav1d) -> fps
#   Stream #314:1 (aac) -> aresample
#   Stream #315:0 (libdav1d) -> fps
#   Stream #315:1 (aac) -> aresample
#   Stream #316:0 (libdav1d) -> fps
#   Stream #316:1 (aac) -> aresample
#   Stream #317:0 (h264) -> fps
#   Stream #317:1 (aac) -> aresample
#   Stream #318:0 (h264) -> fps
#   Stream #318:1 (aac) -> aresample
#   Stream #319:0 (libdav1d) -> fps
#   Stream #319:1 (aac) -> aresample
#   Stream #320:0 (libdav1d) -> fps
#   Stream #320:1 (aac) -> aresample
#   concat:out:v0 -> Stream #0:0 (libx264)
#   concat:out:a0 -> Stream #0:1 (aac)
# Press [q] to stop, [?] for help
# [libx264 @ 0x62b9e26ce7c0] using SAR=1/1
# [libx264 @ 0x62b9e26ce7c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x62b9e26ce7c0] profile Constrained Baseline, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x62b9e26ce7c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=0 ref=1 deblock=0:0:0 analyse=0:0 me=dia subme=0 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=0 keyint=250 keyint_min=25 scenecut=0 intra_refresh=0 rc=crf mbtree=0 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=0
# Output #0, mp4, to '/mnt/d/Youtube/BBC Learning English.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 360x640 [SAR 1:1 DAR 9:16], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 192 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# [mp4 @ 0x62b9e0990f40] Starting second pass: moving the moov atom to the beginning of the filep=0 speed=16.8x
# frame=491705 fps=461 q=-1.0 Lsize= 4306578kB time=04:33:10.22 bitrate=2152.5kbits/s dup=559 drop=0 speed=15.4x
# video:3899905kB audio:389267kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.405826%
# [libx264 @ 0x62b9e26ce7c0] frame I:1967  Avg QP:18.99  size: 51570
# [libx264 @ 0x62b9e26ce7c0] frame P:489738 Avg QP:21.95  size:  7947
# [libx264 @ 0x62b9e26ce7c0] mb I  I16..4: 100.0%  0.0%  0.0%
# [libx264 @ 0x62b9e26ce7c0] mb P  I16..4:  2.5%  0.0%  0.0%  P16..4: 41.9%  0.0%  0.0%  0.0%  0.0%    skip:55.5%
# [libx264 @ 0x62b9e26ce7c0] coded y,uvDC,uvAC intra: 52.5% 48.7% 23.0% inter: 27.1% 12.9% 2.5%
# [libx264 @ 0x62b9e26ce7c0] i16 v,h,dc,p: 41% 25% 17% 17%
# [libx264 @ 0x62b9e26ce7c0] i8c dc,h,v,p: 37% 24% 29% 10%
# [libx264 @ 0x62b9e26ce7c0] kb/s:1949.22
# [aac @ 0x62b9df1f2140] Qavg: 4828.872
# ✅ Successfully created 100% clean MP4: /mnt/d/Youtube/BBC Learning English.mp4
# 0

# %% [markdown]
# ## srt_to_pro_epub

# %%
import srt_to_pro_epub 
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName: ")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
srt_to_pro_epub.convert(full_path, vertical=False)
# Out:
# Enter SRT FileName:  Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.srt
# Output professional-grade EPUB: /mnt/d/Youtube/Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.epub
# True
