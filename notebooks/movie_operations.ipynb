# %% [markdown]
# # setup

# %%
import site
import sys
from pathlib import Path
from IPython.display import Audio, display


# Specify the path to the site-packages of your preferred pyenv environment
pyenv_lib = Path(
    "~/.pyenv/versions/scripts-env/lib/python3.12/site-packages"
).expanduser()

if pyenv_lib.exists():
    sys.path.insert(0, str(pyenv_lib))
    print(f"Environment fixed to: {pyenv_lib}")
else:
    print("Error: Path not found. Please verify the environment name and Python version.")
# Out:
# Environment fixed to: /home/mrsmmori/.pyenv/versions/scripts-env/lib/python3.12/site-packages

# %%
from pathlib import Path
import sys
import os
scripts_dir = Path("~/scripts").expanduser()
sys.path.insert(0, str(scripts_dir))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # youtube download

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/interactive_dl.sh").expanduser()

    print(f"🎬 Starting download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)
# Out:
# 📥 Enter YouTube URL:  https://www.youtube.com/watch?v=FqlNhe8a_sM
# 🎬 Starting download...
# URL: https://www.youtube.com/watch?v=FqlNhe8a_sM
#
# --- Execution Log ---
# Preparing download with subtitles (English)...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FqlNhe8a_sM
# [youtube] FqlNhe8a_sM: Downloading webpage
# [youtube] FqlNhe8a_sM: Downloading android vr player API JSON
# [info] FqlNhe8a_sM: Downloading subtitles: en
# [info] FqlNhe8a_sM: Downloading 1 format(s): 399+140
# [info] Writing video subtitles to: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.en.vtt
# [download] Sleeping 2.00 seconds ...
# [download] Destination: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.en.vtt
#
# [download]    1.00KiB at  241.00KiB/s (00:00:00)
# [download]    3.00KiB at  606.81KiB/s (00:00:00)
# [download]    7.00KiB at    1.02MiB/s (00:00:00)
# [download]   15.00KiB at    1.66MiB/s (00:00:00)
# [download]   26.28KiB at    2.26MiB/s (00:00:00)
# [download] 100% of   26.28KiB in 00:00:00 at 215.42KiB/s
# [SubtitlesConvertor] Converting subtitles
# Deleting original file /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.en.vtt (pass -k to keep)
# [download] Destination: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.f399.mp4
#
# [download]   0.0% of   59.32MiB at  239.51KiB/s ETA 04:14
# [download]   0.0% of   59.32MiB at  604.11KiB/s ETA 01:40
# [download]   0.0% of   59.32MiB at    1.06MiB/s ETA 00:56
# [download]   0.0% of   59.32MiB at    1.66MiB/s ETA 00:35
# [download]   0.1% of   59.32MiB at    2.85MiB/s ETA 00:20
# [download]   0.1% of   59.32MiB at    3.91MiB/s ETA 00:15
# [download]   0.2% of   59.32MiB at    5.42MiB/s ETA 00:10
# [download]   0.4% of   59.32MiB at    7.67MiB/s ETA 00:07
# [download]   0.8% of   59.32MiB at   10.54MiB/s ETA 00:05
# [download]   1.7% of   59.32MiB at   14.45MiB/s ETA 00:04
# [download]   3.4% of   59.32MiB at   18.38MiB/s ETA 00:03
# [download]   6.7% of   59.32MiB at   21.80MiB/s ETA 00:02
# [download]  13.5% of   59.32MiB at   11.32MiB/s ETA 00:04
# [download]  16.3% of   59.32MiB at   12.10MiB/s ETA 00:04
# [download]  16.3% of   59.32MiB at  Unknown B/s ETA Unknown
# [download]
# [download]  67.3% of   14.91MiB at   11.54MiB/s ETA 00:00
# [download]  68.1% of   14.91MiB at   17.79MiB/s ETA 00:00
# [download]  69.8% of   14.91MiB at   26.32MiB/s ETA 00:00
# [download]  73.1% of   14.91MiB at   25.83MiB/s ETA 00:00
# [download]  79.8% of   14.91MiB at   27.64MiB/s ETA 00:00
# [download]  93.3% of   14.91MiB at    1.99MiB/s ETA 00:00
# [download] 100.0% of   14.91MiB at    2.28MiB/s ETA 00:00
# [download] 100% of   14.91MiB in 00:00:05 at 2.70MiB/s
# [Merger] Merging formats into "/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.mp4"
# Deleting original file /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.f140.m4a (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.f399.mp4 (pass -k to keep)
# [EmbedSubtitle] Embedding subtitles in "/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.mp4"
# ✅ Download completed successfully.
#
# --- Standard Error / Warnings ---
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one

# %% [markdown]
# # scripts environment | main

# %% [markdown]
# ## translate_deepl_srt

# %%
import translate_deepl_srt
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
translate_deepl_srt.translate_srt(full_path)

# %% [markdown]
# ## srt_to_pro_epub

# %%
import srt_to_pro_epub 
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName: ")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
srt_to_pro_epub.convert(full_path, vertical=False)
# Out:
# Enter SRT FileName:  Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.srt
# Output professional-grade EPUB: /mnt/d/Youtube/Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.epub
# True

# %% [markdown]
# ## split_media

# %%
import split_media

base = '/mnt/d/Youtube/'

filename = ""
while not filename:
    filename = input("Enter SRT FileName: ").strip().strip('"').strip("'")

num_splits = input("Enter Number of Splits (Default is 3): ")

# 2. パスの結合と分割数の変換
full_path = os.path.join(base, filename)
num_splits = int(num_splits) if num_splits.strip() else 3

# 3. 実行
split_media.split_media_files([full_path], num_splits)
# Out:
# Enter SRT FileName:  Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.mp4
# Enter Number of Splits (Default is 3):  3
# >>> Starting process for: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.mp4
# Detected SRT: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM.en.srt
#
# --- Processing Part 1/3 (0.00s - 322.05s) ---
# Exporting video: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part1.mp4
# Saving subtitles: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part1.srt
#
# --- Processing Part 2/3 (322.05s - 644.11s) ---
# Exporting video: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part2.mp4
# Saving subtitles: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part2.srt
#
# --- Processing Part 3/3 (644.11s - 966.16s) ---
# Exporting video: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part3.mp4
# Saving subtitles: /mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part3.srt
#
# ==========================================
# Success! All files have been split and saved.
# ==========================================
# ['/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part1.mp4',
#  '/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part1.srt',
#  '/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part2.mp4',
#  '/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part2.srt',
#  '/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part3.mp4',
#  '/mnt/d/Youtube/Our next 20 years： AI, capitalism, and fractal min-FqlNhe8a_sM_part3.srt']

# %% [markdown]
# ## make_mp3

# %%
import make_mp3
make_mp3.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
# Out:
# Found 28 files. Processing...
# MoviePy - Writing audio in /mnt/d/Youtube/Movie_Pool_20260712_1206.mp3
# MoviePy - Done.
#
# Successfully created: /mnt/d/Youtube/Movie_Pool_20260712_1206.mp3
# '/mnt/d/Youtube/Movie_Pool_20260712_1206.mp3'

# %% [markdown]
# ## make_playlist

# %%
import make_playlist
make_playlist.generate_xspf("/mnt/d/Youtube/Movie_Pool")
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Movie_Pool.xspf
# '/mnt/d/Youtube/Movie_Pool.xspf'
