# %% [markdown]
# # setup

# %%
import site
import sys
from pathlib import Path
from IPython.display import Audio, display


# Specify the path to the site-packages of your preferred pyenv environment
pyenv_lib = Path(
    "~/.pyenv/versions/scripts-env/lib/python3.12/site-packages"
).expanduser()

if pyenv_lib.exists():
    sys.path.insert(0, str(pyenv_lib))
    print(f"Environment fixed to: {pyenv_lib}")
else:
    print("Error: Path not found. Please verify the environment name and Python version.")
# Out:
# Environment fixed to: /home/mrsmmori/.pyenv/versions/scripts-env/lib/python3.12/site-packages

# %%
from pathlib import Path
import sys
import os
scripts_dir = Path("~/scripts").expanduser()
sys.path.insert(0, str(scripts_dir))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # youtube environment

# %% [markdown]
# ## Standard Youtube Movie

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/interactive_dl.sh").expanduser()

    print(f"🎬 Starting download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)
# Out:
# 📥 Enter YouTube URL:  https://www.youtube.com/shorts/5mMWSxWHLyI
# 🎬 Starting download...
# URL: https://www.youtube.com/shorts/5mMWSxWHLyI
#
# --- Execution Log ---
# Preparing download with subtitles (English)...
# [youtube] Extracting URL: https://www.youtube.com/shorts/5mMWSxWHLyI
# [youtube] 5mMWSxWHLyI: Downloading webpage
# [youtube] 5mMWSxWHLyI: Downloading android vr player API JSON
# [info] 5mMWSxWHLyI: Downloading 1 format(s): 137+140
# [info] There are no subtitles for the requested languages
# [SubtitlesConvertor] There aren't any subtitles to convert
# [download] Destination: /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f137.mp4
#
# [download]   0.0% of    8.31MiB at   95.43KiB/s ETA 01:29
# [download]   0.0% of    8.31MiB at  253.44KiB/s ETA 00:33
# [download]   0.1% of    8.31MiB at  488.93KiB/s ETA 00:17
# [download]   0.2% of    8.31MiB at  847.87KiB/s ETA 00:10
# [download]   0.4% of    8.31MiB at    1.54MiB/s ETA 00:05
# [download]   0.7% of    8.31MiB at    2.77MiB/s ETA 00:02
# [download]   1.5% of    8.31MiB at    3.72MiB/s ETA 00:02
# [download]   3.0% of    8.31MiB at    5.75MiB/s ETA 00:01
# [download]   6.0% of    8.31MiB at    9.07MiB/s ETA 00:00
# [download]  12.0% of    8.31MiB at   12.22MiB/s ETA 00:00
# [download]  24.0% of    8.31MiB at   10.60MiB/s ETA 00:00
# [download]  48.1% of    8.31MiB at    5.80MiB/s ETA 00:00
# [download]  96.1% of    8.31MiB at    8.35MiB/s ETA 00:00
# [download] 100.0% of    8.31MiB at    8.66MiB/s ETA 00:00
# [download] 100% of    8.31MiB in 00:00:01 at 4.51MiB/s
# [download] Destination: /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f140.m4a
#
# [download]   0.1% of  885.01KiB at  243.74KiB/s ETA 00:03
# [download]   0.3% of  885.01KiB at  612.04KiB/s ETA 00:01
# [download]   0.8% of  885.01KiB at    1.07MiB/s ETA 00:00
# [download]   1.7% of  885.01KiB at    1.65MiB/s ETA 00:00
# [download]   3.5% of  885.01KiB at    2.82MiB/s ETA 00:00
# [download]   7.1% of  885.01KiB at    4.78MiB/s ETA 00:00
# [download]  14.4% of  885.01KiB at    7.99MiB/s ETA 00:00
# [download]  28.8% of  885.01KiB at   13.38MiB/s ETA 00:00
# [download]  57.7% of  885.01KiB at   15.56MiB/s ETA 00:00
# [download] 100.0% of  885.01KiB at   13.34MiB/s ETA 00:00
# [download] 100% of  885.01KiB in 00:00:00 at 1.57MiB/s
# [Merger] Merging formats into "/mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.mp4"
# Deleting original file /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f137.mp4 (pass -k to keep)
# Deleting original file /mnt/d/Youtube/ネイティブがよく使うフレーズ5選｜褒め言葉篇#hsk1級 #hsk2級 #hsk3級#中国語発音#s-5mMWSxWHLyI.f140.m4a (pass -k to keep)
# [EmbedSubtitle] There aren't any subtitles to embed
# ✅ Download completed successfully.
#
# --- Standard Error / Warnings ---
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one

# %% [markdown]
# ## Short Movie

# %%
import subprocess
from pathlib import Path
import os

# 1. Display an interactive popup box to input the URL
url = input("📥 Enter YouTube Shorts / Channel URL: ").strip()

if not url:
    print("❌ Error: No URL provided. Process aborted.")
else:
    # 2. Resolve the script path (automatically expands '~')
    script_path = Path("~/youtube/shorts_dl.sh").expanduser()

    print(f"🎬 Starting Shorts download... \nURL: {url}\n")

    # 3. Execute the shell script with the URL as an argument
    # Using shell=True ensures your current virtual environment path is preserved
    result = subprocess.run(
        f"bash {script_path} '{url}'", shell=True, capture_output=True, text=True
    )

    # 4. Display the execution logs
    print("--- Execution Log ---")
    print(result.stdout)

    if result.stderr:
        print("--- Standard Error / Warnings ---")
        print(result.stderr)
# Out:
# 📥 Enter YouTube Shorts / Channel URL:  https://www.youtube.com/@Leechanch
# 🎬 Starting Shorts download...
# URL: https://www.youtube.com/@Leechanch
#
# --- Execution Log ---
# [youtube:tab] Extracting URL: https://www.youtube.com/@Leechanch
# [youtube:tab] @Leechanch: Downloading webpage
# [youtube:tab] Downloading all uploads of the channel. To download only the videos in a specific tab, pass the tab's URL
# [youtube:tab] @Leechanch/streams: Downloading webpage
# [youtube:tab] @Leechanch/shorts: Downloading webpage
# [youtube:tab] Downloading as multiple playlists, separated by tabs. To download as a single playlist instead, pass https://www.youtube.com/playlist?list=UU3-VNyJabIi3cmCjCJPB93w
# [download] Downloading playlist: 李先生の楽しい中国語塾
# [youtube:tab] Playlist 李先生の楽しい中国語塾: Downloading 3 items of 3
# [download] Downloading item 1 of 3
# [download] Downloading playlist: 李先生の楽しい中国語塾 - Videos
# [youtube:tab] Playlist 李先生の楽しい中国語塾 - Videos: Downloading 14 items of 14
# [download] Downloading item 1 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CwOd2ykmr6I
# [youtube] CwOd2ykmr6I: Downloading webpage
# [youtube] CwOd2ykmr6I: Downloading android vr player API JSON
# [download] Lesson 03｜ホテルでのチェックイン・チェックアウト does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 2 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rZZp-cmCfK4
# [youtube] rZZp-cmCfK4: Downloading webpage
# [youtube] rZZp-cmCfK4: Downloading android vr player API JSON
# [download] 【中国語初心者必見】超便利でよく使われる20の必須フレーズ does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 3 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=waUM5tg_lko
# [youtube] waUM5tg_lko: Downloading webpage
# [youtube] waUM5tg_lko: Downloading android vr player API JSON
# [download] 42の重要な文型のパターン - 中国語リスニング練習(中級)｜HSK文法 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 4 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FBdA7rN5I7I
# [youtube] FBdA7rN5I7I: Downloading webpage
# [youtube] FBdA7rN5I7I: Downloading android vr player API JSON
# [download] 【聞き流し中国語】初級会話フレーズ/単語·日常会話·簡単·勉強·初心者·リスニング does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 5 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=or36fiNGIB0
# [youtube] or36fiNGIB0: Downloading webpage
# [youtube] or36fiNGIB0: Downloading android vr player API JSON
# [download] 【たった5分でマスターできる】子音の発音が劇的に向上するコツを伝授します【永久保存版】（下編） does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 6 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Y8kCpaSh-UM
# [youtube] Y8kCpaSh-UM: Downloading webpage
# [youtube] Y8kCpaSh-UM: Downloading android vr player API JSON
# [download] 【たった5分でマスターできる】一瞬で子音の発音が劇的に向上するコツを伝授します【永久保存版】（上編） does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 7 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Wg2Ht3w1Ssw
# [youtube] Wg2Ht3w1Ssw: Downloading webpage
# [youtube] Wg2Ht3w1Ssw: Downloading android vr player API JSON
# [download] 【有料級！ピンインの鼻母音＆erの発音コツは、一本の動画で分マスターできます！】 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 8 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zFY9KgpvriE
# [youtube] zFY9KgpvriE: Downloading webpage
# [youtube] zFY9KgpvriE: Downloading android vr player API JSON
# [download] 【有料級！複合母音の発音コツは、一本の動画でマスターできます！】 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 9 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gHLMyfioIDc
# [youtube] gHLMyfioIDc: Downloading webpage
# [youtube] gHLMyfioIDc: Downloading android vr player API JSON
# [download] 【必見！ピンインの基礎となる単母音とその発音コツは、一本の動画でマスターできます！】 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 10 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YAGSm6hFiCI
# [youtube] YAGSm6hFiCI: Downloading webpage
# [youtube] YAGSm6hFiCI: Downloading android vr player API JSON
# [download] 【必見！中国語のピンインの仕組み＆四声とその発音コツは、一本の動画で分マスターできます！】 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 11 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ddt3qkOpIA4
# [youtube] Ddt3qkOpIA4: Downloading webpage
# [youtube] Ddt3qkOpIA4: Downloading android vr player API JSON
# [download] 【必見！中国語の全体像は、一本の動画でマスターできます！】標準語 vs. 方言、ピンインとは、中国語の簡体字を習得するコツ！ does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 12 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EH11FCYw1Mw
# [youtube] EH11FCYw1Mw: Downloading webpage
# [youtube] EH11FCYw1Mw: Downloading android vr player API JSON
# [download] 流行りの中国ドラマ『最も美しい時間』で学ぶ！HSK頻出文法「让」の構文の解説付き日中字幕 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 13 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5tCrQ1ZJ_7s
# [youtube] 5tCrQ1ZJ_7s: Downloading webpage
# [youtube] 5tCrQ1ZJ_7s: Downloading android vr player API JSON
# [download] 人気中国ドラマ『最も美しい時間』で学ぶ！HSK頻出文法「是...的」の解説付き日中字幕 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Downloading item 14 of 14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B9TVqydKX8E
# [youtube] B9TVqydKX8E: Downloading webpage
# [youtube] B9TVqydKX8E: Downloading android vr player API JSON
# [download] 人気中国ドラマ『最も美しい時間』で学ぶ！HSK頻出文法「把構文」の解説付き日中字幕 does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Finished downloading playlist: 李先生の楽しい中国語塾 - Videos
# [download] Downloading item 2 of 3
# [download] Downloading playlist: 李先生の楽しい中国語塾 - Live
# [youtube:tab] Playlist 李先生の楽しい中国語塾 - Live: Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2UNwSHAdTtc
# [youtube] 2UNwSHAdTtc: Downloading webpage
# [youtube] 2UNwSHAdTtc: Downloading android vr player API JSON
# [download] スタバで使える！リアル中国語会話　ライブ does not pass filter (original_url *= '/shorts/'), skipping ..
# [download] Finished downloading playlist: 李先生の楽しい中国語塾 - Live
# [download] Downloading item 3 of 3
# [download] Downloading playlist: 李先生の楽しい中国語塾 - Shorts
# [youtube:tab] UC3-VNyJabIi3cmCjCJPB93w page 1: Downloading API JSON
# [youtube:tab] UC3-VNyJabIi3cmCjCJPB93w page 2: Downloading API JSON
# [youtube:tab] UC3-VNyJabIi3cmCjCJPB93w page 3: Downloading API JSON
# [youtube:tab] UC3-VNyJabIi3cmCjCJPB93w page 4: Downloading API JSON
# [youtube:tab] Playlist 李先生の楽しい中国語塾 - Shorts: Downloading 227 items of 227
# [download] vXuPMEBMsJA: 😱その中国語、大丈夫？🇨🇳「大姐」はNG!? #中国語#中国語会話#中国語学習#中国語初心者#HSK#shorts has already been recorded in the archive
# [download] aFg8fYWZuCM: 教科書には載ってない中国語🇨🇳「瞎忙呗」 #中国語会話#中国語学習#中国語 #HSK#shorts has already been recorded in the archive
# [download] h3Q4NKf_rD8: 「猫眼」って猫の目じゃないの！？😳 #hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] Z7QJQGPQaUA: 中国人って朝からこれ食べるの!?🥚 #中国語#リアル中国語#中国語勉強 #shorts has already been recorded in the archive
# [download] 70bISRBiYSk: 中国でフルーツを買う時🍎#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] 4300XJXRi_I: 中国人と初対面で使える中国語#中国語会話 #中国語 #shorts has already been recorded in the archive
# [download] g5YAJqAGevU: その中国語、一気に上級者レベルに！#中国語会話#中国語学習#HSK#shorts has already been recorded in the archive
# [download] uBsb-ftaKug: 通じるけど…それ、ちょっと失礼かも😅#中国語#中国語会話#中国語学習 #中国語初心者#HSK #shorts has already been recorded in the archive
# [download] Ge_lb3rwH10: それ、「見てない」の中国語、ほとんどの人が間違えてます#中国 語会話 #中国語学習 #中国語 #HSK #shorts has already been recorded in the archive
# [download] XpIHY7Egopo: 中国でハンバーガーを注文する時🍔#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] bLafN0UPoW0: 中国語のレベルをチェックしてみよう🙌🙌#hsk1級#hsk3級#hsk2級#hsk4級#hsk5級#hsk6級#中国語#中国語会話#shorts has already been recorded in the archive
# [download] yRvVa8wNfqY: 中国語の面接で成功する「秘訣」😂😂 #hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] C2wSKqzYSPY: 中国語でカフェ注文する時☕️#hsk1級#hsk3級#hsk2級#hsk4級#hsk5級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] ceIAdVMHC3o: 中国旅行で困らない！リアルな中国語がすぐ話せる講座 has already been recorded in the archive
# [download] GmYK4o41ieM: あの女性、殴りたくなるよね？😂#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] kMwkpylygU8: 中国で飛行機に乗る時✈️✈️#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] pVZnm0q4_M4: 【衝撃】「打」って電話だけじゃない!? ネイティブが毎日使う超便利フレーズ10選#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] yAElYQvBy7c: 中国語で「我干…」はアウト！？❌🫢🫢#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] -Hnu-jZ0Il4: これ使えばネイティブっぽい！中国語スラング#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] NuH7YheXeBk: 「度日如年（dù rì rú nián）」って、どういう意味だと思いますか？#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] JmEEQmZZh6k: 🇨🇳中国語が難しい理由🤦🏻‍♂️🤦🏻‍♂️#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] z_EhETn9qN0: 中国語と台湾華語を比べてみた🫢🫢#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] Qj3uGxeKeRw: 🇨🇳中国語が難しい理由🤦🏻‍♂️🤦🏻‍♂️#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] GychybGZyew: 中国語が難しい理由😭😭#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] ElxnfqSnoSU: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] QvnhlcQvuTE: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] bR_MijgeuMk: 中国語の先生が自分の中国語を疑い始める瞬間😂#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] o_MI9wshKi4: お正月の挨拶を中国語でお願いされた時🤣新年快乐🎍🎍 #hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] NwucE7wfkxA: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download
🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts - rsyxlkQGPi4.f134.mp4
#
# [download]   0.1% of    1.20MiB at   16.89KiB/s ETA 01:12
# [download]   0.2% of    1.20MiB at   49.97KiB/s ETA 00:24
# [download]   0.6% of    1.20MiB at  113.52KiB/s ETA 00:10
# [download]   1.2% of    1.20MiB at  234.18KiB/s ETA 00:05
# [download]   2.5% of    1.20MiB at  220.51KiB/s ETA 00:05
# [download]   5.1% of    1.20MiB at  252.48KiB/s ETA 00:04
# [download]  10.4% of    1.20MiB at  344.64KiB/s ETA 00:03
# [download]  20.8% of    1.20MiB at  515.36KiB/s ETA 00:01
# [download]  41.7% of    1.20MiB at  823.77KiB/s ETA 00:00
# [download]  83.4% of    1.20MiB at    1.34MiB/s ETA 00:00
# [download] 100.0% of    1.20MiB at    1.54MiB/s ETA 00:00
# [download] 100% of    1.20MiB in 00:00:02 at 529.66KiB/s
# [download] Destination: /mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20231128 - 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts - rsyxlkQGPi4.f140.m4a
#
# [download]   0.2% of  588.95KiB at  143.96KiB/s ETA 00:04
# [download]   0.5% of  588.95KiB at  397.43KiB/s ETA 00:01
# [download]   1.2% of  588.95KiB at  773.45KiB/s ETA 00:00
# [download]   2.5% of  588.95KiB at    1.22MiB/s ETA 00:00
# [download]   5.3% of  588.95KiB at    2.19MiB/s ETA 00:00
# [download]  10.7% of  588.95KiB at    1.84MiB/s ETA 00:00
# [download]  21.6% of  588.95KiB at    3.42MiB/s ETA 00:00
# [download]  43.3% of  588.95KiB at    6.31MiB/s ETA 00:00
# [download]  86.8% of  588.95KiB at   11.44MiB/s ETA 00:00
# [download] 100.0% of  588.95KiB at    2.91MiB/s ETA 00:00
# [download] 100% of  588.95KiB in 00:00:01 at 473.68KiB/s
# [Merger] Merging formats into "/mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20231128 - 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts - rsyxlkQGPi4.mp4"
# Deleting original file /mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20231128 - 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts - rsyxlkQGPi4.f140.m4a (pass -k to keep)
# Deleting original file /mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20231128 - 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts - rsyxlkQGPi4.f134.mp4 (pass -k to keep)
# [download] CrEMPxgYGFc: ✈️初めて中国に行った時 VS🏠しばらく中国に住んだ後#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] TRp2HzM-cAs: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] GhwkYC5TKjY: HSK試験が終わって、つまらない奴に会った😢#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] Q7OLhcDXV04: ✨色んなシチュエーションで使える中国語✨#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] 3j8xQeEZcCE: ✨有点儿VS 一点儿✨の違い｜#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] _REHR2DfTR8: ✈️初めて中国に行った時 VS🏠しばらく中国に住んだ後#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] MtXTwjh1R_0: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] EA3znGPxO0o: コンビニでの中国語🍱#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] KMiqwmcaVcQ: 🗣リアルな中国語 VS 📚教科書の中国語#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download] Xew8gs-Wr6Y: 【中国語の重要文型42選】#中国語#HSK文法#hsk1級 #hsk2級 #hsk3級#hsk4級#hsk1級#shorts has already been recorded in the archive
# [download] mkhVMM0M1_I: 公式LINEを追加してご応募いただけます。💁‍♀️公式LINE ID: @leechanch｜#モニター募集#中国語#中国語勉強 has already been recorded in the archive
# [download] 598Td4Ghae8: 🛏️🪞💡様々な家具·家庭用品の中国語の発音をチェックしてみよう#中国語#shorts has already been recorded in the archive
# [download] nxwL7hAcyhA: 🥄🥢✂️様々な調理器具の中国語の発音をチェックしてみよう#中国語#shorts has already been recorded in the archive
# [download] 3-mYgWrN2fw: 中国語のレベルを、フルーツの名前でチェックしてみましょう！🍎🍌🍊🥑#hsk1級#hsk3級#hsk2級#hsk4級#中国語会話#中国語#shorts has already been recorded in the archive
# [download
# [download] s57TM-ktJ6I: 中国語の朗読｜1日1分で会話スキルが確実に大幅にアップ！ #中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語発音 #中国語学習 #中国語 #shorts has already been recorded in the archive
# [download] H6WTQ4T6fzs: 中国語の朗読｜1日1分でコミュ力が確実に向上します！ #中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語発音 #中国語学習 #中国語 #shorts has already been recorded in the archive
# [download] iaEy_mqXigQ: 助動詞はこれで完璧！ #中国語文法 #hsk1級 #hsk2級 #hsk3級#中国語学習 #中国語#助動詞#shorts has already been recorded in the archive
# [download] AJIPhTeokoM: 中国語の朗読|1日たった1分の練習で会話が全く途切れなくなる！ #中国語ピンイン#中国語の朗読#中国語発音 #hsk1級 #hsk2級 #hsk3級#中国語会話  #shorts has already been recorded in the archive
# [download] VladWmJOL7A: 中国語の母音|たった1分で『e』 が含まれる母音の発音のコツを完全マスター！ #hsk1級 #中国語ピンイン #hsk2級 #中国語発音 #中国語学習 #中国語 #shorts has already been recorded in the archive
# [download] KOTofFCppVU: 中国語の母音|たった1分で『o』 が含まれる母音の発音のコツを完全マスター！ #hsk1級 #中国語ピンイン #hsk2級 #中国語発音 #中国語学習 #中国語 #shorts has already been recorded in the archive
# [download] VRaoM65irrw: 中国語の発音篇｜たった1分で『a』 が含まれる母音の発音のコツを完全マスター！ #hsk1級 #中国語ピンイン #hsk2級 #中国語発音 #中国語学習 #中国語 #shorts has already been recorded in the archive
# [download] V5mbo5oqK_g: 中国語の朗読篇｜1日1分で会話力をグッと高める! #中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語発音 #中国語学習 #中国語 #中国語会話 #中国語の朗読#shorts has already been recorded in the archive
# [download] SdX3yTKeGMc: 中国語の朗読|1日1分でもう雑談には怖くない！ #中国語ピンイン#中国語の朗読#中国語発音 #hsk1級 #hsk2級 #hsk3級#中国語会話  #shorts has already been recorded in the archive
# [download] wzzDSU2QcCo: 中国語の朗読|1日1分でトーク力が確実に上達します！ #中国語ピンイン#中国語の朗読#中国語発音 #hsk1級 #hsk2級 #hsk3級#中国語会話  #shorts has already been recorded in the archive
# [download] Downloading item 222 of 227
# [youtube] Extracting URL: https://www.youtube.com/shorts/X4M7GQSjZ90
# [youtube] X4M7GQSjZ90: Downloading webpage
# [youtube] X4M7GQSjZ90: Downloading android vr player API JSON
# [info] X4M7GQSjZ90: Downloading 1 format(s): 134+140
#
#
# [download] vu95RRiajMA: 中国語の朗読｜ #中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語学習 #中国語発音 #中国語 #shorts has already been recorded in the archive
# [download] CkjuymQ2rAE: 中国語の朗読｜#中国語ピンイン #hsk1級 #hsk3級 #hsk2級 #中国語学習 #中国語発音 #中国語中級 #中国語 #中国旅行 has already been recorded in the archive
# [download] KD1nNfcWme0: 中国語の朗読｜#中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語学習 #中国語発音 #中国語 #中国語の朗読#海外旅行 has already been recorded in the archive
# [download] YosdPDL-j_I: 中国語の朗読｜ #中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #中国語学習 #中国語発音 #中国語 has already been recorded in the archive
# [download] Z_jgpuUd_GU: 中国語の朗読｜#中国語ピンイン #hsk1級 #hsk2級 #hsk3級 #hsk4級 #中国語学習 #中国語発音 #中国語中級 has already been recorded in the archive
# [download] Finished downloading playlist: 李先生の楽しい中国語塾 - Shorts
# [download] Finished downloading playlist: 李先生の楽しい中国語塾
# ✅ Shorts download completed. Saved to: /mnt/d/Youtube
#
# --- Standard Error / Warnings ---
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: unable to open for writing: [Errno 36] File name too long: '/mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20230703 - 中国語の朗読｜今日の動画で自分のことを中国語で完璧に話せるようになりましょう！ #中国語ピンイン#中国語の朗読#中国語発音 #hsk1級 #hsk2級 #hsk3級#中国語会話  #shorts - X4M7GQSjZ90.f134.mp4.part'
# ERROR: unable to open for writing: [Errno 36] File name too long: '/mnt/d/Youtube/李先生の楽しい中国語塾/Shorts/20230703 - 中国語の朗読｜今日の動画で自分のことを中国語で完璧に話せるようになりましょう！ #中国語ピンイン#中国語の朗読#中国語発音 #hsk1級 #hsk2級 #hsk3級#中国語会話  #shorts - X4M7GQSjZ90.f140.m4a.part'

# %% [markdown]
# # scripts environment | main

# %% [markdown]
# ## translate_deepl_srt

# %%
import translate_deepl_srt
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)

translate_deepl_srt.translate_srt(full_path, target_lang="JA")

# %% [markdown]
# ## split_media

# %%
import split_media

base = '/mnt/d/Youtube/'

filename = ""
while not filename:
    filename = input("Enter .mp4 FileName: ").strip().strip('"').strip("'")

num_splits = input("Enter Number of Splits (Default is 3): ")

# 2. パスの結合と分割数の変換
full_path = os.path.join(base, filename)
num_splits = int(num_splits) if num_splits.strip() else 3

# 3. 実行
split_media.split_media_files([full_path], num_splits)

# Switching_Movie/
# Out:
# Enter .mp4 FileName:  Switching_Movie/Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.mp4
# Enter Number of Splits (Default is 3):  2
# ==========================================
# >>> 処理開始: Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.mp4
# 検出された字幕ファイル (3件):
#   - Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en.srt
#   - Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en_JP.srt
#   - Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.srt
#
# --- Processing Part 1/2 (0.00s - 456.52s) ---
# Exporting video: Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part1.mp4
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part1.en.srt
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en_JP.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part1.en_JP.srt
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part1.srt
#
# --- Processing Part 2/2 (456.52s - 913.04s) ---
# Exporting video: Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part2.mp4
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part2.en.srt
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en_JP.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part2.en_JP.srt
# Saving subtitles (Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.srt) -> Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs_part2.srt
#
# ==========================================
# Success! すべての動画と関連字幕の分割が完了しました。
# ==========================================

# %% [markdown]
# ## make_playlist

# %%
import make_playlist
make_playlist.generate_xspf("/mnt/d/Youtube/Movie_Pool")
make_playlist.generate_xspf("/mnt/d/Youtube/Switching_Movie")
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Movie_Pool.xspf
# Playlist created for Windows VLC: /mnt/d/Youtube/Switching_Movie.xspf
# '/mnt/d/Youtube/Switching_Movie.xspf'

# %% [markdown]
# ## switch_subtitles

# %%
import switch_subtitle
switch_subtitle.switch_subtitles("ja")

#witch_subtitle.switch_subtitles("en")
# Out:
# 適用完了: Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.srt <-- Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en_JP.srt
# 適用完了: How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.srt <-- How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.en_JP.srt
#
# 完了: [JA] 字幕を 2 件に適用しました。

# %%
import time
import switch_subtitle

# 初期設定（Trueなら最初は日本語、Falseなら英語からスタート）
is_japanese = True

print("Jupyter上で字幕の切り替えループを開始します。")
print("停止するには、上部の『■ (Interrupt the kernel)』ボタンを押してください。\n")

try:
    while True:
        # 言語の決定
        lang = "ja" if is_japanese else "en"
        
        # 実行ログの出力
        current_time = time.strftime('%H:%M:%S')
        print(f"[{current_time}] 字幕を '{lang}' に切り替えました。")
        
        # 切り替え関数の実行
        switch_subtitle.switch_subtitles(lang)
        
        # フラグを反転（次回の言語を切り替える）
        is_japanese = not is_japanese
        
        # 3分（180秒）待機
        time.sleep(30)

except KeyboardInterrupt:
    print("\n[STOP] カーネルが中断されました。ループを停止します。")
# Out:
# Jupyter上で字幕の切り替えループを開始します。
# 停止するには、上部の『■ (Interrupt the kernel)』ボタンを押してください。
#
# [18:35:12] 字幕を 'ja' に切り替えました。
# 適用完了: Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.srt <-- Can a Camera on Every Corner Make Us Safer？ ｜ Garr-v0BiDmPloBs.en_JP.srt
# 適用完了: How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.srt <-- How to Introduce Yourself — and Get Hired ｜ Rebecc-d1yfb93beSI.en_JP.srt
#
# 完了: [JA] 字幕を 2 件に適用しました。
#
# [STOP] カーネルが中断されました。ループを停止します。

# %% [markdown]
# ## make_mp3

# %%
import make_mp3
make_mp3.combine_audio_files("/mnt/d/Youtube/Movie_Pool")
# Out:
# Found 29 files. Processing...
# MoviePy - Writing audio in /mnt/d/Youtube/Movie_Pool_20260719_1202.mp3
# MoviePy - Done.
#
# Successfully created: /mnt/d/Youtube/Movie_Pool_20260719_1202.mp3
# '/mnt/d/Youtube/Movie_Pool_20260719_1202.mp3'

# %% [markdown]
# ## srt_to_pro_epub

# %%
import srt_to_pro_epub 
import os

base = '/mnt/d/Youtube/'
filename = input("Enter SRT FileName: ")
filename = filename.strip().strip('"').strip("'")
full_path = os.path.join(base, filename)
srt_to_pro_epub.convert(full_path, vertical=False)
# Out:
# Enter SRT FileName:  Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.srt
# Output professional-grade EPUB: /mnt/d/Youtube/Movie_Pool/old/The Army of Autonomous Robots Restoring Nature ｜ Tom Chi ｜ TED - 0R_CJjGRX7o.en_bilingual.epub
# True
