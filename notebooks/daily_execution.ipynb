# %% [markdown]
# # <a id='toc1_'></a>[setup](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [setup](#toc1_)
# - [youtube-env](#toc2_)
# - [scripts-env](#toc3_)
# - [notebooks-env](#toc4_)
# - [web_scraping-env](#toc5_)
# - [daily check](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess
from src.calendar_util import display_holiday_calendar
from src.clock_util import draw_clock

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %%
from pathlib import Path
import sys
import os
scripts_dir = Path("~/scripts").expanduser()
sys.path.insert(0, str(scripts_dir))

# %% [markdown]
# # <a id='toc2_'></a>[youtube-env](#toc0_)

# %%
env_name = "youtube"
cmd_name = "update.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# Requirement already satisfied: pip in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (26.2.1)
# Requirement already satisfied: yt-dlp in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (2026.8.19)

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KIBCauQKEzM
# [youtube] KIBCauQKEzM: Downloading webpage
# [youtube] KIBCauQKEzM: Downloading visionos player API JSON
# [youtube] KIBCauQKEzM: Downloading m3u8 information
# [info] KIBCauQKEzM: Downloading 1 format(s): 398+251-1
# [download] Resuming download at byte 213980886
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (1/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (2/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (3/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (4/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (5/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (6/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (7/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (8/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (9/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# [download] Got error: The read operation timed out. Retrying (10/10)...
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f398.mp4
# ERROR:
# [download] Got error: The read operation timed out. Giving up after 10 retries
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-08-20 - エジプト旅🇪🇬アスワンからルクソールへ3泊4日の5つ星ナイル川クルーズ乗ってみた。【アフリカ#4】2026年5月27日〜6月2日 - KIBCauQKEzM.f251-1.webm
# [download] Download completed
# [download] 1h0Q3SvUjDw: スース旅🇹🇳チュニジアの穴場お手頃リゾートからの大事件発生。【アフリカ#3】2026年5月17日〜21日 has already been recorded in the archive
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] Rl9BHhEuUlM: Investigating the Tribe That Warns of the End of the World has already been recorded in the archive
# [download] DW0uFd1P8eo: The Country with Absolutely ZERO Mercy for Immigrants has already been recorded in the archive
# [download] Finished downloading playlist: Bappa Shota - Videos
# Completed: https://www.youtube.com/@BappaShota/videos
# ✅ All processes completed

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc3_'></a>[scripts-env](#toc0_)

# %%
env_name = "scripts"
cmd_name = "make_playlist.py -r"
option_name = "/mnt/d/Youtube/Movie_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"python {cmd_name} {option_name}"
)
run_commands_fixed(cmd_string)

# %%
#import make_playlist
#make_playlist.generate_xspf("/mnt/d/Youtube/Movie_Pool")
#make_playlist.generate_xspf("/mnt/d/Youtube/MontaEnglish/Shorts")
#make_playlist.generate_xspf("/mnt/d/Youtube/李先生の楽しい中国語塾/Shorts")

# %%
env_name = "scripts"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc4_'></a>[notebooks-env](#toc0_)

# %%
env_name = "notebooks"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %%
env_name = "notebooks"
cmd_name = "freeze_pip.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc5_'></a>[web_scraping-env](#toc0_)

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc6_'></a>[daily check](#toc0_)

# %%
cmd_name = "backup.sh"

cmd_string = (
    f"cd ~ && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %%
display_holiday_calendar()
