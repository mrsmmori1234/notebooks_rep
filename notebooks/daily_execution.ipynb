# %% [markdown]
# # <a id='toc1_'></a>[setup](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [setup](#toc1_)
# - [youtube-env](#toc2_)
# - [scripts-env](#toc3_)
# - [notebooks-env](#toc4_)
# - [web_scraping-env](#toc5_)
# - [daily check](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess
from src.calendar_util import display_holiday_calendar
from src.clock_util import draw_clock

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %% [markdown]
# # <a id='toc2_'></a>[youtube-env](#toc0_)

# %%
env_name = "youtube"
cmd_name = "update.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] nhsRIWSv5us: World Cup Brazil Match, Heaven and Hell at the Stadium. [North/Central America World Cup #10] Jun... has already been recorded in the archive
# [download] fcbMnLEr6Uk: World Cup Sweden Match: Local fans go wild as we advance to the knockout stage! [North and Centra... has already been recorded in the archive
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] XQC-pojFl6k: Investigating South Africa’s White-Only Town has already been recorded in the archive
# [download] kcxRQo6MgN0: Inside Of The Most Unequal Country In The World has already been recorded in the archive
# [download] Finished downloading playlist: Bappa Shota - Videos
# Completed: https://www.youtube.com/@BappaShota/videos
# ✅ All processes completed

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/youtube_rep.git
#    8c28c6f..9d359d7  main -> main
# [main 43100bf] Jul 06
#  2 files changed, 10 insertions(+), 1 deletion(-)

# %% [markdown]
# # <a id='toc3_'></a>[scripts-env](#toc0_)

# %%
env_name = "scripts"
cmd_name = "make_playlist.py -r"
option_name = "/mnt/d/Youtube/Movie_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"python {cmd_name} {option_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Movie_Pool.xspf

# %%
env_name = "scripts"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/script_rep.git
#    c6ec36c..2301c5f  main -> main
# [main cf29f01] Jul 06
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite __pycache__/make_mp3.cpython-312.pyc (61%)

# %% [markdown]
# # <a id='toc4_'></a>[notebooks-env](#toc0_)

# %%
env_name = "notebooks"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/notebooks_rep.git
#    49627b7..37b3632  main -> main
# [main 85f82e7] Jul 06
#  6 files changed, 1466 insertions(+), 659 deletions(-)
#  create mode 100644 pip_backups/requirements_20260705_080652.txt

# %%
env_name = "notebooks"
cmd_name = "freeze_pip.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# =========================================
# 💾 Starting Pip Environment Backup...
# =========================================
# 📝 Freezing installed packages from current environment...
# ✅ Backup successfully created!
# 📂 File Location: ./pip_backups/requirements_20260706_204745.txt
# 📊 Total Packages: 240
# =========================================

# %% [markdown]
# # <a id='toc5_'></a>[web_scraping-env](#toc0_)

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Everything up-to-date
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # <a id='toc6_'></a>[daily check](#toc0_)

# %%
cmd_name = "backup.sh"

cmd_string = (
    f"cd ~ && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# 2026/07/06 20:47
# ./
# ./myWorkspace.code-workspace
# ./launch_jupyter.sh
# ./scripts/
# ./scripts/srt_to_pro_epub.py
# ./scripts/__init__.py
# ./scripts/check_gemini_usage.py
# ./scripts/.vscode/
# ./scripts/.vscode/settings.json
# ./scripts/diskspace.py
# ./scripts/.python-version
# ./scripts/csv2xlsx.sh
# ./scripts/__pycache__/
# ./scripts/__pycache__/make_mp3.cpython-312.pyc
# ./scripts/__pycache__/check_holidays.cpython-312.pyc
# ./scripts/__pycache__/split_media.cpython-312.pyc
# ./scripts/__pycache__/srt_to_pro_epub.cpython-312.pyc
# ./scripts/__pycache__/make_playlist.cpython-312.pyc
# ./scripts/__pycache__/translate_deepl_srt.cpython-312.pyc
# ./scripts/split_media.py
# ./scripts/check_deepl_usage.py
# ./scripts/translate_deepl_srt.py
# ./scripts/make_mp3.py
# ./scripts/check_holidays.py
# ./scripts/.agents/
# ./scripts/old/
# ./scripts/old/csv2xlsx.py
# ./scripts/old/__init__.py
# ./scripts/old/merge_shorts.sh
# ./scripts/old/csv2xlsx.sh
# ./scripts/old/translate_srt.py
# ./scripts/old/mp4.sh
# ./scripts/old/split_media.py.20260530
# ./scripts/old/mp3.sh
# ./scripts/old/convert_to_wmp.sh
# ./scripts/old/muon.sh
# ./scripts/backup.sh
# ./scripts/make_playlist.py
# ./packages/
# ./packages/holidays_wheels/
# ./packages/holidays_wheels/six-1.17.0-py2.py3-none-any.whl
# ./packages/holidays_wheels/holidays-0.92-py3-none-any.whl
# ./packages/holidays_wheels/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# ./packages/README.md
# ./packages/packages/
# ./packages/packages/yt-dlp/
# ./packages/packages/yt-dlp/yt_dlp-2026.3.3-py3-none-any.whl
# ./notebooks/
# ./notebooks/launch_jupyter.sh
# ./notebooks/__init__.py
# ./notebooks/Win_Downloads
# ./notebooks/pip_backups/
# ./notebooks/pip_backups/requirements_20260627_124946.txt
# ./notebooks/pip_backups/requirements_20260701_092218.txt
# ./notebooks/pip_backups/requirements_20260703_162143.txt
# ./notebooks/pip_backups/requirements_20260630_190026.txt
# ./notebooks/pip_backups/requirements_20260705_080652.txt
# ./notebooks/pip_backups/requirements_20260628_082842.txt
# ./notebooks/pip_backups/requirements_20260615_211841.txt
# ./notebooks/pip_backups/requirements_20260629_181431.txt
# ./notebooks/pip_backups/requirements_20260628_094312.txt
# ./notebooks/pip_backups/requirements_20260706_204745.txt
# ./notebooks/pip_backups/requirements_20260701_091424.txt
# ./notebooks/pip_backups/requirements_20260701_085739.txt
# ./notebooks/pip_backups/requirements_20260613_170030.txt
# ./notebooks/pip_backups/requirements_20260614_215918.txt
# ./notebooks/pip_backups/requirements_20260702_191225.txt
# ./notebooks/.vscode/
# ./notebooks/.vscode/settings.json
# ./notebooks/src/
# ./notebooks/src/calendar_util.py
# ./notebooks/src/clock_util.py
# ./notebooks/src/__pycache__/
# ./notebooks/src/__pycache__/gemini_helper.cpython-312.pyc
# ./notebooks/src/__pycache__/data_loader.cpython-312.pyc
# ./notebooks/src/__pycache__/calendar_util.cpython-312.pyc
# ./notebooks/src/__pycache__/env_setup.cpython-312.pyc
# ./notebooks/src/__pycache__/clock_util.cpython-312.pyc
# ./notebooks/src/__pycache__/system.cpython-312.pyc
# ./notebooks/src/system.py
# ./notebooks/src/env_setup.py
# ./notebooks/src/data_loader.py
# ./notebooks/src/gemini_helper.py
# ./notebooks/.python-version
# ./notebooks/.gitignore
# ./notebooks/update_pip.sh
# ./notebooks/outputs/
# ./notebooks/outputs/output.csv
# ./notebooks/outputs/ocbc.csv
# ./notebooks/clean_pip.sh
# ./notebooks/notebooks/
# ./notebooks/notebooks/notes.ipynb
# ./notebooks/notebooks/sgx_etf.ipynb
# ./notebooks/notebooks/.vscode/
# ./notebooks/notebooks/.vscode/settings.json
# ./notebooks/notebooks/sgx_securities.ipynb
# ./notebooks/notebooks/ocbc.ipynb
# ./notebooks/notebooks/yahoo_finance.ipynb
# ./notebooks/notebooks/daily_execution.ipynb
# ./notebooks/notebooks/personal/
# ./notebooks/notebooks/tver_urls.txt
# ./notebooks/notebooks/Archive/
# ./notebooks/notebooks/Archive/MyNotebook.ipynb
# ./notebooks/notebooks/Archive/FSMOne.ipynb
# ./notebooks/notebooks/movie_operations.ipynb
# ./notebooks/backup.sh
# ./notebooks/readme.md
# ./notebooks/stop_jupyter.sh
# ./notebooks/freeze_pip.sh
# ./web_scraping/
# ./web_scraping/.vscode/
# ./web_scraping/.vscode/settings.json
# ./web_scraping/README.md
# ./web_scraping/.python-version
# ./web_scraping/.gitignore
# ./web_scraping/tver_debug.png
# ./web_scraping/test.py
# ./web_scraping/backup.sh
# ./web_scraping/verify_yahoo.py
# ./web_scraping/tver_fav_list.py
# ./backup.sh
# ./.vimrc
# ./.bash_history
# ./.vim/
# ./.vim/.netrwhist
# ./.bashrc
# ./youtube/
# ./youtube/.vscode/
# ./youtube/.vscode/settings.json
# ./youtube/channel_mp4.sh
# ./youtube/tver_batch_dl.sh
# ./youtube/.gitignore.swp
# ./youtube/.python-version
# ./youtube/.gitignore
# ./youtube/mp3_dl.sh
# ./youtube/__pycache__/
# ./youtube/__pycache__/speedtest.cpython-312.pyc
# ./youtube/clean_pip.sh
# ./youtube/channels.txt
# ./youtube/old/
# ./youtube/old/translate_srt.py
# ./youtube/old/yt_bot_check.sh
# ./youtube/speed_test.py
# ./youtube/update.sh
# ./youtube/shorts_dl.sh
# ./youtube/backup.sh
# ./youtube/interactive_dl.sh
# ./youtube/tver_urls.txt
# ./youtube/logs/
# ./youtube/logs/tver_downloaded.log
# ./youtube/logs/downloaded.txt
# ./youtube/logs/shorts_downloaded.txt
# ./youtube/logs/archive.txt
# ./youtube/playlist_dl.sh
# ./youtube/freeze_pip.sh
# ./stop_jupyter.sh
# ./.profile
# ✅ Backup successful: ./_backup/backup-2026-07-06-20-47-47.tar → /mnt/d/Ubuntu_Backup
# 📦 Size: 6.2M

# %%
display_holiday_calendar()
# Out:
# <style>
#     .cal-container {
#         font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif;
#         display: flex;
#         flex-wrap: wrap;
#         gap: 20px;
#         background-color: #1e1e24;
#         padding: 20px;
#         border-radius: 12px;
#     }
#     .cal-box {
#         background-color: #2a2a35;
#         border-radius: 8px;
#         padding: 15px;
#         width: 260px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.3);
#     }
#     .cal-title {
#         color: #ffffff;
#         font-size: 1.1rem;
#         font-weight: bold;
#         text-align: center;
#         margin-bottom: 12px;
#         border-bottom: 2px solid #3e3e50;
#         padding-bottom: 6px;
#     }
#     .cal-grid {
#         display: grid;
#         grid-template-columns: repeat(7, 1fr);
#         gap: 6px;
#         text-align: center;
#     }
#     .day-header {
#         color: #8e8e9f;
#         font-size: 0.8rem;
#         font-weight: bold;
#         padding-bottom: 4px;
#     }
#     .day-cell {
#         color: #e0e0e0;
#         font-size: 0.9rem;
#         height: 30px;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         border-radius: 4px;
#     }
#     .day-empty {
#         height: 30px;
#     }
#
#     /* Neon Highlighting Variables */
#     .today-highlight {
#         background-color: #ff007f !important;
#         color: #ffffff !important;
#         font-weight: bold;
#         box-shadow: 0 0 8px #ff007f;
#     }
#     .sg-highlight {
#         background-color: rgba(0, 240, 255, 0.2);
#         color: #00f0ff !important;
#         font-weight: bold;
#         border: 1px solid #00f0ff;
#     }
#     .jp-highlight {
#         background-color: rgba(255, 235, 59, 0.15);
#         color: #ffeb3b !important;
#         font-weight: bold;
#         border: 1px solid #ffeb3b;
#     }
#     .both-highlight {
#         background-color: #7f1d1d;
#         color: #fca5a5 !important;
#         font-weight: bold;
#         border: 1px solid #ef4444;
#     }
#
#     /* Legend Styles */
#     .legend-container {
#         display: flex;
#         gap: 20px;
#         margin-top: 15px;
#         padding-top: 10px;
#         border-top: 1px solid #3e3e50;
#         width: 100%;
#     }
#     .legend-item {
#         display: flex;
#         align-items: center;
#         gap: 8px;
#         color: #b0b0c0;
#         font-size: 0.85rem;
#     }
#     .legend-badge {
#         width: 16px;
#         height: 16px;
#         border-radius: 3px;
#     }
# </style>
# <div class="cal-container"><div class="cal-box"><div class="cal-title">JULY 2026</div><div class="cal-grid"><div class="day-header">Su</div><div class="day-header">Mo</div><div class="day-header">Tu</div><div class="day-header">We</div><div class="day-header">Th</div><div class="day-header">Fr</div><div class="day-header">Sa</div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-cell">1</div><div class="day-cell">2</div><div class="day-cell">3</div><div class="day-cell">4</div><div class="day-cell">5</div><div class="day-cell today-highlight">6</div><div class="day-cell">7</div><div class="day-cell">8</div><div class="day-cell">9</div><div class="day-cell">10</div><div class="day-cell">11</div><div class="day-cell">12</div><div class="day-cell">13</div><div class="day-cell">14</div><div class="day-cell">15</div><div class="day-cell">16</div><div class="day-cell">17</div><div class="day-cell">18</div><div class="day-cell">19</div><div class="day-cell jp-highlight">20</div><div class="day-cell">21</div><div class="day-cell">22</div><div class="day-cell">23</div><div class="day-cell">24</div><div class="day-cell">25</div><div class="day-cell">26</div><div class="day-cell">27</div><div class="day-cell">28</div><div class="day-cell">29</div><div class="day-cell">30</div><div class="day-cell">31</div><div class="day-empty"></div></div></div><div class="cal-box"><div class="cal-title">AUGUST 2026</div><div class="cal-grid"><div class="day-header">Su</div><div class="day-header">Mo</div><div class="day-header">Tu</div><div class="day-header">We</div><div class="day-header">Th</div><div class="day-header">Fr</div><div class="day-header">Sa</div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-cell">1</div><div class="day-cell">2</div><div class="day-cell">3</div><div class="day-cell">4</div><div class="day-cell">5</div><div class="day-cell">6</div><div class="day-cell">7</div><div class="day-cell">8</div><div class="day-cell sg-highlight">9</div><div class="day-cell sg-highlight">10</div><div class="day-cell jp-highlight">11</div><div class="day-cell">12</div><div class="day-cell">13</div><div class="day-cell">14</div><div class="day-cell">15</div><div class="day-cell">16</div><div class="day-cell">17</div><div class="day-cell">18</div><div class="day-cell">19</div><div class="day-cell">20</div><div class="day-cell">21</div><div class="day-cell">22</div><div class="day-cell">23</div><div class="day-cell">24</div><div class="day-cell">25</div><div class="day-cell">26</div><div class="day-cell">27</div><div class="day-cell">28</div><div class="day-cell">29</div><div class="day-cell">30</div><div class="day-cell">31</div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div><div class="day-empty"></div></div></div><div class="cal-box"><div class="cal-title">SEPTEMBER 2026</div><div class="cal-grid"><div class="day-header">Su</div><div class="day-header">Mo</div><div class="day-header">Tu</div><div class="day-header">We</div><div class="day-header">Th</div><div class="day-header">Fr</div><div class="day-header">Sa</div><div class="day-empty"></div><div class="day-empty"></div><div class="day-cell">1</div><div class="day-cell">2</div><div class="day-cell">3</div><div class="day-cell">4</div><div class="day-cell">5</div><div class="day-cell">6</div><div class="day-cell">7</div><div class="day-cell">8</div><div class="day-cell">9</div><div class="day-cell">10</div><div class="day-cell">11</div><div class="day-cell">12</div><div class="day-cell">13</div><div class="day-cell">14</div><div class="day-cell">15</div><div class="day-cell">16</div><div class="day-cell">17</div><div class="day-cell">18</div><div class="day-cell">19</div><div class="day-cell">20</div><div class="day-cell jp-highlight ...

# %%
draw_clock()
