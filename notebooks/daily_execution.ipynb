# %% [markdown]
# # setup

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %% [markdown]
# # youtube-env

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GL-iChSS-bE
# [youtube] GL-iChSS-bE: Downloading webpage
# [youtube] GL-iChSS-bE: Downloading android vr player API JSON
# [info] GL-iChSS-bE: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-21 - W杯チュニジア戦、現地スタジアム歓喜の瞬間！🇲🇽モンテレイ【北中米W杯#6】2026年6月20日 - GL-iChSS-bE.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-21 - W杯チュニジア戦、現地スタジアム歓喜の瞬間！🇲🇽モンテレイ【北中米W杯#6】2026年6月20日 - GL-iChSS-bE.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-21 - W杯チュニジア戦、現地スタジアム歓喜の瞬間！🇲🇽モンテレイ【北中米W杯#6】2026年6月20日 - GL-iChSS-bE.mp4"
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-21 - W杯チュニジア戦、現地スタジアム歓喜の瞬間！🇲🇽モンテレイ【北中米W杯#6】2026年6月20日 - GL-iChSS-bE.f398.mp4 (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-21 - W杯チュニジア戦、現地スタジアム歓喜の瞬間！🇲🇽モンテレイ【北中米W杯#6】2026年6月20日 - GL-iChSS-bE.f251.webm (pass -k to keep)
# [download] YiHHNXzm8nA: Arrived in Monterrey, Mexico, for the Second World Cup Match Against Tunisia!【North American Worl... has already been recorded in the archive
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] kcxRQo6MgN0: Inside Of The Most Unequal Country In The World has already been recorded in the archive
# [download] atQFyMEStqQ: Surviving with The Last Hunters in Greenland’s Ice World has already been recorded in the archive
# [download] Finished downloading playlist: Bappa Shota - Videos
# Completed: https://www.youtube.com/@BappaShota/videos
# ✅ All processes completed

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/youtube_rep.git
#    b2889c3..99593cc  main -> main
# [main 334ba34] Jun 22
#  1 file changed, 1 insertion(+)

# %% [markdown]
# # scripts-env

# %%
env_name = "scripts"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/script_rep.git
#    fb63a89..3c013ff  main -> main
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # notebooks-env

# %%
env_name = "notebooks"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/notebooks_rep.git
#    3e6282f..8da2c70  main -> main
# [main 81aac77] Jun 22
#  6 files changed, 2596 insertions(+), 3364 deletions(-)
#  rename notebooks/.ipynb_checkpoints/{daily_executions-checkpoint.ipynb => daily_execution-checkpoint.ipynb} (100%)
#  rename notebooks/{daily_executions.ipynb => daily_execution.ipynb} (67%)
#  rewrite notebooks/sgx_securities.ipynb (89%)

# %% [markdown]
# # web_scraping-env

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"
option_name = "/mnt/d/Youtube/TED_Pool"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Everything up-to-date
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # daily check

# %%
from datetime import datetime

# Get today's date
today = datetime.now()

# Get the week number starting from Sunday
# %U: Week number of the year (Sunday as the first day of the week)
week_number = today.strftime("%U")

print(f"Today's date: {today.strftime('%Y-%m-%d')}")
print(f"Week Number (Sunday start): {week_number}")
# Out:
# Today's date: 2026-06-22
# Week Number (Sunday start): 25

# %%
import datetime
import pandas as pd
import yfinance as yf
from IPython.display import display, HTML

# Define the lookback periods (in business days) for performance calculation.
LOOKBACK_DAYS = {
    "1 Day (%)": -2,
    "3 Days (%)": -4,
    "1 Week (%)": -6,
    "1 Month (%)": -21,
    "6 Months (%)": -126,
    "1 Year (%)": -252,
}

# =====================================================================
# DATA PROCESSING FUNCTION (Supports Market Segmentation)
# =====================================================================
def show_market_performances(market_dict):
    today = datetime.date.today()
    start_date = today - datetime.timedelta(days=60)
    
    # Format numerical values to 2 decimal places
    format_config = {"Latest Price": "{:,.2f}"}
    for column_name in LOOKBACK_DAYS.keys():
        format_config[column_name] = "{:+.2f}%"
        
    # Process each market section
    for market_name, ticker_dict in market_dict.items():
        records = []
        
        # Display market header
        display(HTML(f"<h3 style='margin-top: 20px; color: #333;'>■ {market_name} Market</h3>"))
        
        for name, ticker in ticker_dict.items():
            try:
                # Download stock data
                df = yf.download(ticker, start=start_date, end=today, progress=False)
                
                if df.empty:
                    print(f"[Warning] No data found for: {name} ({ticker})")
                    continue
                    
                prices = df["Close"].squeeze()
                latest_price = prices.iloc[-1]
                
                row = {
                    "Name": name,
                    "Ticker": ticker,
                    "Latest Price": latest_price
                }
                
                for label, index in LOOKBACK_DAYS.items():
                    if len(prices) >= abs(index):
                        past_price = prices.iloc[index]
                    else:
                        past_price = prices.iloc[0]
                    
                    row[label] = ((latest_price - past_price) / past_price) * 100
                    
                records.append(row)
                
            except Exception as e:
                print(f"[Error] Failed to process {name}: {e}")
        
        if records:
            df_performance = pd.DataFrame(records)
            # Display formatted table for the current market
            display(df_performance.style.format(format_config).hide(axis="index"))
        else:
            print("No data available for this market.")

# %%
# =====================================================================
# CONFIGURATION & EXECUTION (Segmented by Market)
# =====================================================================
MARKET_TICKERS = {
    "United States": {
        "S&P 500": "^GSPC",
        "NASDAQ Composite": "^IXIC",
        "Apple": "AAPL",
        "NVIDIA": "NVDA",
        "Microsoft": "MSFT",
    },
    "Japan": {
        "Nikkei 225": "^N225",
        "Toyota Motor": "7203.T",
        "Sony Group": "6758.T",
        "Mitsubishi UFJ Financial": "8306.T",
    },
    "Singapore": {
        "STI Index": "^STI",
        "DBS Group": "D05.SI",
        "UOB": "U11.SI",
        "Singtel": "Z74.SI",
        "CapitaLand Ascendas REIT": "A17U.SI",
    }
}

# Run and display the segmented tables
show_market_performances(MARKET_TICKERS)
# Out:
# <h3 style='margin-top: 20px; color: #333;'>■ United States Market</h3>
# <style type="text/css">
# </style>
# <table id="T_52fe9">
#   <thead>
#     <tr>
#       <th id="T_52fe9_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_52fe9_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_52fe9_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_52fe9_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_52fe9_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_52fe9_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_52fe9_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_52fe9_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_52fe9_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52fe9_row0_col0" class="data row0 col0" >S&P 500</td>
#       <td id="T_52fe9_row0_col1" class="data row0 col1" >^GSPC</td>
#       <td id="T_52fe9_row0_col2" class="data row0 col2" >7,500.58</td>
#       <td id="T_52fe9_row0_col3" class="data row0 col3" >+1.08%</td>
#       <td id="T_52fe9_row0_col4" class="data row0 col4" >-0.71%</td>
#       <td id="T_52fe9_row0_col5" class="data row0 col5" >+1.44%</td>
#       <td id="T_52fe9_row0_col6" class="data row0 col6" >+0.91%</td>
#       <td id="T_52fe9_row0_col7" class="data row0 col7" >+5.52%</td>
#       <td id="T_52fe9_row0_col8" class="data row0 col8" >+5.52%</td>
#     </tr>
#     <tr>
#       <td id="T_52fe9_row1_col0" class="data row1 col0" >NASDAQ Composite</td>
#       <td id="T_52fe9_row1_col1" class="data row1 col1" >^IXIC</td>
#       <td id="T_52fe9_row1_col2" class="data row1 col2" >26,517.93</td>
#       <td id="T_52fe9_row1_col3" class="data row1 col3" >+1.91%</td>
#       <td id="T_52fe9_row1_col4" class="data row1 col4" >-0.62%</td>
#       <td id="T_52fe9_row1_col5" class="data row1 col5" >+2.74%</td>
#       <td id="T_52fe9_row1_col6" class="data row1 col6" >+0.94%</td>
#       <td id="T_52fe9_row1_col7" class="data row1 col7" >+8.51%</td>
#       <td id="T_52fe9_row1_col8" class="data row1 col8" >+8.51%</td>
#     </tr>
#     <tr>
#       <td id="T_52fe9_row2_col0" class="data row2 col0" >Apple</td>
#       <td id="T_52fe9_row2_col1" class="data row2 col1" >AAPL</td>
#       <td id="T_52fe9_row2_col2" class="data row2 col2" >298.01</td>
#       <td id="T_52fe9_row2_col3" class="data row2 col3" >+0.70%</td>
#       <td id="T_52fe9_row2_col4" class="data row2 col4" >+0.54%</td>
#       <td id="T_52fe9_row2_col5" class="data row2 col5" >+0.81%</td>
#       <td id="T_52fe9_row2_col6" class="data row2 col6" >-1.40%</td>
#       <td id="T_52fe9_row2_col7" class="data row2 col7" >+9.09%</td>
#       <td id="T_52fe9_row2_col8" class="data row2 col8" >+9.09%</td>
#     </tr>
#     <tr>
#       <td id="T_52fe9_row3_col0" class="data row3 col0" >NVIDIA</td>
#       <td id="T_52fe9_row3_col1" class="data row3 col1" >NVDA</td>
#       <td id="T_52fe9_row3_col2" class="data row3 col2" >210.69</td>
#       <td id="T_52fe9_row3_col3" class="data row3 col3" >+2.95%</td>
#       <td id="T_52fe9_row3_col4" class="data row3 col4" >-0.83%</td>
#       <td id="T_52fe9_row3_col5" class="data row3 col5" >+2.84%</td>
#       <td id="T_52fe9_row3_col6" class="data row3 col6" >-5.61%</td>
#       <td id="T_52fe9_row3_col7" class="data row3 col7" >+5.66%</td>
#       <td id="T_52fe9_row3_col8" class="data row3 col8" >+5.66%</td>
#     </tr>
#     <tr>
#       <td id="T_52fe9_row4_col0" class="data row4 col0" >Microsoft</td>
#       <td id="T_52fe9_row4_col1" class="data row4 col1" >MSFT</td>
#       <td id="T_52fe9_row4_col2" class="data row4 col2" >379.40</td>
#       <td id="T_52fe9_row4_col3" class="data row4 col3" >+0.13%</td>
#       <td id="T_52fe9_row4_col4" class="data row4 col4" >-5.09%</td>
#       <td id="T_52fe9_row4_col5" class="data row4 col5" >-2.80%</td>
#       <td id="T_52fe9_row4_col6" class="data row4 col6" >-9.70%</td>
#       <td id="T_52fe9_row4_col7" class="data row4 col7" >-8.55%</td>
#       <td id="T_52fe9_row4_col8" class="data row4 col8" >-8.55%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ Japan Market</h3>
# <style type="text/css">
# </style>
# <table id="T_83053">
#   <thead>
#     <tr>
#       <th id="T_83053_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_83053_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_83053_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_83053_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_83053_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_83053_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_83053_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_83053_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_83053_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83053_row0_col0" class="data row0 col0" >Nikkei 225</td>
#       <td id="T_83053_row0_col1" class="data row0 col1" >^N225</td>
#       <td id="T_83053_row0_col2" class="data row0 col2" >71,250.06</td>
#       <td id="T_83053_row0_col3" class="data row0 col3" >+0.28%</td>
#       <td id="T_83053_row0_col4" class="data row0 col4" >+2.66%</td>
#       <td id="T_83053_row0_col5" class="data row0 col5" >+7.92%</td>
#       <td id="T_83053_row0_col6" class="data row0 col6" >+12.49%</td>
#       <td id="T_83053_row0_col7" class="data row0 col7" >+20.48%</td>
#       <td id="T_83053_row0_col8" class="data row0 col8" >+20.48%</td>
#     </tr>
#     <tr>
#       <td id="T_83053_row1_col0" class="data row1 col0" >Toyota Motor</td>
#       <td id="T_83053_row1_col1" class="data row1 col1" >7203.T</td>
#       <td id="T_83053_row1_col2" class="data row1 col2" >2,776.50</td>
#       <td id="T_83053_row1_col3" class="data row1 col3" >-0.61%</td>
#       <td id="T_83053_row1_col4" class="data row1 col4" >-2.49%</td>
#       <td id="T_83053_row1_col5" class="data row1 col5" >+0.04%</td>
#       <td id="T_83053_row1_col6" class="data row1 col6" >-7.05%</td>
#       <td id="T_83053_row1_col7" class="data row1 col7" >-11.10%</td>
#       <td id="T_83053_row1_col8" class="data row1 col8" >-11.10%</td>
#     </tr>
#     <tr>
#       <td id="T_83053_row2_col0" class="data row2 col0" >Sony Group</td>
#       <td id="T_83053_row2_col1" class="data row2 col1" >6758.T</td>
#       <td id="T_83053_row2_col2" class="data row2 col2" >3,140.00</td>
#       <td id="T_83053_row2_col3" class="data row2 col3" >-3.38%</td>
#       <td id="T_83053_row2_col4" class="data row2 col4" >-4.12%</td>
#       <td id="T_83053_row2_col5" class="data row2 col5" >-4.62%</td>
#       <td id="T_83053_row2_col6" class="data row2 col6" >-10.92%</td>
#       <td id="T_83053_row2_col7" class="data row2 col7" >-3.77%</td>
#       <td id="T_83053_row2_col8" class="data row2 col8" >-3.77%</td>
#     </tr>
#     <tr>
#       <td id="T_83053_row3_col0" class="data row3 col0" >Mitsubishi UFJ Financial</td>
#       <td id="T_83053_row3_col1" class="data row3 col1" >8306.T</td>
#       <td id="T_83053_row3_col2" class="data row3 col2" >3,278.00</td>
#       <td id="T_83053_row3_col3" class="data row3 col3" >-2.85%</td>
#       <td id="T_83053_row3_col4" class="data row3 col4" >+1.55%</td>
#       <td id="T_83053_row3_col5" class="data row3 col5" >+3.67%</td>
#       <td id="T_83053_row3_col6" class="data row3 col6" >+6.05%</td>
#       <td id="T_83053_row3_col7" class="data row3 col7" >+19.11%</td>
#       <td id="T_83053_row3_col8" class="data row3 col8" >+19.11%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='margin-top: 20px; color: #333;'>■ Singapore Market</h3>
# <style type="text/css">
# </style>
# <table id="T_e0340">
#   <thead>
#     <tr>
#       <th id="T_e0340_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e0340_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_e0340_level0_col2" class="col_heading level0 col2" >Latest Price</th>
#       <th id="T_e0340_level0_col3" class="col_heading level0 col3" >1 Day (%)</th>
#       <th id="T_e0340_level0_col4" class="col_heading level0 col4" >3 Days (%)</th>
#       <th id="T_e0340_level0_col5" class="col_heading level0 col5" >1 Week (%)</th>
#       <th id="T_e0340_level0_col6" class="col_heading level0 col6" >1 Month (%)</th>
#       <th id="T_e0340_level0_col7" class="col_heading level0 col7" >6 Months (%)</th>
#       <th id="T_e0340_level0_col8" class="col_heading level0 col8" >1 Year (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e0340_row0_col0" class="data row0 col0" >STI Index</td>
#       <td id="T_e0340_row0_col1" class="data row0 col1" >^STI</td>
#       <td id="T_e0340_row0_col2" class="data row0 col2" >5,192.70</td>
#       <td id="T_e0340_row0_col3" class="data row0 col3" >-0.39%</td>
#       <td id="T_e0340_row0_col4" class="data row0 col4" >+1.48%</td>
#       <td id="T_e0340_row0_col5" class="data row0 col5" >+3.32%</td>
#       <td id="T_e0340_row0_col6" class="data row0 col6" >+2.93%</td>
#       <td id="T_e0340_row0_col7" class="data row0 col7" >+5.03%</td>
#       <td id="T_e0340_row0_col8" class="data row0 col8" >+5.03%</td>
#     </tr>
#     <tr>
#       <td id="T_e0340_row1_col0" class="data row1 col0" >DBS Group</td>
#       <td id="T_e0340_row1_col1" class="data row1 col1" >D05.SI</td>
#       <td id="T_e0340_row1_col2" class="data row1 col2" >65.96</td>
#       <td id="T_e0340_row1_col3" class="data row1 col3" >-0.06%</td>
#       <td id="T_e0340_row1_col4" class="data row1 col4" >+3.50%</td>
#       <td id="T_e0340_row1_col5" class="data row1 col5" >+4.30%</td>
#       <td id="T_e0340_row1_col6" class="data row1 col6" >+6.82%</td>
#       <td id="T_e0340_row1_col7" class="data row1 col7" >+17.34%</td>
#       <td id="T_e0340_row1_col8" class="data row1 col8" >+17.34%</td>
#     </tr>
#     <tr>
#       <td id="T_e0340_row2_col0" class="data row2 col0" >UOB</td>
#       <td id="T_e0340_row2_col1" class="data row2 col1" >U11.SI</td>
#       <td id="T_e0340_row2_col2" class="data row2 col2" >39.25</td>
#       <td id="T_e0340_row2_col3" class="data row2 col3" >-1.13%</td>
#       <td id="T_e0340_row2_col4" class="data row2 col4" >+0.64%</td>
#       <td id="T_e0340_row2_col5" class="data row2 col5" >+2.86%</td>
#       <td id="T_e0340_row2_col6" class="data row2 col6" >+4.14%</td>
#       <td id="T_e0340_row2_col7" class="data row2 col7" >+8.46%</td>
#       <td id="T_e0340_row2_col8" class="data row2 col8" >+8.46%</td>
#     </tr>
#     <tr>
#       <td id="T_e0340_row3_col0" class="data row3 col0" >Singtel</td>
#       <td id="T_e0340_row3_col1" class="data row3 col1" >Z74.SI</td>
#       <td id="T_e0340_row3_col2" class="data row3 col2" >4.35</td>
#       <td id="T_e0340_row3_col3" class="data row3 col3" >+0.46%</td>
#       <td id="T_e0340_row3_col4" class="data row3 col4" >+1.16%</td>
#       <td id="T_e0340_row3_col5" class="data row3 col5" >+1.87%</td>
#       <td id="T_e0340_row3_col6" class="data row3 col6" >-7.45%</td>
#       <td id="T_e0340_row3_col7" class="data row3 col7" >-7.25%</td>
#       <td id="T_e0340_row3_col8" class="data row3 col8" >-7.25%</td>
#     </tr>
#     <tr>
#       <td id="T_e0340_row4_col0" class="data row4 col0" >CapitaLand Ascendas REIT</td>
#       <td id="T_e0340_row4_col1" class="data row4 col1" >A17U.SI</td>
#       <td id="T_e0340_row4_col2" class="data row4 col2" >2.51</td>
#       <td id="T_e0340_row4_col3" class="data row4 col3" >+0.00%</td>
#       <td id="T_e0340_row4_col4" class="data row4 col4" >-1.18%</td>
#       <td id="T_e0340_row4_col5" class="data row4 col5" >-0.79%</td>
#       <td id="T_e0340_row4_col6" class="data row4 col6" >+0.00%</td>
#       <td id="T_e0340_row4_col7" class="data row4 col7" >-1.95%</td>
#       <td id="T_e0340_row4_col8" class="data row4 col8" >-1.95%</td>
#     </tr>
#   </tbody>
# </table>
