# %% [markdown]
# # <a id='toc1_'></a>[setup](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [setup](#toc1_)
# - [youtube-env](#toc2_)
# - [scripts-env](#toc3_)
# - [notebooks-env](#toc4_)
# - [web_scraping-env](#toc5_)
# - [daily check](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess
from src.calendar_util import display_holiday_calendar
from src.clock_util import draw_clock

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %% [markdown]
# # <a id='toc2_'></a>[youtube-env](#toc0_)

# %%
env_name = "youtube"
cmd_name = "update.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# Requirement already satisfied: pip in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (26.1.2)
# Requirement already satisfied: yt-dlp in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (2026.7.4)

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=siC6hbV96gM
# [youtube] siC6hbV96gM: Downloading webpage
# [youtube] siC6hbV96gM: Downloading android vr player API JSON
# [info] siC6hbV96gM: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-18 - シドニー旅🇦🇺オーストラリア3泊4日飲み歩き。【オセアニア#31】2026年4月10日〜13日 - siC6hbV96gM.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-18 - シドニー旅🇦🇺オーストラリア3泊4日飲み歩き。【オセアニア#31】2026年4月10日〜13日 - siC6hbV96gM.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-18 - シドニー旅🇦🇺オーストラリア3泊4日飲み歩き。【オセアニア#31】2026年4月10日〜13日 - siC6hbV96gM.mp4"
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-18 - シドニー旅🇦🇺オーストラリア3泊4日飲み歩き。【オセアニア#31】2026年4月10日〜13日 - siC6hbV96gM.f251.webm (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-18 - シドニー旅🇦🇺オーストラリア3泊4日飲み歩き。【オセアニア#31】2026年4月10日〜13日 - siC6hbV96gM.f398.mp4 (pass -k to keep)
# [download] Downloading item 2 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7pYe7GHroNU
# [youtube] 7pYe7GHroNU: Downloading webpage
# [youtube] 7pYe7GHroNU: Downloading android vr player API JSON
# [info] 7pYe7GHroNU: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-10 - タンナ島旅🇻🇺バヌアツの世界一近付ける活火山がヤバすぎた。【オセアニア#30】2026年4月1日〜4日 - 7pYe7GHroNU.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-10 - タンナ島旅🇻🇺バヌアツの世界一近付ける活火山がヤバすぎた。【オセアニア#30】2026年4月1日〜4日 - 7pYe7GHroNU.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-10 - タンナ島旅🇻🇺バヌアツの世界一近付ける活火山がヤバすぎた。【オセアニア#30】2026年4月1日〜4日 - 7pYe7GHroNU.mp4"
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-10 - タンナ島旅🇻🇺バヌアツの世界一近付ける活火山がヤバすぎた。【オセアニア#30】2026年4月1日〜4日 - 7pYe7GHroNU.f398.mp4 (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-07-10 - タンナ島旅🇻🇺バヌアツの世界一近付ける活火山がヤバすぎた。【オセアニア#30】2026年4月1日〜4日 - 7pYe7GHroNU.f251.webm (pass -k to keep)
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DW0uFd1P8eo
# [youtube] DW0uFd1P8eo: Downloading webpage
# [youtube] DW0uFd1P8eo: Downloading android vr player API JSON
# [info] DW0uFd1P8eo: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Bappa Shota - Videos/2026-07-18 - 世界一不法移民を徹底的に排除する国の実態が衝撃的すぎた - DW0uFd1P8eo.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Bappa Shota - Videos/2026-07-18 - 世界一不法移民を徹底的に排除する国の実態が衝撃的すぎた - DW0uFd1P8eo.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Bappa Shota - Videos/2026-07-18 - 世界一不法移民を徹底的に排除する国の実態が衝撃的すぎた - DW0uFd1P8eo.mp4"
# Deleting original file /mnt/d/Youtube/Bappa Shota - Videos/2026-07-18 - 世界一不法移民を徹底的に排除する国の実態が衝撃的すぎた - DW0uFd1P8eo.f398.mp4 (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Bappa Shota - Videos/2026-07-18 - 世界一不法移民を徹底的に排除する国の実態が衝撃的すぎた - DW0uFd1P8eo.f251.webm (pass -k to keep)
# [download] Downloading item 2 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XQC-pojFl6k
# [youtube] XQC-pojFl6k: Downloading webpage
# [youtube] XQC-pojFl6k: Downloading android vr player API JSON
# [info] XQC-pojFl6k: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Bappa Shota - Videos/2026-06-27 - 白人専用の世界一人種◯別が酷い街の実態がとんでもなかった - XQC-pojFl6k.f398.mp4

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc3_'></a>[scripts-env](#toc0_)

# %%
env_name = "scripts"
cmd_name = "make_playlist.py -r"
option_name = "/mnt/d/Youtube/Movie_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"python {cmd_name} {option_name}"
)
run_commands_fixed(cmd_string)

# %%
env_name = "scripts"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc4_'></a>[notebooks-env](#toc0_)

# %%
env_name = "notebooks"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %%
env_name = "notebooks"
cmd_name = "freeze_pip.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc5_'></a>[web_scraping-env](#toc0_)

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc6_'></a>[daily check](#toc0_)

# %%
cmd_name = "backup.sh"

cmd_string = (
    f"cd ~ && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %% [markdown]
# <div style="background-color: #EBCB8B; color: #2E3440; padding: 12px; border-radius: 5px; font-weight: bold;">
# </div>

# %%
display_holiday_calendar()
