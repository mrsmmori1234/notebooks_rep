# %% [markdown]
# # <a id='toc1_'></a>[setup](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [setup](#toc1_)
# - [youtube-env](#toc2_)
# - [scripts-env](#toc3_)
# - [notebooks-env](#toc4_)
# - [web_scraping-env](#toc5_)
# - [daily check](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
from src.system import run_commands
import subprocess
from src.calendar_util import display_holiday_calendar
from src.clock_util import draw_clock

# %%
import subprocess

def run_commands_fixed(cmd_string):
    process = subprocess.Popen(
        cmd_string,  # ← 'cmd_str' から 'cmd_string' に修正
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT, 
        text=True
    )
    
    for line in process.stdout:
        print(line, end="")
        
    process.wait()

# %% [markdown]
# # <a id='toc2_'></a>[youtube-env](#toc0_)

# %%
env_name = "youtube"
cmd_name = "update.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# Requirement already satisfied: pip in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (26.1.2)
# Requirement already satisfied: yt-dlp in /home/mrsmmori/.pyenv/versions/3.12.2/envs/youtube-env/lib/python3.12/site-packages (2026.6.9)

# %%
env_name = "youtube"
cmd_name = "channel_mp4.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# ----
# Processing: https://www.youtube.com/@ShigeTravel/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@ShigeTravel/videos
# [youtube:tab] @ShigeTravel/videos: Downloading webpage
# [download] Downloading playlist: Japanese Traveler SHIGE - Videos
# [youtube:tab] Playlist Japanese Traveler SHIGE - Videos: Downloading 2 items
# [download] Downloading item 1 of 2
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nhsRIWSv5us
# [youtube] nhsRIWSv5us: Downloading webpage
# [youtube] nhsRIWSv5us: Downloading android vr player API JSON
# [info] nhsRIWSv5us: Downloading 1 format(s): 398+251
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-30 - W杯ブラジル戦、現地スタジアムの天国と地獄。【北中米W杯#10】2026年6月29日 - nhsRIWSv5us.f398.mp4
# [download] Download completed
# [download] Destination: /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-30 - W杯ブラジル戦、現地スタジアムの天国と地獄。【北中米W杯#10】2026年6月29日 - nhsRIWSv5us.f251.webm
# [download] Download completed
# [Merger] Merging formats into "/mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-30 - W杯ブラジル戦、現地スタジアムの天国と地獄。【北中米W杯#10】2026年6月29日 - nhsRIWSv5us.mp4"
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-30 - W杯ブラジル戦、現地スタジアムの天国と地獄。【北中米W杯#10】2026年6月29日 - nhsRIWSv5us.f251.webm (pass -k to keep)
# Deleting original file /mnt/d/Youtube/Japanese Traveler SHIGE - Videos/2026-06-30 - W杯ブラジル戦、現地スタジアムの天国と地獄。【北中米W杯#10】2026年6月29日 - nhsRIWSv5us.f398.mp4 (pass -k to keep)
# [download] fcbMnLEr6Uk: World Cup Sweden Match: Local fans go wild as we advance to the knockout stage! [North and Centra... has already been recorded in the archive
# [download] Finished downloading playlist: Japanese Traveler SHIGE - Videos
# Completed: https://www.youtube.com/@ShigeTravel/videos
# ----
# Processing: https://www.youtube.com/@BappaShota/videos (subs=n)
# [youtube:tab] Extracting URL: https://www.youtube.com/@BappaShota/videos
# [youtube:tab] @BappaShota/videos: Downloading webpage
# [download] Downloading playlist: Bappa Shota - Videos
# [youtube:tab] Playlist Bappa Shota - Videos: Downloading 2 items
# [download] XQC-pojFl6k: Investigating South Africa’s White-Only Town has already been recorded in the archive
# [download] kcxRQo6MgN0: Inside Of The Most Unequal Country In The World has already been recorded in the archive
# [download] Finished downloading playlist: Bappa Shota - Videos
# Completed: https://www.youtube.com/@BappaShota/videos
# ✅ All processes completed

# %%
env_name = "youtube"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)
# Out:
# To https://github.com/mrsmmori1234/youtube_rep.git
#    98fc97b..3756aa0  main -> main
# [main 7be4aaa] Jun 30
#  2 files changed, 8 insertions(+), 1 deletion(-)

# %% [markdown]
# # <a id='toc3_'></a>[scripts-env](#toc0_)

# %%
env_name = "scripts"
cmd_name = "make_playlist.py"
option_name = "/mnt/d/Youtube/Movie_Pool"



cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"python {cmd_name} {option_name}"
)
run_commands_fixed(cmd_string)
# Out:
# Playlist created for Windows VLC: /mnt/d/Youtube/Movie_Pool.xspf

# %%
env_name = "scripts"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc4_'></a>[notebooks-env](#toc0_)

# %%
env_name = "notebooks"
cmd_name = "backup.sh"

cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %%
env_name = "notebooks"
cmd_name = "freeze_pip.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc5_'></a>[web_scraping-env](#toc0_)

# %%
env_name = "web_scraping"
cmd_name = "backup.sh"


cmd_string = (
    f"source ~/.pyenv/versions/3.12.2/envs/{env_name}-env/bin/activate && "
    f"cd ~/{env_name} && "
    f"./{cmd_name}"
)
run_commands_fixed(cmd_string)

# %% [markdown]
# # <a id='toc6_'></a>[daily check](#toc0_)

# %%
cmd_name = "backup.sh"

cmd_string = (
    f"cd ~ && "
    f"./{cmd_name}"
)

run_commands_fixed(cmd_string)

# %%
display_holiday_calendar()

# %%
draw_clock()
